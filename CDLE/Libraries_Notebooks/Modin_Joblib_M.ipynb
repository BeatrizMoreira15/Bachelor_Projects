# %% [markdown]
# # Modin_Joblib - Medium Dataset

# %% [markdown]
# **Summary of this notebook**
#
# This notebook presents a benchmarking analysis of common data processing operations using Joblib and Modin on the **medium dataset**. The tasks include filtering, arithmetic operations, aggregations, groupbys, joins, and profiling with cProfile, allowing a performance comparison between the two libraries.

# %% [markdown]
# **Setup and configurations**

# %%
# Importing required packages
import pandas as pd
import pyspark
import pyarrow
import numpy as np
import os
import requests
import time
import joblib
import modin.pandas as md
from dask.distributed import Client, LocalCluster
import modin.config as cfg
from joblib import parallel_backend, Parallel, delayed
from joblib import Parallel, delayed, dump, load
import dask.dataframe as dd

# Check versions
print("pandas version:", pd.__version__)
print("pyspark version:", pyspark.__version__)
print("pyarrow version:", pyarrow.__version__)
print("numpy version:", np.__version__)
print("modin version:", md.__version__)
print("joblib version:", joblib.__version__)
# Out:
# pandas version: 1.3.5
# pyspark version: 3.4.4
# pyarrow version: 1.0.1
# numpy version: 1.19.5
# modin version: 0.12.1
# joblib version: 1.3.2

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# Modin was configured to use Dask as its execution engine, and a Dask client was started. After that, the dataset was read with Modin and basic information about the DataFrame was displayed.

# %%
# Configure Modin to use Dask
cfg.Engine.put("dask")

# %%
client = Client()
# Out:
# distributed.diskutils - INFO - Found stale lock file and directory '/home/jupyter/dask-worker-space/worker-oa2u7yho', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/home/jupyter/dask-worker-space/worker-5_peb69k', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/home/jupyter/dask-worker-space/worker-c0hvn3os', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/home/jupyter/dask-worker-space/worker-l4qo7f6s', purging

# %%
modin_data = md.read_parquet("Samples/sample_2009_2010_medium_clean.parquet")

# %%
modin_data.info()
# Out:
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 2190009 entries, 0 to 2190008
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ---------------------  ----------------  -----
#  0   index                  2190009 non-null  int64
#  1   vendor_name            2190009 non-null  object
#  2   Trip_Pickup_DateTime   2190009 non-null  datetime64[ns]
#  3   Trip_Dropoff_DateTime  2190009 non-null  object
#  4   Passenger_Count        2190009 non-null  int64
#  5   Trip_Distance          2190009 non-null  float64
#  6   Start_Lon              2190009 non-null  float64
#  7   Start_Lat              2190009 non-null  float64
#  8   End_Lon                2190009 non-null  float64
#  9   End_Lat                2190009 non-null  float64
#  10  Payment_Type           2190009 non-null  object
#  11  Fare_Amt               2190009 non-null  float64
#  12  surcharge              2190009 non-null  float64
#  13  Tip_Amt                2190009 non-null  float64
#  14  Tolls_Amt              2190009 non-null  float64
#  15  Total_Amt              2190009 non-null  float64
#  16  year                   2190009 non-null  int64
#  17  month                  2190009 non-null  int64
#  18  day                    2190009 non-null  int64
#  19  hour                   2190009 non-null  int64
# dtypes: float64(10), int64(6), object(3), datetime64[ns](1)
# memory usage: 334.2 MB

# %% [markdown]
# # Benchmark

# %% [markdown]
# # Modin

# %% [markdown]
# Several benchmark functions were defined to measure execution time of different operations using Modin. Then, benchmark results are stored in dictionaries for standard, filtered, and cached scenarios.

# %%
def benchmark(f, df, benchmarks, name, **kwargs):
    """Benchmark the given function against the given DataFrame.

    Parameters
    ----------
    f: function to benchmark
    df: data frame
    benchmarks: container for benchmark results
    name: task name

    Returns
    -------
    Duration (in seconds, high precision) of the given operation
    """
    start_time = time.perf_counter()  # alta precisão
    ret = f(df, **kwargs)
    duration = time.perf_counter() - start_time
    benchmarks['duration'].append(duration)
    benchmarks['task'].append(name)
    print(f"{name} took: {duration:.6f} seconds")
    return duration

def get_results(benchmarks):
    """Return a pandas DataFrame containing benchmark results."""
    return pd.DataFrame.from_dict(benchmarks)

# %%
def read_file_parquet(df=None):
    return md.read_parquet("Samples/sample_2009_2010_medium_clean.parquet")

def count(df=None):
    return len(df)

def count_index_length(df=None):
    return len(df.index)

def mean(df):
    return df.Fare_Amt.mean()

def standard_deviation(df):
    return df.Fare_Amt.std()

def mean_of_sum(df):
    return (df.Fare_Amt + df.Tip_Amt).mean()

def sum_columns(df):
    x = df.Fare_Amt + df.Tip_Amt

    return x

def mean_of_product(df):
    return (df.Fare_Amt * df.Tip_Amt).mean()

def product_columns(df):
    x = df.Fare_Amt * df.Tip_Amt

    return x

def value_counts(df):
    val_counts = df.Fare_Amt.value_counts()
    return val_counts

def complicated_arithmetic_operation(df):
    theta_1 = df.Start_Lon
    phi_1 = df.Start_Lat
    theta_2 = df.End_Lon
    phi_2 = df.End_Lat
    temp = (np.sin((theta_2 - theta_1) / 2 * np.pi / 180) ** 2
           + np.cos(theta_1 * np.pi / 180) * np.cos(theta_2 * np.pi / 180) * np.sin((phi_2 - phi_1) / 2 * np.pi / 180) ** 2)
    ret = np.multiply(np.arctan2(np.sqrt(temp), np.sqrt(1-temp)),2)

    return ret

def mean_of_complicated_arithmetic_operation(df):
    theta_1 = df.Start_Lon
    phi_1 = df.Start_Lat
    theta_2 = df.End_Lon
    phi_2 = df.End_Lat
    temp = (np.sin((theta_2 - theta_1) / 2 * np.pi / 180) ** 2
           + np.cos(theta_1 * np.pi / 180) * np.cos(theta_2 * np.pi / 180) * np.sin((phi_2 - phi_1) / 2 * np.pi / 180) ** 2)
    ret = np.multiply(np.arctan2(np.sqrt(temp), np.sqrt(1-temp)),2)
    return ret.mean()

def groupby_statistics(df):
    gb = df.groupby(by='Passenger_Count').agg(
      {
        'Fare_Amt': ['mean', 'std'],
        'Tip_Amt': ['mean', 'std']
      }
    )
    return gb

other = md.DataFrame(groupby_statistics(modin_data))
other.columns = md.Index([e[0]+'_' + e[1] for e in other.columns.tolist()])

def join_count(df, other):
    return len(df.merge(other, left_index=True, right_index=True))

def join_data(df, other):
    return df.merge(other, left_index=True, right_index=True)

# %%
modin_benchmarks = {
    'duration': [],  # in seconds
    'task': [],
}

modin_benchmarks_filtered = {
    'duration': [],  # in seconds
    'task': [],
}

modin_benchmarks_cache = {
    'duration': [],  # in seconds
    'task': [],
}

# %% [markdown]
# After that, each function was benchmarked using the benchmark() utility. The tasks were applied to the Modin DataFrame

# %%
# Execute benchmark
benchmark(read_file_parquet, df=None, benchmarks=modin_benchmarks, name='read file')
benchmark(count, df=modin_data, benchmarks=modin_benchmarks, name='count')
benchmark(count_index_length, df=modin_data, benchmarks=modin_benchmarks, name='count index length')
benchmark(mean, df=modin_data, benchmarks=modin_benchmarks, name='mean')
benchmark(standard_deviation, df=modin_data, benchmarks=modin_benchmarks, name='standard deviation')
benchmark(mean_of_sum, df=modin_data, benchmarks=modin_benchmarks, name='mean of columns addition')
benchmark(sum_columns, df=modin_data, benchmarks=modin_benchmarks, name='addition of columns')
benchmark(mean_of_product, df=modin_data, benchmarks=modin_benchmarks, name='mean of columns multiplication')
benchmark(product_columns, df=modin_data, benchmarks=modin_benchmarks, name='multiplication of columns')
benchmark(value_counts, df=modin_data, benchmarks=modin_benchmarks, name='value counts')
benchmark(complicated_arithmetic_operation, df=modin_data, benchmarks=modin_benchmarks, name='complex arithmetic ops')
benchmark(mean_of_complicated_arithmetic_operation, df=modin_data, benchmarks=modin_benchmarks, name='mean of complex arithmetic ops')
benchmark(groupby_statistics, df=modin_data, benchmarks=modin_benchmarks, name='groupby statistics')
benchmark(join_count, modin_data, benchmarks=modin_benchmarks, name='join count', other=other)
benchmark(join_data, modin_data, benchmarks=modin_benchmarks, name='join', other=other)
# Out:
# read file took: 1.108470 seconds
# count took: 0.000016 seconds
# count index length took: 0.000006 seconds
# mean took: 0.098757 seconds
# standard deviation took: 0.102205 seconds
# mean of columns addition took: 0.410183 seconds
# addition of columns took: 0.323195 seconds
# mean of columns multiplication took: 0.404205 seconds
# multiplication of columns took: 0.303075 seconds
# value counts took: 0.473489 seconds
# complex arithmetic ops took: 4.097208 seconds
# mean of complex arithmetic ops took: 4.369861 seconds
# groupby statistics took: 0.313020 seconds
# join count took: 0.760922 seconds
# join took: 0.709835 seconds
# 0.7098348320000127

# %%
# Retrieve benchmark results and remove duplicate task entries
modin_res_temp = get_results(modin_benchmarks).drop_duplicates(subset='task').set_index('task')

# Print the result DataFrame
print(modin_res_temp)

# Define the file path for saving
filename = 'Results_Modin_M/modin_local_medium'

# Save the result DataFrame as a Parquet file
modin_res_temp.to_parquet(filename)

print(f'O arquivo Parquet foi salvo em {filename}.')
# Out:
#                                 duration
# task
# read file                       1.108470
# count                           0.000016
# count index length              0.000006
# mean                            0.098757
# standard deviation              0.102205
# mean of columns addition        0.410183
# addition of columns             0.323195
# mean of columns multiplication  0.404205
# multiplication of columns       0.303075
# value counts                    0.473489
# complex arithmetic ops          4.097208
# mean of complex arithmetic ops  4.369861
# groupby statistics              0.313020
# join count                      0.760922
# join                            0.709835
# O arquivo Parquet foi salvo em Results_Modin_M/modin_local_medium.

# %% [markdown]
# ## cProfile

# %% [markdown]
# In this section, the same Modin benchmarks were executed using the cProfile module to collect detailed profiling statistics. This allows for deeper analysis of function performance by identifying the most time-consuming operations. Execution times and profiling data were saved for later comparison.

# %%
import cProfile
import matplotlib.pyplot as plt
from io import StringIO
import pstats

# %%
def benchmark_cprofile(f, df, benchmarks, name, profile_data=None, **kwargs):
    """
    Benchmark and profile the execution of a function using cProfile (without file I/O).
    
    Parameters:
    - f: function to benchmark
    - df: input dataframe (or None)
    - benchmarks: dictionary to store timing results
    - name: name of the benchmark task
    - profile_data: optional list to store detailed profiling data
    - kwargs: other keyword arguments passed to the function
    """    
    pr = cProfile.Profile() #Create a profile object
    pr.enable()             #Start profiling

    start_time = time.perf_counter()
    ret = f(df, **kwargs)
    duration = time.perf_counter() - start_time

    pr.disable()

    benchmarks['duration'].append(duration)
    benchmarks['task'].append(name)
    print(f"{name} took: {duration:.4f} seconds")

    # Print top 15 most time-consuming operations to the terminal 
    ps = pstats.Stats(pr)
    ps.sort_stats(pstats.SortKey.CUMULATIVE)
    ps.print_stats(15)

    # Store detailed profiling data for later visualization
    if profile_data is not None:
        stats_data = []
        for func, stat in ps.stats.items():
            filename, lineno, function = func
            ncalls, _, percall, cumtime, _ = stat
            stats_data.append({
                'task': name,
                'function': f"{filename}:{lineno} ({function})",
                'percall': percall,
                'cumtime': cumtime,
                'ncalls': ncalls
            })
        profile_data.append(pd.DataFrame(stats_data))

    return duration

# %%
# Store benchmark durations and task names
modin_benchmarks_cprofile = {'duration': [], 'task': []}
# Store profiling details per function
modin_profile_data = []

# Run the benchmarks with profiling enabled
benchmark_cprofile(read_file_parquet, df=None, benchmarks=modin_benchmarks_cprofile, name='read file', profile_data=modin_profile_data)
benchmark_cprofile(count, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='count', profile_data=modin_profile_data)
benchmark_cprofile(count_index_length, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='count index length', profile_data=modin_profile_data)
benchmark_cprofile(mean, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='mean', profile_data=modin_profile_data)
benchmark_cprofile(standard_deviation, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='standard deviation', profile_data=modin_profile_data)
benchmark_cprofile(mean_of_sum, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='mean of columns addition', profile_data=modin_profile_data)
benchmark_cprofile(sum_columns, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='addition of columns', profile_data=modin_profile_data)
benchmark_cprofile(mean_of_product, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='mean of columns multiplication', profile_data=modin_profile_data)
benchmark_cprofile(product_columns, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='multiplication of columns', profile_data=modin_profile_data)
benchmark_cprofile(value_counts, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='value counts', profile_data=modin_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='complex arithmetic ops', profile_data=modin_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='mean of complex arithmetic ops', profile_data=modin_profile_data)
benchmark_cprofile(groupby_statistics, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='groupby statistics', profile_data=modin_profile_data)
benchmark_cprofile(join_count, modin_data, benchmarks=modin_benchmarks_cprofile, name='join count', other=other, profile_data=modin_profile_data)
benchmark_cprofile(join_data, modin_data, benchmarks=modin_benchmarks_cprofile, name='join', other=other, profile_data=modin_profile_data)
# Out:
# read file took: 1.0965 seconds
#          63816 function calls (60667 primitive calls) in 1.096 seconds
#
#    Ordered by: cumulative time
#    List reduced from 526 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.096    1.096 /var/tmp/ipykernel_3248/742427061.py:1(read_file_parquet)
#         1    0.000    0.000    1.096    1.096 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/io.py:203(read_parquet)
#         1    0.000    0.000    1.096    1.096 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/dispatcher.py:172(read_parquet)
#         1    0.000    0.000    1.096    1.096 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/factories.py:189(_read_parquet)
#         1    0.000    0.000    1.096    1.096 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/file_dispatcher.py:128(read)
#         1    0.000    0.000    1.096    1.096 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/parquet_dispatcher.py:31(_read)
#         1    0.000    0.000    1.095    1.095 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/column_store_dispatcher.py:197(build_query_compiler)
#         2    0.000    0.000    1.064    0.532 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/common/task_wrapper.py:48(materialize)
#         2    0.000    0.000    1.064    0.532 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2093(gather)
#         2    0.000    0.000    1.064    0.532 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    1.064    0.532 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    1.064    0.532 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    1.064    0.532 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    1.064    0.532 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    1.064    0.133    1.064    0.133 {method 'acquire' of '_thread.lock' objects}
#
#
# count took: 0.0000 seconds
#          14 function calls (11 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/742427061.py:4(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023(__len__)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806(__len__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          12 function calls (10 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/742427061.py:7(count_index_length)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806(__len__)
#
#
# mean took: 0.1307 seconds
#          117434 function calls (113969 primitive calls) in 0.131 seconds
#
#    Ordered by: cumulative time
#    List reduced from 787 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.131    0.131 /var/tmp/ipykernel_3248/742427061.py:10(mean)
#         1    0.000    0.000    0.129    0.129 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1724(mean)
#         1    0.000    0.000    0.129    0.129 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.107    0.107 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:721(mean)
#         1    0.000    0.000    0.107    0.107 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/map_reduce.py:43(caller)
#         1    0.000    0.000    0.106    0.106 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1256(map_reduce)
#        29    0.000    0.000    0.066    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        29    0.000    0.000    0.063    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.060    0.060 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.060    0.060 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         3    0.000    0.000    0.059    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         3    0.000    0.000    0.059    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         3    0.000    0.000    0.059    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         3    0.000    0.000    0.059    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         3    0.000    0.000    0.059    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# standard deviation took: 0.1191 seconds
#          127341 function calls (123401 primitive calls) in 0.119 seconds
#
#    Ordered by: cumulative time
#    List reduced from 792 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.119    0.119 /var/tmp/ipykernel_3248/742427061.py:13(standard_deviation)
#         1    0.000    0.000    0.118    0.118 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2448(std)
#         1    0.000    0.000    0.117    0.117 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.081    0.081 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/reduction.py:42(caller)
#         1    0.000    0.000    0.080    0.080 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1234(fold_reduce)
#         1    0.000    0.000    0.080    0.080 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.080    0.080 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#        29    0.001    0.000    0.068    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        29    0.001    0.000    0.061    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.046    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    0.046    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    0.046    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    0.046    0.023 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    0.046    0.023 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    0.046    0.006    0.046    0.006 {method 'acquire' of '_thread.lock' objects}
#
#
# mean of columns addition took: 0.5314 seconds
#          624068 function calls (604677 primitive calls) in 0.531 seconds
#
#    Ordered by: cumulative time
#    List reduced from 868 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.531    0.531 /var/tmp/ipykernel_3248/742427061.py:16(mean_of_sum)
#         1    0.000    0.000    0.414    0.414 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.414    0.414 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.412    0.412 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.412    0.412 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.412    0.412 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       157    0.005    0.000    0.313    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       157    0.002    0.000    0.297    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#        10    0.000    0.000    0.205    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.205    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        10    0.000    0.000    0.205    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.205    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.205    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        40    0.205    0.005    0.205    0.005 {method 'acquire' of '_thread.lock' objects}
#
#
# addition of columns took: 0.4144 seconds
#          518936 function calls (502087 primitive calls) in 0.414 seconds
#
#    Ordered by: cumulative time
#    List reduced from 644 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.414    0.414 /var/tmp/ipykernel_3248/742427061.py:19(sum_columns)
#         1    0.000    0.000    0.412    0.412 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.412    0.412 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.410    0.410 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.409    0.409 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       128    0.004    0.000    0.273    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       128    0.002    0.000    0.255    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.213    0.213 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#       128    0.001    0.000    0.149    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       128    0.000    0.000    0.147    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#       128    0.001    0.000    0.146    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:946(getsourcelines)
#         1    0.000    0.000    0.134    0.134 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1266(<listcomp>)
#         4    0.000    0.000    0.134    0.034 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#
#
# mean of columns multiplication took: 0.5330 seconds
#          624063 function calls (604673 primitive calls) in 0.533 seconds
#
#    Ordered by: cumulative time
#    List reduced from 868 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.533    0.533 /var/tmp/ipykernel_3248/742427061.py:24(mean_of_product)
#         1    0.000    0.000    0.413    0.413 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.413    0.413 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.410    0.410 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       157    0.002    0.000    0.310    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       157    0.002    0.000    0.292    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#        10    0.000    0.000    0.209    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.208    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        10    0.000    0.000    0.208    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.208    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.208    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        40    0.208    0.005    0.208    0.005 {method 'acquire' of '_thread.lock' objects}
#
#
# multiplication of columns took: 0.4342 seconds
#          518940 function calls (502091 primitive calls) in 0.434 seconds
#
#    Ordered by: cumulative time
#    List reduced from 644 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.434    0.434 /var/tmp/ipykernel_3248/742427061.py:27(product_columns)
#         1    0.000    0.000    0.432    0.432 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.431    0.431 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.430    0.430 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.430    0.430 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.430    0.430 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.429    0.429 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       128    0.002    0.000    0.254    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       128    0.002    0.000    0.239    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.196    0.196 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#         7    0.000    0.000    0.169    0.024 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.169    0.024 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.169    0.024 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.169    0.024 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.169    0.024 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# value counts took: 0.5783 seconds
#          589418 function calls (572798 primitive calls) in 0.578 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1079 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.578    0.578 /var/tmp/ipykernel_3248/742427061.py:32(value_counts)
#         1    0.000    0.000    0.577    0.577 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1974(value_counts)
#         1    0.000    0.000    0.577    0.577 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2888(value_counts)
#         1    0.000    0.000    0.312    0.312 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:581(size)
#       139    0.005    0.000    0.298    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#         1    0.000    0.000    0.275    0.275 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:913(_wrap_aggregation)
#         1    0.000    0.000    0.274    0.274 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2495(groupby_size)
#         1    0.000    0.000    0.273    0.273 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2518(_groupby_dict_reduce)
#         1    0.000    0.000    0.273    0.273 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/groupby.py:67(<lambda>)
#         1    0.000    0.000    0.273    0.273 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/groupby.py:239(caller)
#         1    0.000    0.000    0.273    0.273 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2107(groupby_reduce)
#       139    0.002    0.000    0.270    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.264    0.264 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1709(sort_values)
#         1    0.000    0.000    0.262    0.262 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2415(sort_values)
#         1    0.000    0.000    0.262    0.262 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:3065(sort_rows_by_column_values)
#
#
# complex arithmetic ops took: 4.8279 seconds
#          3899575 function calls (3785122 primitive calls) in 4.826 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1062 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.133    0.133    4.828    4.828 /var/tmp/ipykernel_3248/742427061.py:36(complicated_arithmetic_operation)
#        18    0.000    0.000    2.548    0.142 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.546    0.141 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#       192    0.002    0.000    2.360    0.012 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       192    0.002    0.000    2.357    0.012 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       192    0.000    0.000    2.346    0.012 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       192    0.001    0.000    2.345    0.012 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       192    0.001    0.000    2.344    0.012 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       768    2.342    0.003    2.342    0.003 {method 'acquire' of '_thread.lock' objects}
#         5    0.000    0.000    2.055    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       940    0.021    0.000    1.914    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       940    0.012    0.000    1.776    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       132    0.001    0.000    1.487    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       112    0.001    0.000    1.324    0.012 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/partition.py:56(get)
#       940    0.009    0.000    1.065    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#
#
# mean of complex arithmetic ops took: 4.9968 seconds
#          4015015 function calls (3897189 primitive calls) in 4.995 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1086 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.131    0.131    4.996    4.996 /var/tmp/ipykernel_3248/742427061.py:47(mean_of_complicated_arithmetic_operation)
#        18    0.000    0.000    2.654    0.147 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.652    0.147 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#       195    0.002    0.000    2.457    0.013 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       195    0.002    0.000    2.453    0.013 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       195    0.000    0.000    2.443    0.013 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       195    0.001    0.000    2.442    0.013 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       195    0.001    0.000    2.441    0.013 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       780    2.439    0.003    2.439    0.003 {method 'acquire' of '_thread.lock' objects}
#         5    0.000    0.000    2.153    0.431 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       969    0.025    0.000    2.000    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       969    0.013    0.000    1.852    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       133    0.001    0.000    1.462    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       113    0.001    0.000    1.288    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/partition.py:56(get)
#       969    0.010    0.000    1.110    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#
#
# groupby statistics took: 0.3697 seconds
#          237515 function calls (230856 primitive calls) in 0.370 seconds
#
#    Ordered by: cumulative time
#    List reduced from 697 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.370    0.370 /var/tmp/ipykernel_3248/742427061.py:57(groupby_statistics)
#         1    0.000    0.000    0.368    0.368 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:442(aggregate)
#         1    0.000    0.000    0.368    0.368 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:1014(_apply_agg_function)
#         1    0.000    0.000    0.368    0.368 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2606(groupby_agg)
#         1    0.000    0.000    0.368    0.368 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1810(broadcast_apply_full_axis)
#         7    0.000    0.000    0.242    0.035 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.242    0.035 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.242    0.035 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.242    0.035 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.241    0.034 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        28    0.241    0.009    0.241    0.009 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.224    0.224 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1875(<listcomp>)
#         2    0.000    0.000    0.224    0.112 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:291(_compute_axis_labels)
#         2    0.000    0.000    0.224    0.112 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/partition_manager.py:40(get_indices)
#         4    0.000    0.000    0.196    0.049 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2093(gather)
#
#
# join count took: 0.7952 seconds
#          498085 function calls (483149 primitive calls) in 0.795 seconds
#
#    Ordered by: cumulative time
#    List reduced from 807 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.795    0.795 /var/tmp/ipykernel_3248/742427061.py:69(join_count)
#         1    0.000    0.000    0.794    0.794 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.794    0.794 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.789    0.789 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.789    0.789 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.683    0.683 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#         8    0.000    0.000    0.304    0.038 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         8    0.000    0.000    0.304    0.038 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         8    0.000    0.000    0.303    0.038 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         8    0.000    0.000    0.303    0.038 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         8    0.000    0.000    0.303    0.038 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        32    0.303    0.009    0.303    0.009 {method 'acquire' of '_thread.lock' objects}
#       124    0.004    0.000    0.257    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       124    0.001    0.000    0.241    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.237    0.237 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1930(get_axis_lengths)
#
#
# join took: 0.7914 seconds
#          432784 function calls (420814 primitive calls) in 0.791 seconds
#
#    Ordered by: cumulative time
#    List reduced from 795 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.791    0.791 /var/tmp/ipykernel_3248/742427061.py:72(join_data)
#         1    0.000    0.000    0.791    0.791 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.791    0.791 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.786    0.786 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.786    0.786 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.689    0.689 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#         8    0.000    0.000    0.302    0.038 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         8    0.000    0.000    0.302    0.038 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         8    0.000    0.000    0.301    0.038 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         8    0.000    0.000    0.301    0.038 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         8    0.000    0.000    0.301    0.038 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        32    0.301    0.009    0.301    0.009 {method 'acquire' of '_thread.lock' objects}
#       112    0.004    0.000    0.259    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#         1    0.000    0.000    0.243    0.243 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1930(get_axis_lengths)
#         1    0.000    0.000    0.243    0.243 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1933(<listcomp>)
# 0.7913720590000253

# %%
# Concatenate all DataFrames
df_profile_all = pd.concat(modin_profile_data, ignore_index=True)

# %% [markdown]
# **NOTE:**
#
# Instead of generating plots to visualize the profiling results, we opted to use the print function, as rendering multiple plots made the notebook too heavy and unresponsive when running in Google Cloud Platform (GCP).

# %% [markdown]
# In this way, the print_profile_per_task function provides a textual summary of the slowest internal functions (based on profiling) for each benchmarked operation, directly printed to the console instead of generating visual plots.
#
# The printed output includes:
#
# - A separate section for each benchmarked operation;
# - For each operation, the top N internal functions (based on profiling metrics) are listed in descending order of execution time.
# - The two available profiling metrics are:
#   - 'percall': Average time per individual call to the function (in seconds).
#
#   - 'cumtime': Total cumulative time spent in the function, including all nested calls.
#
# - For each listed function, the name, file, and line number are shown alongside the corresponding metric value.
#
# This function is especially useful when working in resource-constrained environments like Google Cloud Platform (GCP), where generating heavy visual plots can make notebooks sluggish or unusable. Instead, print_profile_per_task provides a lightweight and effective way to analyze performance bottlenecks.

# %%
def print_profile_per_task(profile_data_list, metric='percall', top_n=10):
    """
    Prints the top slowest functions (by percall or cumtime) for each benchmark task.
    
    Parameters:
    - profile_data_list: list of DataFrames (one per benchmark task), each containing profiling data
    - metric: the metric to sort by ('percall' or 'cumtime')
    - top_n: number of slowest functions to display per task
    """
     
    for df in profile_data_list:
        task_name = df['task'].iloc[0]  # todas as linhas têm o mesmo 'task'
        df_sorted = df.sort_values(by=metric, ascending=False).head(top_n)

        print(f"\n{'='*50}")
        print(f"Tarefa: {task_name}")
        print(f"Top {top_n} funções por {metric}:\n")
        print(df_sorted[['function', metric]].to_string(index=False))

# %%
print_profile_per_task(modin_profile_data, metric='percall', top_n=25)
# Out:
# ==================================================
# Tarefa: read file
# Top 25 funções por percall:
#
#                                                                     function  percall
#                           ~:0 (<method 'acquire' of '_thread.lock' objects>) 1.063840
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.002977
#               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.001976
#                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001676
#                               ~:0 (<method 'match' of 're.Pattern' objects>) 0.001291
#         ~:0 (<method 'finish' of 'pyarrow._dataset.DatasetFactory' objects>) 0.001214
#                                           ~:0 (<built-in method posix.stat>) 0.001191
#                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001040
#                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.000852
#                                       ~:0 (<method 'get' of 'dict' objects>) 0.000608
#                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:464 (put) 0.000594
#                      /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.000592
#                                     ~:0 (<method 'encode' of 'str' objects>) 0.000584
#                 /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.000543
#               /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000540
#                /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000524
#                                          ~:0 (<built-in method builtins.id>) 0.000424
#                              ~:0 (<method 'write' of '_io.BytesIO' objects>) 0.000414
#               /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.000360
#              /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000358
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/base.py:846 (tokenize) 0.000350
#           /opt/conda/envs/cdle/lib/python3.7/pickle.py:865 (_batch_setitems) 0.000334
#                                    ~:0 (<method 'replace' of 'str' objects>) 0.000322
#               /opt/conda/envs/cdle/lib/python3.7/pickle.py:567 (save_reduce) 0.000317
#                                     ~:0 (<built-in method builtins.getattr>) 0.000301
#
# ==================================================
# Tarefa: count
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000004
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000003
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023 (__len__) 0.000003
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000003
#                                                                       /var/tmp/ipykernel_3248/742427061.py:4 (count) 0.000002
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000002
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000000
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806 (__len__) 0.000000
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ==================================================
# Tarefa: count index length
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                                                          /var/tmp/ipykernel_3248/742427061.py:7 (count_index_length) 0.000002
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000002
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000001
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000001
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000001
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000001
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000000
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806 (__len__) 0.000000
#
# ==================================================
# Tarefa: mean
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.059205
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.009916
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.005985
#                                                                      ~:0 (<built-in method posix.stat>) 0.004470
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.003621
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.002846
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002574
#                                                                   ~:0 (<built-in method posix.urandom>) 0.002342
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001976
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.001960
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.001475
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001442
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001271
#                                                                                    <string>:1 (__new__) 0.001107
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001069
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.000985
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000867
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000867
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000848
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.000762
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000730
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000730
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.000690
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.000615
#                                                                    ~:0 (<built-in method builtins.len>) 0.000532
#
# ==================================================
# Tarefa: standard deviation
# Top 25 funções por percall:
#
#                                                                                        function  percall
#                                              ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.046148
#                                  /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.009751
#                                                  ~:0 (<method 'match' of 're.Pattern' objects>) 0.005582
#                                                              ~:0 (<built-in method posix.stat>) 0.004840
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.004168
#                                         /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.003009
#                                    /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002535
#                                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.002224
#                                  /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.001932
#                                   /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001426
#                                                           ~:0 (<built-in method posix.urandom>) 0.001423
#                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001225
#                                       /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001210
#                                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.001180
# /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840 (_graph_to_futures) 0.001163
#                                                                            <string>:1 (__new__) 0.001102
#                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000886
#                                          /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000839
#                                          /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000834
#                                               ~:0 (<method 'send' of '_socket.socket' objects>) 0.000824
#                                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000790
#                                                          ~:0 (<method 'get' of 'dict' objects>) 0.000745
#                                                     ~:0 (<built-in method builtins.isinstance>) 0.000721
#                                ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.000705
#                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000691
#
# ==================================================
# Tarefa: mean of columns addition
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.204573
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.048159
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.029433
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.019976
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.014817
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012494
#                                                                      ~:0 (<built-in method posix.stat>) 0.011123
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010403
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009566
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.006869
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006213
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005812
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005706
#                                                                                    <string>:1 (__new__) 0.005458
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.004955
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004446
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004368
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.004026
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003862
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003753
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003725
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.003642
#                                                                   ~:0 (<built-in method posix.urandom>) 0.003547
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003208
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002953
#
# ==================================================
# Tarefa: addition of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.132763
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.038630
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.023398
#                                                                      ~:0 (<built-in method posix.stat>) 0.020152
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.016997
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.011705
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.009982
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008864
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007665
#                                                                   ~:0 (<built-in method posix.urandom>) 0.006111
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005686
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005012
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004963
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004958
#                                                                                    <string>:1 (__new__) 0.004386
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.004162
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003993
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003605
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003195
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003137
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003069
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.002839
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.002663
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002577
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002374
#
# ==================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.207847
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.047106
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.028423
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.019287
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.014373
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012392
#                                                                      ~:0 (<built-in method posix.stat>) 0.010819
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010231
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009244
#                                                                   ~:0 (<built-in method posix.urandom>) 0.008020
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.006928
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.005864
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005751
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005643
#                                                                                    <string>:1 (__new__) 0.005404
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004476
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004471
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.004255
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003809
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003747
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.003567
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003564
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003224
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002961
#                                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.002593
#
# ==================================================
# Tarefa: multiplication of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.168547
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.037407
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.022919
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.016770
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.011568
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010135
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008884
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007398
#                                                                      ~:0 (<built-in method posix.stat>) 0.006550
#                                                                   ~:0 (<built-in method posix.urandom>) 0.006389
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005483
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.005078
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004905
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004826
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004632
#                                                                                    <string>:1 (__new__) 0.004264
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003878
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003615
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003191
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003143
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003100
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.002863
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002697
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002406
#                                                                     ~:0 (<built-in method builtins.id>) 0.002250
#
# ==================================================
# Tarefa: value counts
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.252441
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.045712
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.026299
#                                                                      ~:0 (<built-in method posix.stat>) 0.017866
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.016957
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.014244
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012379
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.009088
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009088
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.006715
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.005847
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.005513
#                                                                                    <string>:1 (__new__) 0.005278
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005260
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004968
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.004837
#                                                                   ~:0 (<built-in method posix.urandom>) 0.004455
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004338
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003837
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003536
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003483
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.003482
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003171
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003144
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002728
#
# ==================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                       function  percall
#                                             ~:0 (<method 'acquire' of '_thread.lock' objects>) 2.342235
#                                 /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.293668
#                                                 ~:0 (<method 'match' of 're.Pattern' objects>) 0.177926
#                     /var/tmp/ipykernel_3248/742427061.py:36 (complicated_arithmetic_operation) 0.132552
#                                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.110833
#                                        /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.090363
#                                   /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.078997
#                                                             ~:0 (<built-in method posix.stat>) 0.075834
#                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.060074
#                                 /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.058422
#                  ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.057689
#                                               ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.053013
#                                                          ~:0 (<built-in method posix.urandom>) 0.043486
#                                  /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.043423
#                                            ~:0 (<method 'flatten' of 'numpy.ndarray' objects>) 0.043204
#                                      /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.037129
#                                              ~:0 (<method 'send' of '_socket.socket' objects>) 0.036951
#                                    /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.034176
#                                                                           <string>:1 (__new__) 0.034028
#                                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.032352
# /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/shape_base.py:873 (_block_slicing) 0.031021
#                                         /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.027459
#                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.025116
#                                                    ~:0 (<built-in method builtins.isinstance>) 0.024751
#                                         /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.023828
#
# ==================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                       function  percall
#                                             ~:0 (<method 'acquire' of '_thread.lock' objects>) 2.438982
#                                 /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.306416
#                                                 ~:0 (<method 'match' of 're.Pattern' objects>) 0.184479
#             /var/tmp/ipykernel_3248/742427061.py:47 (mean_of_complicated_arithmetic_operation) 0.130866
#                                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.115873
#                                        /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.093848
#                                   /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.082209
#                                                             ~:0 (<built-in method posix.stat>) 0.079414
#                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.062578
#                                 /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.061641
#                  ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.059610
#                                                          ~:0 (<built-in method posix.urandom>) 0.047379
#                                  /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.044520
#                                               ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.042601
#                                            ~:0 (<method 'flatten' of 'numpy.ndarray' objects>) 0.040312
#                                      /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.038868
#                                    /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.035783
#                                                                           <string>:1 (__new__) 0.035360
#                                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.034017
#                                              ~:0 (<method 'send' of '_socket.socket' objects>) 0.031227
# /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/shape_base.py:873 (_block_slicing) 0.030965
#                                         /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.030066
#                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.025980
#                                                    ~:0 (<built-in method builtins.isinstance>) 0.025493
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.024764
#
# ==================================================
# Tarefa: groupby statistics
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.241401
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.019330
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.011384
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.006828
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.005782
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.005116
#                                                                      ~:0 (<built-in method posix.stat>) 0.004551
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.003982
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.003756
#                                                                   ~:0 (<built-in method posix.urandom>) 0.003201
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.002821
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.002485
#                                                                                    <string>:1 (__new__) 0.002197
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.002163
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.002046
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.001789
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.001592
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.001515
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.001498
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.001416
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.001357
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.001326
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.001318
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.001166
#                                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.001052
#
# ==================================================
# Tarefa: join count
# Top 25 funções por percall:
#
#                                                                                                    function  percall
#                                                          ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.303354
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.065323
#                                                          ~:0 (<method 'astype' of 'numpy.ndarray' objects>) 0.054377
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.043512
#                                              /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.040243
#                                                                        ~:0 (<pandas._libs.lib.infer_dtype>) 0.031127
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:198 (join) 0.025083
#                                                              ~:0 (<method 'match' of 're.Pattern' objects>) 0.024061
#                                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.015368
#                                                     /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012079
#                                                /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010560
#                                                                          ~:0 (<built-in method posix.stat>) 0.008379
#                                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008128
#                                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007860
#                                               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005875
#                                                   /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.005104
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004634
#                                                    /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004577
#                                                                                        <string>:1 (__new__) 0.004550
#                                                                       ~:0 (<built-in method posix.urandom>) 0.004492
#                                                           ~:0 (<method 'send' of '_socket.socket' objects>) 0.003970
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003650
#                                                      /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003611
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003498
#                                                      /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003205
#
# ==================================================
# Tarefa: join
# Top 25 funções por percall:
#
#                                                                                                    function  percall
#                                                          ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.301062
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.063685
#                                                          ~:0 (<method 'astype' of 'numpy.ndarray' objects>) 0.054665
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.043412
#                                              /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.037550
#                                                                        ~:0 (<pandas._libs.lib.infer_dtype>) 0.031406
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:198 (join) 0.022995
#                                                              ~:0 (<method 'match' of 're.Pattern' objects>) 0.022396
#                                                                          ~:0 (<built-in method posix.stat>) 0.014360
#                                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.013529
#                                                     /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.011282
#                                                /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010135
#                                                                       ~:0 (<built-in method posix.urandom>) 0.008208
#                                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.007455
#                                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007116
#                                               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005401
#                                                           ~:0 (<method 'send' of '_socket.socket' objects>) 0.004803
#                                                   /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004631
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004286
#                                                                                        <string>:1 (__new__) 0.004073
#                                                    /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.003876
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003770
#                                                      /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003519
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003073
#                                            ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.002858

# %% [markdown]
# **Operations with filtering**

# %% [markdown]
# The **filtered benchmarks** focus on evaluating performance after applying a data filtering operation.
#
# The dataset is filtered to include only rows where the Tip_Amt is between 1 and 5 (inclusive), simulating a common preprocessing step.
#
# This filtered DataFrame is then passed through the same benchmarking pipeline as before, testing various operations like count, mean, groupby, and joins.
#
# This allows us to compare the performance of Modin on both raw and pre-filtered data, which is often more representative of real-world data workflows.

# %%
expr_filter = 'Tip_Amt >= 1 and Tip_Amt <= 5'
filtered = modin_data.query(expr_filter)

if not isinstance(filtered, (pd.DataFrame, md.DataFrame)):
    filtered = md.DataFrame(filtered) if isinstance(data_filtered, md.DataFrame) else pd.DataFrame(filtered)

modin_filtered = filtered

# %%
benchmark(read_file_parquet, df=None, benchmarks=modin_benchmarks_filtered, name='read file')
benchmark(count, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='count')
benchmark(count_index_length, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='count index length')
benchmark(mean, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='mean')
benchmark(standard_deviation, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='standard deviation')
benchmark(mean_of_sum, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='mean of columns addition')
benchmark(sum_columns, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='addition of columns')
benchmark(mean_of_product, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='mean of columns multiplication')
benchmark(product_columns, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='multiplication of columns')
benchmark(value_counts, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='value counts')
benchmark(complicated_arithmetic_operation, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='complex arithmetic ops')
benchmark(mean_of_complicated_arithmetic_operation, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='mean of complex arithmetic ops')
benchmark(groupby_statistics, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='groupby statistics')
benchmark(join_count, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='join count', other=other)
benchmark(join_data, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='join', other=other)
# Out:
# read file took: 1.071508 seconds
# count took: 0.000017 seconds
# count index length took: 0.000005 seconds
# mean took: 0.096863 seconds
# standard deviation took: 0.091935 seconds
# mean of columns addition took: 0.426919 seconds
# addition of columns took: 0.305941 seconds
# mean of columns multiplication took: 0.409634 seconds
# multiplication of columns took: 0.331951 seconds
# value counts took: 0.597510 seconds
# complex arithmetic ops took: 3.672276 seconds
# mean of complex arithmetic ops took: 3.618664 seconds
# groupby statistics took: 0.250453 seconds
# join count took: 0.437638 seconds
# join took: 0.335061 seconds
# 0.33506074999996827

# %% [markdown]
# **Save results**

# %%
modin_res_filtered = get_results(modin_benchmarks_filtered).drop_duplicates(subset='task').set_index('task')
print(modin_res_filtered)
# Out:
#                                 duration
# task
# read file                       1.071508
# count                           0.000017
# count index length              0.000005
# mean                            0.096863
# standard deviation              0.091935
# mean of columns addition        0.426919
# addition of columns             0.305941
# mean of columns multiplication  0.409634
# multiplication of columns       0.331951
# value counts                    0.597510
# complex arithmetic ops          3.672276
# mean of complex arithmetic ops  3.618664
# groupby statistics              0.250453
# join count                      0.437638
# join                            0.335061

# %%
# Guardar resultados simples em Parquet
filename_filter = 'Results_Modin_M/modin_filtered_local_medium'
modin_res_filtered.to_parquet(filename_filter)
print(f'O arquivo Parquet foi salvo em {filename_filter}.')
# Out:
# O arquivo Parquet foi salvo em Results_Modin_M/modin_filtered_local_medium.

# %% [markdown]
# **Operations with filtering using cProfile**
#
# The filtered cProfile benchmarks collect detailed performance insights for each filtered operation using the cProfile module.
#
# - Each operation (e.g., count, mean, groupby) is executed on the previously filtered dataset, and function-level profiling data is collected.
#
# - The profiling results are stored in a list of DataFrames, one per benchmarked task, capturing execution time per function call.
#
# - Once again, since graphical profiling plots were too resource-intensive for GCP notebooks, the top 25 slowest functions per operation are printed to screen using print_profile_per_task, based on average time per call (percall).

# %%
modin_benchmarks_filtered_cprofile = {'duration': [], 'task': []}
modin_filtered_profile_data = []

# %%
# Execute benchmarks with cProfile
benchmark_cprofile(read_file_parquet, df=None, benchmarks=modin_benchmarks_filtered_cprofile, name='read file', profile_data=modin_filtered_profile_data)
benchmark_cprofile(count, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='count', profile_data=modin_filtered_profile_data)
benchmark_cprofile(count_index_length, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='count index length', profile_data=modin_filtered_profile_data)
benchmark_cprofile(mean, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='mean', profile_data=modin_filtered_profile_data)
benchmark_cprofile(standard_deviation, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='standard deviation', profile_data=modin_filtered_profile_data)
benchmark_cprofile(mean_of_sum, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='mean of columns addition', profile_data=modin_filtered_profile_data)
benchmark_cprofile(sum_columns, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='addition of columns', profile_data=modin_filtered_profile_data)
benchmark_cprofile(mean_of_product, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='mean of columns multiplication', profile_data=modin_filtered_profile_data)
benchmark_cprofile(product_columns, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='multiplication of columns', profile_data=modin_filtered_profile_data)
benchmark_cprofile(value_counts, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='value counts', profile_data=modin_filtered_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='complex arithmetic ops', profile_data=modin_filtered_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='mean of complex arithmetic ops', profile_data=modin_filtered_profile_data)
benchmark_cprofile(groupby_statistics, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='groupby statistics', profile_data=modin_filtered_profile_data)
benchmark_cprofile(join_count, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='join count', other=other, profile_data=modin_filtered_profile_data)
benchmark_cprofile(join_data, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='join', other=other, profile_data=modin_filtered_profile_data)
# Out:
# read file took: 1.0763 seconds
#          63819 function calls (60670 primitive calls) in 1.076 seconds
#
#    Ordered by: cumulative time
#    List reduced from 525 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.076    1.076 /var/tmp/ipykernel_3248/742427061.py:1(read_file_parquet)
#         1    0.000    0.000    1.076    1.076 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/io.py:203(read_parquet)
#         1    0.000    0.000    1.076    1.076 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/dispatcher.py:172(read_parquet)
#         1    0.000    0.000    1.076    1.076 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/factories.py:189(_read_parquet)
#         1    0.000    0.000    1.076    1.076 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/file_dispatcher.py:128(read)
#         1    0.000    0.000    1.076    1.076 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/parquet_dispatcher.py:31(_read)
#         1    0.000    0.000    1.074    1.074 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/column_store_dispatcher.py:197(build_query_compiler)
#         2    0.000    0.000    1.045    0.522 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/common/task_wrapper.py:48(materialize)
#         2    0.000    0.000    1.045    0.522 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2093(gather)
#         2    0.000    0.000    1.044    0.522 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    1.044    0.522 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    1.044    0.522 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    1.044    0.522 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    1.044    0.522 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    1.044    0.131    1.044    0.131 {method 'acquire' of '_thread.lock' objects}
#
#
# count took: 0.0000 seconds
#          14 function calls (11 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/742427061.py:4(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023(__len__)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          12 function calls (10 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/742427061.py:7(count_index_length)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#
#
# mean took: 0.1214 seconds
#          124637 function calls (121144 primitive calls) in 0.121 seconds
#
#    Ordered by: cumulative time
#    List reduced from 792 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.121    0.121 /var/tmp/ipykernel_3248/742427061.py:10(mean)
#         1    0.000    0.000    0.115    0.115 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1724(mean)
#         1    0.000    0.000    0.115    0.115 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.105    0.105 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:721(mean)
#         1    0.000    0.000    0.105    0.105 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/map_reduce.py:43(caller)
#         1    0.000    0.000    0.104    0.104 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1256(map_reduce)
#        33    0.001    0.000    0.068    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        33    0.000    0.000    0.065    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.059    0.059 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.059    0.059 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         3    0.000    0.000    0.049    0.016 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         3    0.000    0.000    0.048    0.016 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         3    0.000    0.000    0.048    0.016 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         3    0.000    0.000    0.048    0.016 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         3    0.000    0.000    0.048    0.016 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# standard deviation took: 0.1281 seconds
#          134533 function calls (130566 primitive calls) in 0.128 seconds
#
#    Ordered by: cumulative time
#    List reduced from 786 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.128    0.128 /var/tmp/ipykernel_3248/742427061.py:13(standard_deviation)
#         1    0.000    0.000    0.121    0.121 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2448(std)
#         1    0.000    0.000    0.121    0.121 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.085    0.085 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/reduction.py:42(caller)
#         1    0.000    0.000    0.085    0.085 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1234(fold_reduce)
#         1    0.000    0.000    0.084    0.084 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.084    0.084 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#        33    0.001    0.000    0.072    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        33    0.000    0.000    0.064    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.051    0.026 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    0.051    0.026 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    0.051    0.025 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    0.051    0.025 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    0.051    0.025 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    0.051    0.006    0.051    0.006 {method 'acquire' of '_thread.lock' objects}
#
#
# mean of columns addition took: 0.5369 seconds
#          631675 function calls (612258 primitive calls) in 0.537 seconds
#
#    Ordered by: cumulative time
#    List reduced from 867 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.537    0.537 /var/tmp/ipykernel_3248/742427061.py:16(mean_of_sum)
#         1    0.000    0.000    0.416    0.416 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.416    0.416 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.415    0.415 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.415    0.415 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.415    0.415 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.414    0.414 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       165    0.003    0.000    0.323    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       161    0.002    0.000    0.305    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#        10    0.000    0.000    0.199    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.199    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         1    0.000    0.000    0.199    0.199 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#        10    0.000    0.000    0.198    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.198    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.198    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# addition of columns took: 0.4201 seconds
#          526552 function calls (509676 primitive calls) in 0.420 seconds
#
#    Ordered by: cumulative time
#    List reduced from 594 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.420    0.420 /var/tmp/ipykernel_3248/742427061.py:19(sum_columns)
#         1    0.000    0.000    0.413    0.413 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.412    0.412 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.410    0.410 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       136    0.002    0.000    0.268    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       132    0.002    0.000    0.251    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.204    0.204 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#       132    0.001    0.000    0.144    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       132    0.000    0.000    0.141    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#       132    0.001    0.000    0.141    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:946(getsourcelines)
#         7    0.000    0.000    0.136    0.019 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.136    0.019 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#
#
# mean of columns multiplication took: 0.5337 seconds
#          631675 function calls (612258 primitive calls) in 0.534 seconds
#
#    Ordered by: cumulative time
#    List reduced from 867 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.534    0.534 /var/tmp/ipykernel_3248/742427061.py:24(mean_of_product)
#         1    0.000    0.000    0.403    0.403 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.403    0.403 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.401    0.401 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.401    0.401 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.401    0.401 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.400    0.400 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       165    0.003    0.000    0.320    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       161    0.002    0.000    0.299    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.203    0.203 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#        10    0.000    0.000    0.195    0.019 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.194    0.019 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        10    0.000    0.000    0.194    0.019 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.194    0.019 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.194    0.019 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# multiplication of columns took: 0.4194 seconds
#          526552 function calls (509676 primitive calls) in 0.419 seconds
#
#    Ordered by: cumulative time
#    List reduced from 594 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.419    0.419 /var/tmp/ipykernel_3248/742427061.py:27(product_columns)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.409    0.409 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.409    0.409 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.409    0.409 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.408    0.408 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       136    0.003    0.000    0.264    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       132    0.002    0.000    0.248    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.203    0.203 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#         7    0.000    0.000    0.143    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.143    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.142    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.142    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.142    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# value counts took: 0.7140 seconds
#          712560 function calls (692526 primitive calls) in 0.714 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1080 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.714    0.714 /var/tmp/ipykernel_3248/742427061.py:32(value_counts)
#         1    0.000    0.000    0.708    0.708 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1974(value_counts)
#         1    0.000    0.000    0.707    0.707 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2888(value_counts)
#         1    0.000    0.000    0.442    0.442 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:581(size)
#         1    0.000    0.000    0.408    0.408 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:913(_wrap_aggregation)
#       172    0.003    0.000    0.355    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        19    0.000    0.000    0.327    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        19    0.000    0.000    0.327    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        19    0.000    0.000    0.326    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        19    0.000    0.000    0.326    0.017 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        19    0.000    0.000    0.326    0.017 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        76    0.325    0.004    0.325    0.004 {method 'acquire' of '_thread.lock' objects}
#       172    0.003    0.000    0.325    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.287    0.287 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2495(groupby_size)
#         1    0.000    0.000    0.287    0.287 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2518(_groupby_dict_reduce)
#
#
# complex arithmetic ops took: 4.5463 seconds
#          3922588 function calls (3808201 primitive calls) in 4.545 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1045 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.034    0.034    4.546    4.546 /var/tmp/ipykernel_3248/742427061.py:36(complicated_arithmetic_operation)
#        18    0.000    0.000    2.789    0.155 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.787    0.155 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#       192    0.002    0.000    2.270    0.012 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       192    0.002    0.000    2.267    0.012 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         5    0.000    0.000    2.266    0.453 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       192    0.000    0.000    2.257    0.012 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       192    0.001    0.000    2.257    0.012 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       192    0.001    0.000    2.256    0.012 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       768    2.254    0.003    2.254    0.003 {method 'acquire' of '_thread.lock' objects}
#       956    0.021    0.000    1.959    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       944    0.012    0.000    1.811    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       132    0.001    0.000    1.263    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#         5    0.000    0.000    1.177    0.235 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#       944    0.009    0.000    1.084    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#
#
# mean of complex arithmetic ops took: 4.3562 seconds
#          4038019 function calls (3920259 primitive calls) in 4.355 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1069 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.034    0.034    4.355    4.355 /var/tmp/ipykernel_3248/742427061.py:47(mean_of_complicated_arithmetic_operation)
#        18    0.000    0.000    2.533    0.141 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.532    0.141 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#       195    0.002    0.000    2.045    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       195    0.002    0.000    2.042    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       195    0.000    0.000    2.032    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       195    0.001    0.000    2.031    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       195    0.001    0.000    2.030    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       780    2.028    0.003    2.028    0.003 {method 'acquire' of '_thread.lock' objects}
#         5    0.000    0.000    2.014    0.403 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       985    0.022    0.000    1.990    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       973    0.015    0.000    1.846    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       133    0.001    0.000    1.220    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       973    0.009    0.000    1.109    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       973    0.001    0.000    1.087    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#
#
# groupby statistics took: 0.2962 seconds
#          244664 function calls (237977 primitive calls) in 0.296 seconds
#
#    Ordered by: cumulative time
#    List reduced from 644 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.296    0.296 /var/tmp/ipykernel_3248/742427061.py:57(groupby_statistics)
#         1    0.000    0.000    0.290    0.290 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:442(aggregate)
#         1    0.000    0.000    0.290    0.290 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:1014(_apply_agg_function)
#         1    0.000    0.000    0.290    0.290 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2606(groupby_agg)
#         1    0.000    0.000    0.290    0.290 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1810(broadcast_apply_full_axis)
#         7    0.000    0.000    0.164    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.163    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.163    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.163    0.023 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.163    0.023 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        28    0.163    0.006    0.163    0.006 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.145    0.145 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1875(<listcomp>)
#         2    0.000    0.000    0.145    0.072 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:291(_compute_axis_labels)
#         2    0.000    0.000    0.145    0.072 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/partition_manager.py:40(get_indices)
#        63    0.002    0.000    0.126    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#
#
# join count took: 0.4444 seconds
#          496742 function calls (481806 primitive calls) in 0.444 seconds
#
#    Ordered by: cumulative time
#    List reduced from 801 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.444    0.444 /var/tmp/ipykernel_3248/742427061.py:69(join_count)
#         1    0.000    0.000    0.444    0.444 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.444    0.444 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.439    0.439 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.438    0.438 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.320    0.320 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#       124    0.001    0.000    0.261    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       124    0.002    0.000    0.240    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.227    0.114 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         2    0.000    0.000    0.227    0.114 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         2    0.000    0.000    0.169    0.084 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:443(<listcomp>)
#         5    0.000    0.000    0.169    0.034 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#         5    0.000    0.000    0.168    0.034 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:50(deploy_axis_func)
#         5    0.000    0.000    0.157    0.031 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:97(<listcomp>)
#       124    0.001    0.000    0.143    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#
#
# join took: 0.4553 seconds
#          431655 function calls (419685 primitive calls) in 0.455 seconds
#
#    Ordered by: cumulative time
#    List reduced from 790 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.455    0.455 /var/tmp/ipykernel_3248/742427061.py:72(join_data)
#         1    0.000    0.000    0.455    0.455 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.455    0.455 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.451    0.451 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.449    0.449 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.346    0.346 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#       112    0.002    0.000    0.216    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       112    0.001    0.000    0.201    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.184    0.092 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         2    0.000    0.000    0.184    0.092 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         8    0.000    0.000    0.169    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         8    0.000    0.000    0.169    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         8    0.000    0.000    0.169    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         8    0.000    0.000    0.168    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         8    0.000    0.000    0.168    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
# 0.45529051599999093

# %%
# Concatenate all results
df_filtered_profile_all = pd.concat(modin_filtered_profile_data, ignore_index=True)

# %%
print_profile_per_task(modin_filtered_profile_data, metric='percall', top_n=25)
# Out:
# ==================================================
# Tarefa: read file
# Top 25 funções por percall:
#
#                                                                     function  percall
#                           ~:0 (<method 'acquire' of '_thread.lock' objects>) 1.044267
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.002976
#               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.001999
#                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001587
#                               ~:0 (<method 'match' of 're.Pattern' objects>) 0.001393
#         ~:0 (<method 'finish' of 'pyarrow._dataset.DatasetFactory' objects>) 0.001153
#                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.000971
#                                           ~:0 (<built-in method posix.stat>) 0.000942
#                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.000936
#                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:464 (put) 0.000639
#                                     ~:0 (<method 'encode' of 'str' objects>) 0.000589
#                      /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.000586
#                                       ~:0 (<method 'get' of 'dict' objects>) 0.000561
#               /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000540
#                /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000538
#                 /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.000495
#                              ~:0 (<method 'write' of '_io.BytesIO' objects>) 0.000454
#              /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000380
#                                    ~:0 (<method 'replace' of 'str' objects>) 0.000375
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/base.py:846 (tokenize) 0.000364
#                                          ~:0 (<built-in method builtins.id>) 0.000361
#               /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.000359
#               /opt/conda/envs/cdle/lib/python3.7/pickle.py:567 (save_reduce) 0.000337
#           /opt/conda/envs/cdle/lib/python3.7/pickle.py:865 (_batch_setitems) 0.000336
#             /opt/conda/envs/cdle/lib/python3.7/pickle.py:289 (_getattribute) 0.000271
#
# ==================================================
# Tarefa: count
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000005
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000005
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023 (__len__) 0.000003
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000002
#                                                                       /var/tmp/ipykernel_3248/742427061.py:4 (count) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000001
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000001
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000000
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000000
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ==================================================
# Tarefa: count index length
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                                                          /var/tmp/ipykernel_3248/742427061.py:7 (count_index_length) 0.000003
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000003
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000003
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000001
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000001
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000001
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000000
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000000
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000000
#
# ==================================================
# Tarefa: mean
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.048258
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.010415
#                                                                      ~:0 (<built-in method posix.stat>) 0.006487
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.006243
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.003476
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.003044
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002646
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.002078
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001881
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001451
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001319
#                                                                                    <string>:1 (__new__) 0.001127
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001032
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.001013
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000984
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.000860
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000824
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.000801
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000801
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000778
#                                                                   ~:0 (<built-in method posix.urandom>) 0.000705
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.000695
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.000681
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000609
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.000565
#
# ==================================================
# Tarefa: standard deviation
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.050870
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.010318
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.005929
#                                                                      ~:0 (<built-in method posix.stat>) 0.005438
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.004092
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.003082
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002787
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.002114
#                                                                   ~:0 (<built-in method posix.urandom>) 0.002085
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.002021
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001493
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.001338
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001331
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.001198
#                                                                                    <string>:1 (__new__) 0.001189
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001176
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000959
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000829
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000826
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000825
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.000788
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.000780
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000767
#                                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000672
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.000660
#
# ==================================================
# Tarefa: mean of columns addition
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.197928
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.048674
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.028984
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.019241
#                                                                      ~:0 (<built-in method posix.stat>) 0.015934
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.014706
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012848
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010335
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009424
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.007089
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006102
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005875
#                                                                   ~:0 (<built-in method posix.urandom>) 0.005685
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005653
#                                                                                    <string>:1 (__new__) 0.005435
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004630
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004564
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003952
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003767
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003666
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.003648
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003445
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.003416
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003351
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003168
#
# ==================================================
# Tarefa: addition of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.135769
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.038912
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.023329
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.016806
#                                                                      ~:0 (<built-in method posix.stat>) 0.012762
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.011697
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010432
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008781
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007684
#                                                                   ~:0 (<built-in method posix.urandom>) 0.006551
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005751
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.005380
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004967
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004901
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004864
#                                                                                    <string>:1 (__new__) 0.004345
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003784
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003703
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003186
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003132
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003105
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.002954
#                                                        ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.002797
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002702
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002547
#
# ==================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por percall:
#
#                                                                             function  percall
#                                   ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.193710
#                       /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.048233
#                                       ~:0 (<method 'match' of 're.Pattern' objects>) 0.029305
#                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.019556
#                              /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.014794
#                         /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012738
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010289
#                       /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009703
#                                                   ~:0 (<built-in method posix.stat>) 0.008959
#                                                ~:0 (<built-in method posix.urandom>) 0.008813
#                        /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.007019
#                            /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006137
#                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005959
#                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005558
#                                                                 <string>:1 (__new__) 0.005363
#                                    ~:0 (<method 'send' of '_socket.socket' objects>) 0.004818
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004479
#                               /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004419
#                                     ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.003793
#                     ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.003787
#                               /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003786
#                                               ~:0 (<method 'get' of 'dict' objects>) 0.003744
#                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003741
# /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003485
#                                          ~:0 (<built-in method builtins.isinstance>) 0.003350
#
# ==================================================
# Tarefa: multiplication of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.142189
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.038531
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.024175
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.016747
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.011939
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010371
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008823
#                                                                      ~:0 (<built-in method posix.stat>) 0.008616
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007543
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005710
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004934
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004866
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004795
#                                                                   ~:0 (<built-in method posix.urandom>) 0.004692
#                                                                                    <string>:1 (__new__) 0.004415
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.003955
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003724
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003643
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003252
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003189
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003174
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.002882
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.002826
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002694
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002615
#
# ==================================================
# Tarefa: value counts
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.325371
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.056334
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.032045
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.019878
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.017300
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.015172
#                                                                      ~:0 (<built-in method posix.stat>) 0.013074
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.011191
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.011009
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.008249
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.007146
#                                                                   ~:0 (<built-in method posix.urandom>) 0.006556
#                                                                                    <string>:1 (__new__) 0.006433
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.006200
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005751
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.005271
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.005206
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.004539
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004325
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.004276
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.004257
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003860
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003703
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003433
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003128
#
# ==================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                  function  percall
#                                        ~:0 (<method 'acquire' of '_thread.lock' objects>) 2.253807
#                            /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.300981
#                                            ~:0 (<method 'match' of 're.Pattern' objects>) 0.177675
#                                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.111740
#                                   /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.091441
#                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.079982
#                                                        ~:0 (<built-in method posix.stat>) 0.079284
#                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.060224
#                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.059266
#                                                     ~:0 (<built-in method posix.urandom>) 0.050349
#                             /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.044577
#                                 /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.038280
#                               /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.034729
#                /var/tmp/ipykernel_3248/742427061.py:36 (complicated_arithmetic_operation) 0.034368
#                                                                      <string>:1 (__new__) 0.033723
#                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.032279
#                                         ~:0 (<method 'send' of '_socket.socket' objects>) 0.028476
#                                    /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.027775
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.025614
#                                               ~:0 (<built-in method builtins.isinstance>) 0.025520
# /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/numeric.py:2317 (array_equal) 0.025165
#                                    /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.024364
#                          ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.022786
#                                                    ~:0 (<method 'get' of 'dict' objects>) 0.021769
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.020922
#
# ==================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                  function  percall
#                                        ~:0 (<method 'acquire' of '_thread.lock' objects>) 2.028137
#                            /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.305319
#                                            ~:0 (<method 'match' of 're.Pattern' objects>) 0.180291
#                                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.114603
#                                   /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.092399
#                                                        ~:0 (<built-in method posix.stat>) 0.088940
#                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.081510
#                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.060735
#                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.060244
#                                                     ~:0 (<built-in method posix.urandom>) 0.046598
#                             /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.044277
#                                 /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.038135
#                               /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.035250
#                                                                      <string>:1 (__new__) 0.034667
#        /var/tmp/ipykernel_3248/742427061.py:47 (mean_of_complicated_arithmetic_operation) 0.034025
#                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.033222
#                                    /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.028505
#                                         ~:0 (<method 'send' of '_socket.socket' objects>) 0.027893
#                                               ~:0 (<built-in method builtins.isinstance>) 0.026234
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.025897
#                                    /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.024740
#                          ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.023145
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.022151
#                                                    ~:0 (<method 'get' of 'dict' objects>) 0.021922
# /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/numeric.py:2317 (array_equal) 0.021724
#
# ==================================================
# Tarefa: groupby statistics
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.163007
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.020338
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.011875
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.006929
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.006116
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.005339
#                                                                      ~:0 (<built-in method posix.stat>) 0.004593
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.003902
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.003582
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.002977
#                                                                   ~:0 (<built-in method posix.urandom>) 0.002832
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.002511
#                                                                                    <string>:1 (__new__) 0.002332
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.002129
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.002101
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.002069
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.002028
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.001837
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.001634
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.001564
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.001484
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.001415
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.001363
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.001342
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.001206
#
# ==================================================
# Tarefa: join count
# Top 25 funções por percall:
#
#                                                                                                    function  percall
#                                                          ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.110180
#                                              /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039164
#                                                              ~:0 (<method 'match' of 're.Pattern' objects>) 0.023445
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.022100
#                                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.015744
#                                                                          ~:0 (<built-in method posix.stat>) 0.012282
#                                                          ~:0 (<method 'astype' of 'numpy.ndarray' objects>) 0.011890
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.011849
#                                                     /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.011562
#                                                /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010195
#                                                                       ~:0 (<built-in method posix.urandom>) 0.009959
#                                                                        ~:0 (<pandas._libs.lib.infer_dtype>) 0.008288
#                                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008247
#                                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007695
#                                                           ~:0 (<method 'send' of '_socket.socket' objects>) 0.006344
#                                               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005757
#                                                   /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004928
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004688
#                                                    /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004403
#                                                                                        <string>:1 (__new__) 0.004392
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:198 (join) 0.004305
#                                                      /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003526
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003444
#                                                      /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003179
#                                            ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.002906
#
# ==================================================
# Tarefa: join
# Top 25 funções por percall:
#
#                                                                                                    function  percall
#                                                          ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.168314
#                                              /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.033452
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.023092
#                                                              ~:0 (<method 'match' of 're.Pattern' objects>) 0.019955
#                                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.012647
#                                                          ~:0 (<method 'astype' of 'numpy.ndarray' objects>) 0.011536
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.011411
#                                                     /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.009966
#                                                /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.008890
#                                                                        ~:0 (<pandas._libs.lib.infer_dtype>) 0.008185
#                                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.006834
#                                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.006602
#                                                                          ~:0 (<built-in method posix.stat>) 0.006486
#                                                                       ~:0 (<built-in method posix.urandom>) 0.005138
#                                               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.004749
#                                                   /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004252
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:198 (join) 0.004173
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.003892
#                                                                                        <string>:1 (__new__) 0.003786
#                                                    /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.003675
#                                                      /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003132
#                                                           ~:0 (<method 'send' of '_socket.socket' objects>) 0.003083
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.002760
#                                                      /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002624
#                                            ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.002567

# %% [markdown]
# **Operations with cache**

# %% [markdown]
# In this section, the filtered Modin DataFrame was first converted to a Pandas DataFrame, then transformed into a Dask DataFrame with multiple partitions to leverage parallel processing and better memory management.
#
# The Dask DataFrame was persisted in memory to speed up repeated computations. Subsequently, a series of benchmark functions were executed on this cached data to measure performance across various operations.
#
# For join operations, the auxiliary dataset was also converted to Dask format to maintain consistency.
#
# Finally, the benchmark results were collected, deduplicated by task, saved to a Parquet file for future analysis, and printed.

# %%
# Convert Modin DataFrame to Pandas DataFrame
dask_df = modin_filtered._to_pandas()
print("Conversão para Pandas realizada com sucesso.")

# Convert Pandas DataFrame to Dask DataFrame with 10 partitions
dask_df = dd.from_pandas(dask_df, npartitions=10)

# Persist the Dask DataFrame in memory for faster access
dask_df = client.persist(dask_df)
modin_cache = dask_df
# Out:
# Conversão para Pandas realizada com sucesso.

# %%
# Run benchmarks on cached data
benchmark(read_file_parquet, df=None, benchmarks=modin_benchmarks_cache, name='read file')
benchmark(count, df=modin_cache, benchmarks=modin_benchmarks_cache, name='count')
benchmark(count_index_length, df=modin_cache, benchmarks=modin_benchmarks_cache, name='count index length')
benchmark(mean, df=modin_cache, benchmarks=modin_benchmarks_cache, name='mean')
benchmark(standard_deviation, df=modin_cache, benchmarks=modin_benchmarks_cache, name='standard deviation')
benchmark(mean_of_sum, df=modin_cache, benchmarks=modin_benchmarks_cache, name='mean of columns addition')
benchmark(sum_columns, df=modin_cache, benchmarks=modin_benchmarks_cache, name='addition of columns')
benchmark(mean_of_product, df=modin_cache, benchmarks=modin_benchmarks_cache, name='mean of columns multiplication')
benchmark(product_columns, df=modin_cache, benchmarks=modin_benchmarks_cache, name='multiplication of columns')
benchmark(value_counts, df=modin_cache, benchmarks=modin_benchmarks_cache, name='value counts')
benchmark(complicated_arithmetic_operation, df=modin_cache, benchmarks=modin_benchmarks_cache, name='complex arithmetic ops')
benchmark(groupby_statistics, df=modin_cache, benchmarks=modin_benchmarks_cache, name='groupby statistics')

# Prepare 'other' DataFrame for join operations, converting from Modin to Dask
other_dask = dd.from_pandas(other._to_pandas(), npartitions=10)  # ajusta npartitions conforme desejar

benchmark(join_count, df=modin_cache, benchmarks=modin_benchmarks_cache, name='join count', other=other_dask)
benchmark(join_data, df=modin_cache, benchmarks=modin_benchmarks_cache, name='join', other=other_dask)
# Out:
# read file took: 1.060289 seconds
# count took: 0.259545 seconds
# count index length took: 0.025296 seconds
# mean took: 0.003111 seconds
# standard deviation took: 0.003509 seconds
# mean of columns addition took: 0.002549 seconds
# addition of columns took: 0.000727 seconds
# mean of columns multiplication took: 0.002877 seconds
# multiplication of columns took: 0.000716 seconds
# value counts took: 0.000903 seconds
# complex arithmetic ops took: 0.009292 seconds
# groupby statistics took: 0.018042 seconds
# join count took: 0.214032 seconds
# join took: 0.012649 seconds
# 0.0126488309999786

# %%
# Retrieve benchmark results, drop duplicate tasks and set index to 'task'
modin_res_cache = get_results(modin_benchmarks_cache).drop_duplicates(subset='task').set_index('task')
print(modin_res_cache)
# Out:
#                                 duration
# task
# read file                       1.060289
# count                           0.259545
# count index length              0.025296
# mean                            0.003111
# standard deviation              0.003509
# mean of columns addition        0.002549
# addition of columns             0.000727
# mean of columns multiplication  0.002877
# multiplication of columns       0.000716
# value counts                    0.000903
# complex arithmetic ops          0.009292
# groupby statistics              0.018042
# join count                      0.214032
# join                            0.012649

# %%
# Save results to Parquet file
filename_cache = 'Results_Modin_M/modin_cache_local_medium'
modin_res_cache.to_parquet(filename_cache)
print(f'O arquivo Parquet foi salvo em {filename_cache}.')
# Out:
# O arquivo Parquet foi salvo em Results_Modin_M/modin_cache_local_medium.

# %% [markdown]
# **Cache with cprofile**
#
# In this section, performance profiling was conducted using cProfile for the previously cached Dask DataFrame (modin_cache). The goal was to capture fine-grained profiling data (function call durations and frequencies) across various common operations such as count, mean, groupby, and arithmetic operations. Each function was profiled individually using benchmark_cprofile, and the profiling data was stored in a list. At the end, all collected profiling results were concatenated into a single DataFrame and visualized using a custom print_profile_per_task function to highlight the top functions sorted by time per call (percall). Finally, the Dask client was restarted to clear memory and reset the environment.
#
# This approach allows deeper analysis of function-level performance bottlenecks and behavior when working with cached data using Dask after converting from Modin.

# %%
# === Benchmarks with cProfile for cached Modin data ===
modin_benchmarks_cache_cprofile = {'duration': [], 'task': []}
modin_cache_profile_data = []

# %%
benchmark_cprofile(read_file_parquet, df=None, benchmarks=modin_benchmarks_cache_cprofile, name='read file', profile_data=modin_cache_profile_data)
benchmark_cprofile(count, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='count', profile_data=modin_cache_profile_data)
benchmark_cprofile(count_index_length, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='count index length', profile_data=modin_cache_profile_data)
benchmark_cprofile(mean, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='mean', profile_data=modin_cache_profile_data)
benchmark_cprofile(standard_deviation, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='standard deviation', profile_data=modin_cache_profile_data)
benchmark_cprofile(mean_of_sum, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='mean of columns addition', profile_data=modin_cache_profile_data)
benchmark_cprofile(sum_columns, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='addition of columns', profile_data=modin_cache_profile_data)
benchmark_cprofile(mean_of_product, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='mean of columns multiplication', profile_data=modin_cache_profile_data)
benchmark_cprofile(product_columns, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='multiplication of columns', profile_data=modin_cache_profile_data)
benchmark_cprofile(value_counts, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='value counts', profile_data=modin_cache_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='complex arithmetic ops', profile_data=modin_cache_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='mean of complex arithmetic ops', profile_data=modin_cache_profile_data)
benchmark_cprofile(groupby_statistics, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='groupby statistics', profile_data=modin_cache_profile_data)
benchmark_cprofile(join_count, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='join count', other=other, profile_data=modin_cache_profile_data)
benchmark_cprofile(join_data, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='join', other=other, profile_data=modin_cache_profile_data)
# Out:
# read file took: 1.0722 seconds
#          63805 function calls (60657 primitive calls) in 1.072 seconds
#
#    Ordered by: cumulative time
#    List reduced from 526 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.072    1.072 /var/tmp/ipykernel_3248/742427061.py:1(read_file_parquet)
#         1    0.000    0.000    1.072    1.072 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/io.py:203(read_parquet)
#         1    0.000    0.000    1.072    1.072 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/dispatcher.py:172(read_parquet)
#         1    0.000    0.000    1.072    1.072 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/factories.py:189(_read_parquet)
#         1    0.000    0.000    1.072    1.072 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/file_dispatcher.py:128(read)
#         1    0.000    0.000    1.072    1.072 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/parquet_dispatcher.py:31(_read)
#         1    0.000    0.000    1.070    1.070 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/column_store_dispatcher.py:197(build_query_compiler)
#         2    0.000    0.000    1.040    0.520 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/common/task_wrapper.py:48(materialize)
#         2    0.000    0.000    1.039    0.520 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2093(gather)
#         2    0.000    0.000    1.039    0.520 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    1.039    0.520 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    1.039    0.520 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    1.039    0.520 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    1.039    0.520 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    1.039    0.130    1.039    0.130 {method 'acquire' of '_thread.lock' objects}
#
#
# count took: 0.0000 seconds
#          14 function calls (11 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/742427061.py:4(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023(__len__)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          12 function calls (10 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/742427061.py:7(count_index_length)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# mean took: 0.1281 seconds
#          124639 function calls (121146 primitive calls) in 0.128 seconds
#
#    Ordered by: cumulative time
#    List reduced from 793 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.128    0.128 /var/tmp/ipykernel_3248/742427061.py:10(mean)
#         1    0.000    0.000    0.119    0.119 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1724(mean)
#         1    0.000    0.000    0.119    0.119 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.106    0.106 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:721(mean)
#         1    0.000    0.000    0.106    0.106 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/map_reduce.py:43(caller)
#         1    0.000    0.000    0.106    0.106 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1256(map_reduce)
#        33    0.001    0.000    0.072    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        33    0.000    0.000    0.069    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.062    0.062 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.062    0.062 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         3    0.000    0.000    0.051    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         3    0.000    0.000    0.051    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         3    0.000    0.000    0.051    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         3    0.000    0.000    0.051    0.017 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         3    0.000    0.000    0.051    0.017 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# standard deviation took: 0.1275 seconds
#          134533 function calls (130566 primitive calls) in 0.127 seconds
#
#    Ordered by: cumulative time
#    List reduced from 786 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.127    0.127 /var/tmp/ipykernel_3248/742427061.py:13(standard_deviation)
#         1    0.000    0.000    0.121    0.121 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2448(std)
#         1    0.000    0.000    0.121    0.121 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.081    0.081 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/reduction.py:42(caller)
#         1    0.000    0.000    0.081    0.081 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1234(fold_reduce)
#         1    0.000    0.000    0.080    0.080 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.080    0.080 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#        33    0.001    0.000    0.069    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        33    0.000    0.000    0.063    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.053    0.027 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    0.053    0.027 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    0.053    0.026 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    0.053    0.026 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    0.053    0.026 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    0.053    0.007    0.053    0.007 {method 'acquire' of '_thread.lock' objects}
#
#
# mean of columns addition took: 0.5262 seconds
#          631677 function calls (612260 primitive calls) in 0.526 seconds
#
#    Ordered by: cumulative time
#    List reduced from 867 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.526    0.526 /var/tmp/ipykernel_3248/742427061.py:16(mean_of_sum)
#         1    0.000    0.000    0.402    0.402 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.402    0.402 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.401    0.401 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.401    0.401 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.401    0.401 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.400    0.400 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       165    0.003    0.000    0.324    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       161    0.003    0.000    0.305    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.208    0.208 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#        10    0.000    0.000    0.186    0.019 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.186    0.019 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        10    0.000    0.000    0.185    0.019 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.185    0.019 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.185    0.019 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# addition of columns took: 0.4143 seconds
#          526554 function calls (509678 primitive calls) in 0.414 seconds
#
#    Ordered by: cumulative time
#    List reduced from 594 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.414    0.414 /var/tmp/ipykernel_3248/742427061.py:19(sum_columns)
#         1    0.000    0.000    0.407    0.407 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.407    0.407 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.406    0.406 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.406    0.406 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.405    0.405 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.404    0.404 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       136    0.002    0.000    0.259    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       132    0.002    0.000    0.244    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.200    0.200 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#         7    0.000    0.000    0.141    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.141    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.141    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.141    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.141    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# mean of columns multiplication took: 0.5357 seconds
#          631675 function calls (612258 primitive calls) in 0.536 seconds
#
#    Ordered by: cumulative time
#    List reduced from 867 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.536    0.536 /var/tmp/ipykernel_3248/742427061.py:24(mean_of_product)
#         1    0.000    0.000    0.408    0.408 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.408    0.408 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.407    0.407 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.407    0.407 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.407    0.407 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.406    0.406 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       165    0.003    0.000    0.316    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       161    0.002    0.000    0.301    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#        10    0.000    0.000    0.201    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.201    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        10    0.000    0.000    0.200    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.200    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.200    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        40    0.200    0.005    0.200    0.005 {method 'acquire' of '_thread.lock' objects}
#
#
# multiplication of columns took: 0.4172 seconds
#          526554 function calls (509678 primitive calls) in 0.417 seconds
#
#    Ordered by: cumulative time
#    List reduced from 594 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.417    0.417 /var/tmp/ipykernel_3248/742427061.py:27(product_columns)
#         1    0.000    0.000    0.410    0.410 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.409    0.409 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.408    0.408 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.408    0.408 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.408    0.408 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.407    0.407 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       136    0.003    0.000    0.266    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       132    0.002    0.000    0.248    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.207    0.207 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#       132    0.001    0.000    0.141    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#         7    0.000    0.000    0.140    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.140    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.139    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.139    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#
#
# value counts took: 0.7280 seconds
#          712562 function calls (692528 primitive calls) in 0.728 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1080 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.728    0.728 /var/tmp/ipykernel_3248/742427061.py:32(value_counts)
#         1    0.000    0.000    0.717    0.717 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1974(value_counts)
#         1    0.000    0.000    0.717    0.717 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2888(value_counts)
#         1    0.000    0.000    0.443    0.443 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:581(size)
#         1    0.000    0.000    0.407    0.407 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:913(_wrap_aggregation)
#       172    0.003    0.000    0.366    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       172    0.002    0.000    0.335    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#        19    0.000    0.000    0.332    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        19    0.000    0.000    0.331    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        19    0.000    0.000    0.330    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        19    0.000    0.000    0.330    0.017 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        19    0.000    0.000    0.330    0.017 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        76    0.330    0.004    0.330    0.004 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.284    0.284 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2495(groupby_size)
#         1    0.000    0.000    0.283    0.283 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2518(_groupby_dict_reduce)
#
#
# complex arithmetic ops took: 4.3579 seconds
#          3922602 function calls (3808215 primitive calls) in 4.356 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1045 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.034    0.034    4.357    4.357 /var/tmp/ipykernel_3248/742427061.py:36(complicated_arithmetic_operation)
#        18    0.000    0.000    2.636    0.146 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.634    0.146 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         5    0.000    0.000    2.136    0.427 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       192    0.002    0.000    2.123    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       192    0.002    0.000    2.120    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       192    0.000    0.000    2.110    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       192    0.001    0.000    2.109    0.011 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       192    0.001    0.000    2.108    0.011 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       768    2.106    0.003    2.106    0.003 {method 'acquire' of '_thread.lock' objects}
#       956    0.020    0.000    1.913    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       944    0.013    0.000    1.778    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       132    0.001    0.000    1.347    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       944    0.009    0.000    1.063    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       112    0.001    0.000    1.056    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/partition.py:56(get)
#
#
# mean of complex arithmetic ops took: 4.5858 seconds
#          4038019 function calls (3920259 primitive calls) in 4.584 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1069 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.033    0.033    4.585    4.585 /var/tmp/ipykernel_3248/742427061.py:47(mean_of_complicated_arithmetic_operation)
#        18    0.000    0.000    2.587    0.144 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.585    0.144 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#       195    0.003    0.000    2.210    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       195    0.002    0.000    2.206    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       195    0.000    0.000    2.195    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       195    0.001    0.000    2.194    0.011 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       195    0.001    0.000    2.193    0.011 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       780    2.191    0.003    2.191    0.003 {method 'acquire' of '_thread.lock' objects}
#         5    0.000    0.000    2.059    0.412 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       985    0.027    0.000    2.035    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       973    0.015    0.000    1.869    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       133    0.001    0.000    1.283    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       113    0.001    0.000    1.127    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/partition.py:56(get)
#       973    0.010    0.000    1.103    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#
#
# groupby statistics took: 0.2994 seconds
#          244666 function calls (237979 primitive calls) in 0.299 seconds
#
#    Ordered by: cumulative time
#    List reduced from 644 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.299    0.299 /var/tmp/ipykernel_3248/742427061.py:57(groupby_statistics)
#         1    0.000    0.000    0.293    0.293 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:442(aggregate)
#         1    0.000    0.000    0.293    0.293 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:1014(_apply_agg_function)
#         1    0.000    0.000    0.293    0.293 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2606(groupby_agg)
#         1    0.000    0.000    0.293    0.293 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1810(broadcast_apply_full_axis)
#         7    0.000    0.000    0.164    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.164    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.164    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.164    0.023 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.164    0.023 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        28    0.164    0.006    0.164    0.006 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.140    0.140 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1875(<listcomp>)
#         2    0.000    0.000    0.140    0.070 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:291(_compute_axis_labels)
#         2    0.000    0.000    0.140    0.070 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/partition_manager.py:40(get_indices)
#        63    0.001    0.000    0.129    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#
#
# join count took: 0.4726 seconds
#          496748 function calls (481812 primitive calls) in 0.473 seconds
#
#    Ordered by: cumulative time
#    List reduced from 802 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.473    0.473 /var/tmp/ipykernel_3248/742427061.py:69(join_count)
#         1    0.000    0.000    0.473    0.473 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.472    0.472 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.468    0.468 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.467    0.467 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.358    0.358 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#       124    0.002    0.000    0.257    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       124    0.002    0.000    0.240    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.224    0.112 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         2    0.000    0.000    0.224    0.112 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         2    0.000    0.000    0.165    0.083 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:443(<listcomp>)
#         5    0.000    0.000    0.165    0.033 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#         5    0.000    0.000    0.165    0.033 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:50(deploy_axis_func)
#         5    0.000    0.000    0.158    0.032 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:97(<listcomp>)
#       124    0.001    0.000    0.139    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#
#
# join took: 0.4144 seconds
#          431657 function calls (419687 primitive calls) in 0.414 seconds
#
#    Ordered by: cumulative time
#    List reduced from 790 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.414    0.414 /var/tmp/ipykernel_3248/742427061.py:72(join_data)
#         1    0.000    0.000    0.414    0.414 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.414    0.414 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.410    0.410 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.409    0.409 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.297    0.297 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#       112    0.002    0.000    0.245    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       112    0.001    0.000    0.229    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.210    0.105 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         2    0.000    0.000    0.210    0.105 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         2    0.000    0.000    0.183    0.092 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:443(<listcomp>)
#         5    0.000    0.000    0.183    0.037 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#         5    0.000    0.000    0.183    0.037 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:50(deploy_axis_func)
#         5    0.000    0.000    0.175    0.035 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:97(<listcomp>)
#       112    0.001    0.000    0.140    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
# 0.41437093100000766

# %%
# Concatenate all profiling results
df_cache_profile_all = pd.concat(modin_cache_profile_data, ignore_index=True)

# %%
print_profile_per_task(modin_cache_profile_data, metric='percall', top_n=25)
# Out:
# ==================================================
# Tarefa: read file
# Top 25 funções por percall:
#
#                                                                     function  percall
#                           ~:0 (<method 'acquire' of '_thread.lock' objects>) 1.039231
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.003078
#               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.002069
#                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001632
#         ~:0 (<method 'finish' of 'pyarrow._dataset.DatasetFactory' objects>) 0.001463
#                               ~:0 (<method 'match' of 're.Pattern' objects>) 0.001286
#                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001012
#                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.000933
#                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:464 (put) 0.000665
#                                     ~:0 (<method 'encode' of 'str' objects>) 0.000643
#                      /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.000612
#                                       ~:0 (<method 'get' of 'dict' objects>) 0.000588
#               /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000549
#                /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000548
#                 /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.000525
#                                          ~:0 (<built-in method builtins.id>) 0.000503
#                            ~:0 (<method 'send' of '_socket.socket' objects>) 0.000474
#                              ~:0 (<method 'write' of '_io.BytesIO' objects>) 0.000411
#               /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.000392
#              /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000364
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/base.py:846 (tokenize) 0.000359
#           /opt/conda/envs/cdle/lib/python3.7/pickle.py:865 (_batch_setitems) 0.000347
#                                    ~:0 (<method 'replace' of 'str' objects>) 0.000347
#                                           ~:0 (<built-in method posix.stat>) 0.000326
#               /opt/conda/envs/cdle/lib/python3.7/pickle.py:567 (save_reduce) 0.000323
#
# ==================================================
# Tarefa: count
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000005
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000005
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023 (__len__) 0.000004
#                                                                       /var/tmp/ipykernel_3248/742427061.py:4 (count) 0.000003
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000003
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000002
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000002
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000001
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000001
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ==================================================
# Tarefa: count index length
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000005
#                                                          /var/tmp/ipykernel_3248/742427061.py:7 (count_index_length) 0.000003
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000002
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000002
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000001
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000001
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000000
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ==================================================
# Tarefa: mean
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.050610
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.010508
#                                                                      ~:0 (<built-in method posix.stat>) 0.008996
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.006421
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.003288
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.003137
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002879
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.002038
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001796
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001513
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001294
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.001293
#                                                                                    <string>:1 (__new__) 0.001121
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.001112
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.000994
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000972
#                                                                   ~:0 (<built-in method posix.urandom>) 0.000960
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.000911
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000863
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000845
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000822
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.000779
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.000694
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.000684
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000638
#
# ==================================================
# Tarefa: standard deviation
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.052913
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.010152
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.005871
#                                                                      ~:0 (<built-in method posix.stat>) 0.005867
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.004062
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.003076
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002764
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.002172
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.001986
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001462
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001245
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.001203
#                                                                                    <string>:1 (__new__) 0.001113
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001107
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.001012
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000862
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000860
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000809
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000786
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.000747
#                                                                   ~:0 (<built-in method posix.urandom>) 0.000740
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.000739
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.000607
#                                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000599
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.000588
#
# ==================================================
# Tarefa: mean of columns addition
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.184900
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.048403
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.029756
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.019604
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.014523
#                                                                      ~:0 (<built-in method posix.stat>) 0.014119
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012767
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010189
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009489
#                                                                   ~:0 (<built-in method posix.urandom>) 0.007531
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.007173
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006165
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005777
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005732
#                                                                                    <string>:1 (__new__) 0.005382
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.005090
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004442
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004413
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003895
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.003691
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003654
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003626
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003270
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003213
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003167
#
# ==================================================
# Tarefa: addition of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.140473
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039581
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.024188
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.016945
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012098
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010277
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008673
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007915
#                                                                      ~:0 (<built-in method posix.stat>) 0.006193
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005730
#                                                                   ~:0 (<built-in method posix.urandom>) 0.005249
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004935
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004897
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004840
#                                                                                    <string>:1 (__new__) 0.004566
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.004478
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003863
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003693
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003247
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003186
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003146
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.002815
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002588
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002495
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/numeric.py:2317 (array_equal) 0.002429
#
# ==================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.199921
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.048732
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.030327
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.019533
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.015153
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.013029
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010502
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009628
#                                                                      ~:0 (<built-in method posix.stat>) 0.009620
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.007140
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006097
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005907
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005611
#                                                                                    <string>:1 (__new__) 0.005512
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/numeric.py:2317 (array_equal) 0.004886
#                                                                   ~:0 (<built-in method posix.urandom>) 0.004694
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004593
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004564
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003841
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003831
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003753
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.003676
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003307
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003144
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.002955
#
# ==================================================
# Tarefa: multiplication of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.139190
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039255
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.023930
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.017003
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012004
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010308
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.009034
#                                                                      ~:0 (<built-in method posix.stat>) 0.008450
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007937
#                                                                   ~:0 (<built-in method posix.urandom>) 0.007186
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005736
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004977
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004938
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004875
#                                                                                    <string>:1 (__new__) 0.004492
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003907
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003723
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003273
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.003235
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003201
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003128
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.002996
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.002736
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002701
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002587
#
# ==================================================
# Tarefa: value counts
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.329900
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.056828
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.033085
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.020300
#                                                                      ~:0 (<built-in method posix.stat>) 0.018380
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.017293
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.015382
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.011123
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.011023
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.008478
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.007268
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.007004
#                                                                   ~:0 (<built-in method posix.urandom>) 0.006540
#                                                                                    <string>:1 (__new__) 0.006370
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.006107
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005921
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.005181
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.004698
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004487
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.004294
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.004082
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003931
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003813
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003553
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003260
#
# ==================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                  function  percall
#                                        ~:0 (<method 'acquire' of '_thread.lock' objects>) 2.106398
#                            /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.295287
#                                            ~:0 (<method 'match' of 're.Pattern' objects>) 0.176294
#                                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.109307
#                                   /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.089326
#                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.078546
#                                                        ~:0 (<built-in method posix.stat>) 0.071117
#                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.059845
#                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.058309
#                             /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.043418
#                                                     ~:0 (<built-in method posix.urandom>) 0.040100
#                                         ~:0 (<method 'send' of '_socket.socket' objects>) 0.040075
#                                 /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.037387
#                               /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.034733
#                                                                      <string>:1 (__new__) 0.033598
#                /var/tmp/ipykernel_3248/742427061.py:36 (complicated_arithmetic_operation) 0.033536
#                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.032084
#                                    /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.027584
#                                               ~:0 (<built-in method builtins.isinstance>) 0.025795
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.025132
#                                    /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.024038
#                          ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.022977
# /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/numeric.py:2317 (array_equal) 0.022064
#                                                    ~:0 (<method 'get' of 'dict' objects>) 0.021547
#                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.020277
#
# ==================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                  function  percall
#                                        ~:0 (<method 'acquire' of '_thread.lock' objects>) 2.190830
#                            /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.305501
#                                            ~:0 (<method 'match' of 're.Pattern' objects>) 0.182574
#                                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.114569
#                                   /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.093023
#                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.080885
#                                                        ~:0 (<built-in method posix.stat>) 0.075551
#                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.061704
#                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.060333
#                                                     ~:0 (<built-in method posix.urandom>) 0.059218
#                             /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.044585
#                                 /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.038820
#                               /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.035343
#                                                                      <string>:1 (__new__) 0.034641
#                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.034053
#        /var/tmp/ipykernel_3248/742427061.py:47 (mean_of_complicated_arithmetic_operation) 0.033106
#                                         ~:0 (<method 'send' of '_socket.socket' objects>) 0.032945
#                                    /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.028478
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.026767
#                                               ~:0 (<built-in method builtins.isinstance>) 0.026430
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.026423
# /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/numeric.py:2317 (array_equal) 0.026206
#                                    /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.024723
#                          ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.023203
#                                                    ~:0 (<method 'get' of 'dict' objects>) 0.022647
#
# ==================================================
# Tarefa: groupby statistics
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.163680
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.020099
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.011816
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.007115
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.006062
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.005424
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.003959
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.003812
#                                                                   ~:0 (<built-in method posix.urandom>) 0.003725
#                                                                      ~:0 (<built-in method posix.stat>) 0.003539
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.003098
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.002518
#                                                                                    <string>:1 (__new__) 0.002304
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.002218
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.002085
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.001931
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.001689
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.001501
#                                        ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.001472
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.001414
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.001389
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.001363
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.001338
#                                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:865 (_batch_setitems) 0.001283
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.001229
#
# ==================================================
# Tarefa: join count
# Top 25 funções por percall:
#
#                                                                                                    function  percall
#                                                          ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.125627
#                                              /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039248
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.034630
#                                                              ~:0 (<method 'match' of 're.Pattern' objects>) 0.023826
#                                                          ~:0 (<method 'astype' of 'numpy.ndarray' objects>) 0.016890
#                                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.015363
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.012073
#                                                     /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.011744
#                                                /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010201
#                                                                        ~:0 (<pandas._libs.lib.infer_dtype>) 0.008219
#                                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008183
#                                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007676
#                                                                          ~:0 (<built-in method posix.stat>) 0.006970
#                                                                       ~:0 (<built-in method posix.urandom>) 0.006257
#                                               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005595
#                                                   /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004978
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004617
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:198 (join) 0.004518
#                                                    /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004515
#                                                                                        <string>:1 (__new__) 0.004431
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003591
#                                                      /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003550
#                                                           ~:0 (<method 'send' of '_socket.socket' objects>) 0.003507
#                                                      /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003059
#                                                                 ~:0 (<built-in method builtins.isinstance>) 0.002986
#
# ==================================================
# Tarefa: join
# Top 25 funções por percall:
#
#                                                                                                    function  percall
#                                                          ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.097640
#                                              /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.036305
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.022828
#                                                              ~:0 (<method 'match' of 're.Pattern' objects>) 0.022069
#                                                                          ~:0 (<built-in method posix.stat>) 0.019749
#                                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.013201
#                                                          ~:0 (<method 'astype' of 'numpy.ndarray' objects>) 0.012127
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.011711
#                                                     /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.010712
#                                                /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.009317
#                                                                        ~:0 (<pandas._libs.lib.infer_dtype>) 0.008237
#                                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.007198
#                                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007083
#                                               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005111
#                                                                       ~:0 (<built-in method posix.urandom>) 0.004694
#                                                   /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004399
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004166
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:198 (join) 0.004147
#                                                           ~:0 (<method 'send' of '_socket.socket' objects>) 0.004019
#                                                                                        <string>:1 (__new__) 0.003953
#                                                    /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.003794
#                                                      /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003299
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003215
#                                                      /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002761
#                                            ~:0 (<built-in method __new__ of type object at 0x55e4d87646e0>) 0.002728

# %%
# Restart the Dask client to clear cluster state and free resources
client.restart()
# Out:
# <Client: 'tcp://127.0.0.1:42267' processes=4 threads=8, memory=31.34 GiB>

# %% [markdown]
# # Joblib
#
# This part of the notebook defines a set of benchmark functions to evaluate the performance of common data processing operations using Joblib.
#
# The dataset is loaded from a Parquet file and a benchmark_joblib function is also provided to run all tasks in parallel using Joblib and measure execution time.
#
# The goal is to compare execution speed across different backends or configurations.

# %%
joblib_data = pd.read_parquet("Samples/sample_2009_2010_medium_clean.parquet")

# %%
# Helper function to convert benchmark results into a pandas DataFrame
def get_results(benchmarks):
    """Returns a pandas DataFrame containing benchmark results"""
    return pd.DataFrame.from_dict(benchmarks)

def read_file_parquet(df=None):
    return pd.read_parquet("Samples/sample_2009_2010_medium_clean.parquet")

def count(df=None):
    return len(df)

def count_index_length(df=None):
    return len(df.index)

def mean(df):
    return df.Fare_Amt.mean()

def standard_deviation(df):
    return df.Fare_Amt.std()

def mean_of_sum(df):
    return (df.Fare_Amt + df.Tip_Amt).mean()

def sum_columns(df):
    x = df.Fare_Amt + df.Tip_Amt

    return x

def mean_of_product(df):
    return (df.Fare_Amt * df.Tip_Amt).mean()

def product_columns(df):
    x = df.Fare_Amt * df.Tip_Amt

    return x

def value_counts(df):
    val_counts = df.Fare_Amt.value_counts()
    return val_counts

def complicated_arithmetic_operation(df):
    theta_1 = df.Start_Lon
    phi_1 = df.Start_Lat
    theta_2 = df.End_Lon
    phi_2 = df.End_Lat
    temp = (np.sin((theta_2 - theta_1) / 2 * np.pi / 180) ** 2
           + np.cos(theta_1 * np.pi / 180) * np.cos(theta_2 * np.pi / 180) * np.sin((phi_2 - phi_1) / 2 * np.pi / 180) ** 2)
    ret = np.multiply(np.arctan2(np.sqrt(temp), np.sqrt(1-temp)),2)

    return ret

def mean_of_complicated_arithmetic_operation(df):
    theta_1 = df.Start_Lon
    phi_1 = df.Start_Lat
    theta_2 = df.End_Lon
    phi_2 = df.End_Lat
    temp = (np.sin((theta_2 - theta_1) / 2 * np.pi / 180) ** 2
           + np.cos(theta_1 * np.pi / 180) * np.cos(theta_2 * np.pi / 180) * np.sin((phi_2 - phi_1) / 2 * np.pi / 180) ** 2)
    ret = np.multiply(np.arctan2(np.sqrt(temp), np.sqrt(1-temp)),2)
    return ret.mean()

def groupby_statistics(df):
    gb = df.groupby(by='Passenger_Count').agg(
      {
        'Fare_Amt': ['mean', 'std'],
        'Tip_Amt': ['mean', 'std']
      }
    )
    return gb

other = pd.DataFrame(groupby_statistics(joblib_data))
other.columns = pd.Index([e[0]+'_' + e[1] for e in other.columns.tolist()])

def join_count(df, other):
    return len(df.merge(other, left_index=True, right_index=True))

def join_data(df, other):
    return df.merge(other, left_index=True, right_index=True)

# %%
# === Joblib benchmarking utility ===

# Run benchmark tasks in parallel using Joblib
def benchmark_joblib(tasks, n_jobs=-1, save_path=None):
    """
    Executes parallel benchmarks for a list of tasks and optionally saves the results.
    
    tasks: list of tuples (function, df, kwargs dict, task name)
    n_jobs: number of parallel jobs (-1 = use all cores)
    save_path: optional path to save results as a Parquet file
    
    Returns: DataFrame with 'task' as index and 'duration' in seconds
    """
    
    def run_task(f, df, kwargs, name):
        start = time.perf_counter()
        f(df, **kwargs)
        elapsed = time.perf_counter() - start
        return (name, elapsed)
    
    # Run all tasks in parallel
    results = Parallel(n_jobs=n_jobs)(
        delayed(run_task)(f, df, kwargs, name) for f, df, kwargs, name in tasks
    )
    
    # Create DataFrame and clean duplicates
    df_results = pd.DataFrame(results, columns=['task', 'duration']) \
                   .drop_duplicates(subset='task') \
                   .set_index('task')
    
    # Save to Parquet if specified
    if save_path:
        df_results.to_parquet(save_path)
        print(f'O arquivo Parquet foi salvo em {save_path}.')
    
    return df_results

# %% [markdown]
# Three dictionaries (joblib_benchmarks, joblib_benchmarks_filtered, joblib_benchmarks_cache) are initialized to store benchmark results.
#
# Then, a list of tasks is defined, where each task represents a function to benchmark (e.g., count, mean, groupby) along with its inputs.
#
# These tasks will be executed in parallel using Joblib to evaluate the performance of various data processing operations.

# %%
joblib_benchmarks = {
    'duration': [],  # in seconds
    'task': [],
}

joblib_benchmarks_filtered = {
    'duration': [],  # in seconds
    'task': [],
}

joblib_benchmarks_cache = {
    'duration': [],  # in seconds
    'task': [],
}

# %%
# === Define the list of tasks to run in parallel using Joblib ===
tasks = [
    (read_file_parquet, None, {}, "read file"),
    (count, joblib_data, {}, "count"),
    (count_index_length, joblib_data, {}, "count index length"),
    (mean, joblib_data, {}, "mean"),
    (standard_deviation, joblib_data, {}, "standard deviation"),
    (mean_of_sum, joblib_data, {}, "mean of columns addition"),
    (sum_columns, joblib_data, {}, "addition of columns"),
    (mean_of_product, joblib_data, {}, "mean of columns multiplication"),
    (product_columns, joblib_data, {}, "multiplication of columns"),
    (value_counts, joblib_data, {}, "value counts"),
    (complicated_arithmetic_operation, joblib_data, {}, "complex arithmetic ops"),
    (mean_of_complicated_arithmetic_operation, joblib_data, {}, "mean of complex arithmetic ops"),
    (groupby_statistics, joblib_data, {}, "groupby statistics"),
    (join_count, joblib_data, {'other': other}, "join count"),
    (join_data, joblib_data, {'other': other}, "join"),
]

# %%
df_results = benchmark_joblib(tasks, n_jobs=-1, save_path='Results_Joblib_M/joblib_local_medium')
print(df_results)
# Out:
# O arquivo Parquet foi salvo em Results_Joblib_M/joblib_local_medium.
#                                 duration
# task
# read file                       1.805698
# count                           0.000012
# count index length              0.000009
# mean                            0.020047
# standard deviation              0.066321
# mean of columns addition        0.033437
# addition of columns             0.015166
# mean of columns multiplication  0.029282
# multiplication of columns       0.011707
# value counts                    0.064545
# complex arithmetic ops          0.595629
# mean of complex arithmetic ops  0.585256
# groupby statistics              0.325579
# join count                      0.039675
# join                            0.033301

# %% [markdown]
# # cProfile
#
# The function benchmark_cprofile benchmarks and profiles the execution of data processing functions using Python’s cProfile.
#
# It collects both execution time and profiling statistics, then runs it for a set of predefined tasks. Finally, it aggregates all profiling statistics into a single DataFrame for further analysis or visualization.

# %%
def benchmark_cprofile(f, df, benchmarks, name, profile_data=None, **kwargs):
    """
    Benchmark and profile the execution of a function using cProfile (without I/O).
    
    Parameters:
        f (callable): The function to benchmark.
        df (DataFrame): The DataFrame or data to pass as input.
        benchmarks (dict): Dictionary to store duration and task name.
        name (str): Name of the task/function.
        profile_data (list): List to store detailed profiling statistics.
        **kwargs: Additional arguments passed to the function.
    """ 
    pr = cProfile.Profile()
    pr.enable()

    start_time = time.perf_counter()
    ret = f(df, **kwargs)
    duration = time.perf_counter() - start_time

    pr.disable()

    benchmarks['duration'].append(duration)
    benchmarks['task'].append(name)
    print(f"{name} took: {duration:.4f} seconds")

    # Display top 15 most time-consuming function calls
    ps = pstats.Stats(pr)
    ps.sort_stats(pstats.SortKey.CUMULATIVE)
    ps.print_stats(15)

    # Save detailed profiling statistics into a list of DataFrames
    if profile_data is not None:
        stats_data = []
        for func, stat in ps.stats.items():
            filename, lineno, function = func
            ncalls, _, percall, cumtime, _ = stat
            stats_data.append({
                'task': name,
                'function': f"{filename}:{lineno} ({function})",
                'percall': percall,
                'cumtime': cumtime,
                'ncalls': ncalls
            })
        profile_data.append(pd.DataFrame(stats_data))

    return duration

# %%
joblib_benchmarks_cprofile = {'duration': [], 'task': []}
joblib_profile_data = []

# === Execute benchmarks with cProfile for all tasks ===
benchmark_cprofile(read_file_parquet, df=None, benchmarks=joblib_benchmarks_cprofile, name='read file', profile_data=joblib_profile_data)
benchmark_cprofile(count, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='count', profile_data=joblib_profile_data)
benchmark_cprofile(count_index_length, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='count index length', profile_data=joblib_profile_data)
benchmark_cprofile(mean, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='mean', profile_data=joblib_profile_data)
benchmark_cprofile(standard_deviation, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='standard deviation', profile_data=joblib_profile_data)
benchmark_cprofile(mean_of_sum, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='mean of columns addition', profile_data=joblib_profile_data)
benchmark_cprofile(sum_columns, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='addition of columns', profile_data=joblib_profile_data)
benchmark_cprofile(mean_of_product, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='mean of columns multiplication', profile_data=joblib_profile_data)
benchmark_cprofile(product_columns, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='multiplication of columns', profile_data=joblib_profile_data)
benchmark_cprofile(value_counts, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='value counts', profile_data=joblib_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='complex arithmetic ops', profile_data=joblib_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='mean of complex arithmetic ops', profile_data=joblib_profile_data)
benchmark_cprofile(groupby_statistics, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='groupby statistics', profile_data=joblib_profile_data)
benchmark_cprofile(join_count, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='join count', other=other, profile_data=joblib_profile_data)
benchmark_cprofile(join_data, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='join', other=other, profile_data=joblib_profile_data)
# Out:
# read file took: 1.7751 seconds
#          1787 function calls (1776 primitive calls) in 1.775 seconds
#
#    Ordered by: cumulative time
#    List reduced from 354 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.775    1.775 /var/tmp/ipykernel_3248/3012487071.py:6(read_file_parquet)
#         1    0.000    0.000    1.775    1.775 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:433(read_parquet)
#         1    0.003    0.003    1.775    1.775 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201(read)
#         1    0.000    0.000    1.064    1.064 {method 'to_pandas' of 'pyarrow.lib._PandasConvertible' objects}
#         1    0.000    0.000    1.064    1.064 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756(table_to_blockmanager)
#         1    0.000    0.000    1.062    1.062 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1109(_table_to_blocks)
#         1    1.061    1.061    1.061    1.061 {pyarrow.lib.table_to_blocks}
#         1    0.000    0.000    0.708    0.708 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1551(read_table)
#         1    0.000    0.000    0.706    0.706 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440(read)
#         1    0.706    0.706    0.706    0.706 {method 'to_table' of 'pyarrow._dataset.Dataset' objects}
#         1    0.002    0.002    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377(__init__)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:858(_deserialize_column_index)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:195(new_meth)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:495(from_tuples)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:429(from_arrays)
#
#
# count took: 0.0000 seconds
#          9 function calls (7 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/3012487071.py:9(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352(__len__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          7 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/3012487071.py:12(count_index_length)
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# mean took: 0.0139 seconds
#          185 function calls in 0.014 seconds
#
#    Ordered by: cumulative time
#    List reduced from 79 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.014    0.014 /var/tmp/ipykernel_3248/3012487071.py:15(mean)
#         1    0.000    0.000    0.014    0.014 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.014    0.014 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.014    0.014 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.014    0.014 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.014    0.014 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.014    0.014 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.014    0.014 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.014    0.014 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         3    0.008    0.003    0.008    0.003 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.007    0.004 {method 'sum' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.007    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45(_sum)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258(_get_values)
#         1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214(_maybe_get_mask)
#         1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:61(isna)
#
#
# standard deviation took: 0.0388 seconds
#          279 function calls (278 primitive calls) in 0.039 seconds
#
#    Ordered by: cumulative time
#    List reduced from 90 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.039    0.039 /var/tmp/ipykernel_3248/3012487071.py:18(standard_deviation)
#         1    0.000    0.000    0.039    0.039 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10610(std)
#         1    0.000    0.000    0.039    0.039 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10317(std)
#         1    0.000    0.000    0.039    0.039 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271(_stat_function_ddof)
#         1    0.000    0.000    0.039    0.039 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#       2/1    0.000    0.000    0.039    0.039 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.039    0.039 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838(nanstd)
#         1    0.000    0.000    0.034    0.034 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.013    0.013    0.033    0.033 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877(nanvar)
#         4    0.010    0.003    0.010    0.003 {method 'reduce' of 'numpy.ufunc' objects}
#         3    0.000    0.000    0.010    0.003 {method 'sum' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.010    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45(_sum)
#         2    0.000    0.000    0.006    0.003 <__array_function__ internals>:2(putmask)
#         2    0.006    0.003    0.006    0.003 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258(_get_values)
#
#
# mean of columns addition took: 0.0169 seconds
#          455 function calls (453 primitive calls) in 0.017 seconds
#
#    Ordered by: cumulative time
#    List reduced from 156 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.017    0.017 /var/tmp/ipykernel_3248/3012487071.py:21(mean_of_sum)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#
#
# addition of columns took: 0.0075 seconds
#          299 function calls (297 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time
#    List reduced from 115 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 /var/tmp/ipykernel_3248/3012487071.py:24(sum_columns)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.007    0.007    0.007    0.007 {built-in method _operator.add}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:242(__call__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:114(_get_option)
#
#
# mean of columns multiplication took: 0.0161 seconds
#          455 function calls (453 primitive calls) in 0.016 seconds
#
#    Ordered by: cumulative time
#    List reduced from 156 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.016    0.016 /var/tmp/ipykernel_3248/3012487071.py:29(mean_of_product)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#
#
# multiplication of columns took: 0.0062 seconds
#          299 function calls (297 primitive calls) in 0.006 seconds
#
#    Ordered by: cumulative time
#    List reduced from 115 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.006    0.006 /var/tmp/ipykernel_3248/3012487071.py:32(product_columns)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.006    0.006    0.006    0.006 {built-in method _operator.mul}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#        58    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#
#
# value counts took: 0.0484 seconds
#          568 function calls (564 primitive calls) in 0.048 seconds
#
#    Ordered by: cumulative time
#    List reduced from 156 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.048    0.048 /var/tmp/ipykernel_3248/3012487071.py:37(value_counts)
#         1    0.000    0.000    0.048    0.048 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/base.py:874(value_counts)
#         1    0.000    0.000    0.048    0.048 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796(value_counts)
#         1    0.047    0.047    0.047    0.047 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876(value_counts_arraylike)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/util/_decorators.py:302(wrapper)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258(sort_values)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343(nargsort)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:6279(ensure_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375(__new__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4587(__getitem__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931(new_block)
#       135    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#
#
# complex arithmetic ops took: 0.4556 seconds
#          6642 function calls (6583 primitive calls) in 0.456 seconds
#
#    Ordered by: cumulative time
#    List reduced from 202 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.006    0.006    0.456    0.456 /var/tmp/ipykernel_3248/3012487071.py:41(complicated_arithmetic_operation)
#         8    0.000    0.000    0.331    0.041 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.312    0.039    0.331    0.041 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.126    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.126    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        19    0.000    0.000    0.121    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#        19    0.000    0.000    0.121    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.120    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.120    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         7    0.000    0.000    0.036    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         7    0.034    0.005    0.034    0.005 {built-in method _operator.mul}
#         6    0.000    0.000    0.030    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#         6    0.029    0.005    0.029    0.005 {built-in method _operator.truediv}
#         1    0.000    0.000    0.022    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.021    0.021    0.021    0.021 {built-in method _operator.add}
#
#
# mean of complex arithmetic ops took: 0.4355 seconds
#          6554 function calls (6499 primitive calls) in 0.436 seconds
#
#    Ordered by: cumulative time
#    List reduced from 225 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002    0.436    0.436 /var/tmp/ipykernel_3248/3012487071.py:52(mean_of_complicated_arithmetic_operation)
#         8    0.000    0.000    0.322    0.040 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.308    0.038    0.322    0.040 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.105    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.105    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        19    0.000    0.000    0.101    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#        19    0.000    0.000    0.100    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.100    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.100    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         7    0.000    0.000    0.032    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         7    0.030    0.004    0.030    0.004 {built-in method _operator.mul}
#         6    0.000    0.000    0.029    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#         6    0.028    0.005    0.028    0.005 {built-in method _operator.truediv}
#         2    0.000    0.000    0.016    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:146(__pow__)
#         2    0.016    0.008    0.016    0.008 {built-in method _operator.pow}
#
#
# groupby statistics took: 0.2280 seconds
#          4022 function calls (3968 primitive calls) in 0.228 seconds
#
#    Ordered by: cumulative time
#    List reduced from 447 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.228    0.228 /var/tmp/ipykernel_3248/3012487071.py:62(groupby_statistics)
#         1    0.000    0.000    0.228    0.228 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:964(aggregate)
#         1    0.000    0.000    0.228    0.228 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:143(agg)
#         1    0.000    0.000    0.228    0.228 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405(agg_dict_like)
#         1    0.000    0.000    0.226    0.226 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:435(<dictcomp>)
#       6/2    0.000    0.000    0.226    0.113 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:225(aggregate)
#         2    0.000    0.000    0.226    0.113 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278(_aggregate_multiple_funcs)
#         2    0.000    0.000    0.142    0.071 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1634(mean)
#         2    0.000    0.000    0.142    0.071 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:322(_cython_agg_general)
#         2    0.000    0.000    0.142    0.071 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:338(array_func)
#         2    0.000    0.000    0.142    0.071 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:991(_cython_operation)
#         2    0.000    0.000    0.082    0.041 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1723(std)
#         2    0.082    0.041    0.082    0.041 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2790(_get_cythonized_result)
#         2    0.000    0.000    0.081    0.041 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:631(cython_operation)
#         2    0.000    0.000    0.081    0.040 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:488(_cython_op_ndim_compat)
#
#
# join count took: 0.0320 seconds
#          3170 function calls (3142 primitive calls) in 0.032 seconds
#
#    Ordered by: cumulative time
#    List reduced from 331 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.032    0.032 /var/tmp/ipykernel_3248/3012487071.py:74(join_count)
#         1    0.000    0.000    0.032    0.032 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.032    0.032 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.032    0.032 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.028    0.028 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#     75/67    0.000    0.000    0.027    0.000 {built-in method builtins.all}
#        11    0.000    0.000    0.027    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#        22    0.000    0.000    0.026    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.026    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#         8    0.000    0.000    0.026    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        16    0.002    0.000    0.026    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#         3    0.000    0.000    0.024    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:670(<lambda>)
#         3    0.000    0.000    0.024    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221(_isna_array)
#         3    0.001    0.000    0.024    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259(_isna_string_dtype)
#         3    0.023    0.008    0.023    0.008 {built-in method pandas._libs.missing.isnaobj}
#
#
# join took: 0.0294 seconds
#          3003 function calls (2983 primitive calls) in 0.029 seconds
#
#    Ordered by: cumulative time
#    List reduced from 301 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.029    0.029 /var/tmp/ipykernel_3248/3012487071.py:77(join_data)
#         1    0.000    0.000    0.029    0.029 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.029    0.029 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.029    0.029 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.029    0.029 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#     75/67    0.000    0.000    0.027    0.000 {built-in method builtins.all}
#        11    0.000    0.000    0.027    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#        22    0.000    0.000    0.027    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.027    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#         8    0.000    0.000    0.027    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        16    0.002    0.000    0.027    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#         3    0.000    0.000    0.024    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:670(<lambda>)
#         3    0.000    0.000    0.024    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221(_isna_array)
#         3    0.001    0.000    0.024    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259(_isna_string_dtype)
#         3    0.023    0.008    0.023    0.008 {built-in method pandas._libs.missing.isnaobj}
# 0.02943596800002979

# %%
# Concatenate all DataFrames
df_profile_all = pd.concat(joblib_profile_data, ignore_index=True)

# %% [markdown]
# Once again, The print_profile_per_task function is used to print the slowest functions for each task that was profiled using cProfile.
#
# Each task (like 'mean', 'join', etc.) has a corresponding DataFrame in the profile_data_list, which contains profiling information (e.g. time per function call and total cumulative time).
#
# The function works as follows:
#
# - Iterates over each DataFrame in the list (one per task).
# - For each task, it sorts the profiling stats by the selected metric (percall or cumtime).
# - Prints the top N slowest functions according to the selected metric.
# - Displays the task name and a table with the function name and the chosen metric.

# %%
def print_profile_per_task(profile_data_list, metric='percall', top_n=10):

    for df in profile_data_list:
        task_name = df['task'].iloc[0]  # todas as linhas têm o mesmo 'task'
        df_sorted = df.sort_values(by=metric, ascending=False).head(top_n)

        print(f"\n{'=' * 60}")
        print(f"Tarefa: {task_name}")
        print(f"Top {top_n} funções por '{metric}':\n")
        print(df_sorted[['function', metric]].to_string(index=False))

# %%
print_profile_per_task(joblib_profile_data, metric='percall', top_n=25)
# Out:
# ============================================================
# Tarefa: read file
# Top 25 funções por 'percall':
#
#                                                                                                  function  percall
#                                                                       ~:0 (<pyarrow.lib.table_to_blocks>) 1.061178
#                                           ~:0 (<method 'to_table' of 'pyarrow._dataset.Dataset' objects>) 0.705919
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201 (read) 0.002979
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377 (__init__) 0.001958
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:1073 (_engine) 0.000111
#                                                               ~:0 (<built-in method builtins.isinstance>) 0.000107
#                                                            ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000070
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/base.py:425 (find) 0.000065
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1130 (<listcomp>) 0.000062
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440 (read) 0.000061
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756 (table_to_blockmanager) 0.000058
#                                                                           ~:0 (<built-in method io.open>) 0.000055
#                            ~:0 (<method 'make_fragment' of 'pyarrow._dataset.ParquetFileFormat' objects>) 0.000051
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000049
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.000043
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:858 (_deserialize_column_index) 0.000042
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:794 (_get_extension_dtypes) 0.000041
#                            ~:0 (<method 'factorize' of 'pandas._libs.hashtable.StringHashTable' objects>) 0.000041
#                                    ~:0 (<method 'to_pandas' of 'pyarrow.lib._PandasConvertible' objects>) 0.000040
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/api.py:34 (make_block) 0.000039
#                                                          ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000037
#                                       /opt/conda/envs/cdle/lib/python3.7/json/decoder.py:343 (raw_decode) 0.000036
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:361 (__init__) 0.000035
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:571 (factorize) 0.000035
#                                                            ~:0 (<pandas._libs.algos.take_1d_int64_int64>) 0.000032
#
# ============================================================
# Tarefa: count
# Top 25 funções por 'percall':
#
#                                                                                    function  percall
#                                                        ~:0 (<built-in method builtins.len>) 0.000006
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352 (__len__) 0.000006
#                                                   ~:0 (<built-in method time.perf_counter>) 0.000002
#                                             /var/tmp/ipykernel_3248/3012487071.py:9 (count) 0.000002
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806 (__len__) 0.000002
#                                      ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ============================================================
# Tarefa: count index length
# Top 25 funções por 'percall':
#
#                                                                                    function  percall
#                               /var/tmp/ipykernel_3248/3012487071.py:12 (count_index_length) 0.000004
#                                                        ~:0 (<built-in method builtins.len>) 0.000002
#                                                   ~:0 (<built-in method time.perf_counter>) 0.000000
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806 (__len__) 0.000000
#                                      ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ============================================================
# Tarefa: mean
# Top 25 funções por 'percall':
#
#                                                                                                 function  percall
#                                                         ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.008145
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.005317
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000026
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000025
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000020
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000017
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000016
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000016
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368 (mean) 0.000015
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396 (new_func) 0.000014
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000013
#                                                          /var/tmp/ipykernel_3248/3012487071.py:15 (mean) 0.000013
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000012
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000012
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000012
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000011
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000010
#                                                              ~:0 (<built-in method builtins.isinstance>) 0.000009
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000009
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:87 (<genexpr>) 0.000008
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000008
#                                                                  ~:0 (<built-in method numpy.seterrobj>) 0.000006
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1141 (needs_i8_conversion) 0.000006
#                                                          ~:0 (<method 'sum' of 'numpy.ndarray' objects>) 0.000006
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:438 (__exit__) 0.000006
#
# ============================================================
# Tarefa: standard deviation
# Top 25 funções por 'percall':
#
#                                                                                                      function  percall
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877 (nanvar) 0.013259
#                                                              ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.010500
#                                 ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.006410
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.004408
#                                                              ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.003721
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838 (nanstd) 0.000034
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000024
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000023
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000020
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000019
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000018
#                                                                   ~:0 (<built-in method builtins.isinstance>) 0.000017
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000015
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1420 (is_extension_array_dtype) 0.000015
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000013
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000013
#                                                                    <__array_function__ internals>:2 (putmask) 0.000013
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1585 (_ensure_numeric) 0.000012
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271 (_stat_function_ddof) 0.000012
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:673 (is_integer_dtype) 0.000010
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10317 (std) 0.000010
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000009
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000009
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1141 (needs_i8_conversion) 0.000009
#                                                 /var/tmp/ipykernel_3248/3012487071.py:18 (standard_deviation) 0.000009
#
# ============================================================
# Tarefa: mean of columns addition
# Top 25 funções por 'percall':
#
#                                                                                                                 function  percall
#                                                                                    ~:0 (<built-in method _operator.add>) 0.006643
#                                                                         ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.005826
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.003749
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000030
#                                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000025
#                                                                   /var/tmp/ipykernel_3248/3012487071.py:21 (mean_of_sum) 0.000020
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000018
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000017
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000015
#                                                                              ~:0 (<built-in method builtins.isinstance>) 0.000015
#                                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000014
#                                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90 (__add__) 0.000013
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000013
#                                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000012
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000012
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4638 (_can_hold_identifiers_and_holds_name) 0.000012
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185 (arithmetic_op) 0.000011
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000010
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000010
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000010
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000009
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000009
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000009
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000009
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000009
#
# ============================================================
# Tarefa: addition of columns
# Top 25 funções por 'percall':
#
#                                                                                              function  percall
#                                                                 ~:0 (<built-in method _operator.add>) 0.007081
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000023
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:114 (_get_option) 0.000022
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000015
#                                                           ~:0 (<built-in method builtins.isinstance>) 0.000015
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000012
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000008
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000008
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000008
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000007
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000007
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000007
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000006
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000006
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000006
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000006
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000006
#                                                /var/tmp/ipykernel_3248/3012487071.py:24 (sum_columns) 0.000006
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:565 (_get_root) 0.000005
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185 (arithmetic_op) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/missing.py:140 (dispatch_fill_zeros) 0.000005
#                                                              ~:0 (<built-in method builtins.getattr>) 0.000005
#
# ============================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por 'percall':
#
#                                                                                              function  percall
#                                                                 ~:0 (<built-in method _operator.mul>) 0.005765
#                                                      ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.005599
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.004124
#                                                           ~:0 (<built-in method builtins.isinstance>) 0.000030
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000025
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000019
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000018
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/missing.py:140 (dispatch_fill_zeros) 0.000017
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000015
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000014
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000013
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000012
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000011
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000011
#                                            /var/tmp/ipykernel_3248/3012487071.py:29 (mean_of_product) 0.000011
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000010
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000010
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000009
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214 (_maybe_get_mask) 0.000008
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000008
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000008
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000008
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000007
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000007
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000007
#
# ============================================================
# Tarefa: multiplication of columns
# Top 25 funções por 'percall':
#
#                                                                                                        function  percall
#                                                                           ~:0 (<built-in method _operator.mul>) 0.005896
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000020
#                                                                     ~:0 (<built-in method builtins.isinstance>) 0.000017
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000014
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000009
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000009
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_asarray.py:14 (asarray) 0.000009
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000009
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000008
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000008
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000007
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000006
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000006
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000006
#                                                      /var/tmp/ipykernel_3248/3012487071.py:32 (product_columns) 0.000006
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000006
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000006
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:565 (_get_root) 0.000005
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000005
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185 (arithmetic_op) 0.000005
#                                                                        ~:0 (<built-in method builtins.getattr>) 0.000005
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:441 (maybe_prepare_scalar_for_op) 0.000004
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/__init__.py:151 (align_method_SERIES) 0.000004
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:96 (_get_single_key) 0.000004
#
# ============================================================
# Tarefa: value counts
# Top 25 funções por 'percall':
#
#                                                                                                function  percall
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876 (value_counts_arraylike) 0.047059
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343 (nargsort) 0.000451
#                                                     ~:0 (<method 'argsort' of 'numpy.ndarray' objects>) 0.000118
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4587 (__getitem__) 0.000047
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000042
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258 (sort_values) 0.000035
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000029
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796 (value_counts) 0.000026
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000023
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000021
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/util/_validators.py:213 (validate_bool_kwarg) 0.000019
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000018
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000015
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:605 (_simple_new) 0.000015
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000013
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000013
#                           ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000012
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000012
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000012
#                                                                    ~:0 (<built-in method numpy.arange>) 0.000011
#                                                                ~:0 (<built-in method builtins.getattr>) 0.000011
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:6279 (ensure_index) 0.000010
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000010
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000009
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:183 (_reconstruct_data) 0.000009
#
# ============================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.312201
#                                                                  ~:0 (<built-in method _operator.mul>) 0.034198
#                                                              ~:0 (<built-in method _operator.truediv>) 0.028708
#                                                                  ~:0 (<built-in method _operator.add>) 0.021276
#                                                                  ~:0 (<built-in method _operator.pow>) 0.015109
#                                                                  ~:0 (<built-in method _operator.sub>) 0.014179
#                                                       ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.008362
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/roperator.py:12 (rsub) 0.006907
#                            /var/tmp/ipykernel_3248/3012487071.py:41 (complicated_arithmetic_operation) 0.006106
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000641
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000407
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000350
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000272
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000225
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000213
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000202
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000181
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000171
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000164
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000157
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000134
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:318 (reconstruct) 0.000134
#                                                                   ~:0 (<built-in method builtins.len>) 0.000133
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000132
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000126
#
# ============================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.307623
#                                                                  ~:0 (<built-in method _operator.mul>) 0.030442
#                                                              ~:0 (<built-in method _operator.truediv>) 0.027803
#                                                                  ~:0 (<built-in method _operator.pow>) 0.015605
#                                                                  ~:0 (<built-in method _operator.sub>) 0.013027
#                                                       ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.007613
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/roperator.py:12 (rsub) 0.007485
#                                                       ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.006198
#                                                                  ~:0 (<built-in method _operator.add>) 0.005681
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.003348
#                    /var/tmp/ipykernel_3248/3012487071.py:52 (mean_of_complicated_arithmetic_operation) 0.002360
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000618
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000422
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000333
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000261
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000221
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000220
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000195
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000170
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000166
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000163
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000149
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000140
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000138
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:318 (reconstruct) 0.000136
#
# ============================================================
# Tarefa: groupby statistics
# Top 25 funções por 'percall':
#
#                                                                                                        function  percall
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2790 (_get_cythonized_result) 0.081748
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:525 (_call_cython_op) 0.080791
#                                   ~:0 (<method 'factorize' of 'pandas._libs.hashtable.Int64HashTable' objects>) 0.039168
#                                                                  ~:0 (<pandas._libs.algos.take_1d_int64_int64>) 0.016555
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:571 (factorize) 0.004411
#                                                                  ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000202
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000193
#                                                                     ~:0 (<built-in method builtins.isinstance>) 0.000174
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000119
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278 (_aggregate_multiple_funcs) 0.000081
#                                                                            ~:0 (<built-in method builtins.len>) 0.000068
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000063
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000063
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000060
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1811 (_form_blocks) 0.000060
#                                                                             ~:0 (<built-in method numpy.array>) 0.000059
#                                                                        ~:0 (<built-in method builtins.getattr>) 0.000058
#                                                                        ~:0 (<built-in method builtins.hasattr>) 0.000056
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:680 (get_grouper) 0.000053
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405 (agg_dict_like) 0.000052
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:322 (_cython_agg_general) 0.000049
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:225 (aggregate) 0.000044
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:846 (__init__) 0.000043
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000043
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000041
#
# ============================================================
# Tarefa: join count
# Top 25 funções por 'percall':
#
#                                                                                                           function  percall
#                                                               ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.022632
#                                                                               ~:0 (<built-in method numpy.arange>) 0.002714
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.001891
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259 (_isna_string_dtype) 0.001064
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:665 (<lambda>) 0.000300
#                                                                   ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000150
#                                                                        ~:0 (<built-in method builtins.isinstance>) 0.000103
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000089
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000081
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000072
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000065
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000064
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:327 (_inner_indexer) 0.000064
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000056
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.000052
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:551 (_get_empty_dtype) 0.000047
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:528 (_dtype_to_na_value) 0.000046
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000045
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711 (get_result) 0.000043
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000041
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000040
#                                                                               ~:0 (<built-in method builtins.all>) 0.000038
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381 (is_na) 0.000036
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.000036
#                                                                                ~:0 (<built-in method numpy.empty>) 0.000035
#
# ============================================================
# Tarefa: join
# Top 25 funções por 'percall':
#
#                                                                                                                       function  percall
#                                                                           ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.023340
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.002069
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259 (_isna_string_dtype) 0.000975
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:665 (<lambda>) 0.000191
#                                                                               ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000143
#                                                                                    ~:0 (<built-in method builtins.isinstance>) 0.000098
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000087
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000070
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000067
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000054
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000052
#                                                                         ~:0 (<pandas._libs.algos.take_2d_axis1_object_object>) 0.000046
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000044
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000043
#                                                                                           ~:0 (<built-in method builtins.all>) 0.000043
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000039
#                                                                                           ~:0 (<built-in method builtins.len>) 0.000039
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:327 (_inner_indexer) 0.000038
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711 (get_result) 0.000037
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:190 (is_sparse) 0.000036
#                                                                                 ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000035
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:517 (_take_preprocess_indexer_and_fill_value) 0.000035
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000034
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585 (_is_uniform_join_units) 0.000033
#                                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381 (is_na) 0.000032

# %% [markdown]
# **Operations with filtering**

# %%
print(f"Tipo do DataFrame : {type(joblib_data)}")

# Apply filter using query
expr_filter = 'Tip_Amt >= 1 and Tip_Amt <= 5'
joblib_filtered = joblib_data.query(expr_filter)

print(f"Tipo do DataFrame filtrado: {type(joblib_filtered)}")
# Out:
# Tipo do DataFrame : <class 'pandas.core.frame.DataFrame'>
# Tipo do DataFrame filtrado: <class 'pandas.core.frame.DataFrame'>

# %%
tasks_filtered = [
    (read_file_parquet, None, {}, "read file"),
    (count, joblib_filtered, {}, "count"),
    (count_index_length, joblib_filtered, {}, "count index length"),
    (mean, joblib_filtered, {}, "mean"),
    (standard_deviation, joblib_filtered, {}, "standard deviation"),
    (mean_of_sum, joblib_filtered, {}, "mean of columns addition"),
    (sum_columns, joblib_filtered, {}, "addition of columns"),
    (mean_of_product, joblib_filtered, {}, "mean of columns multiplication"),
    (product_columns, joblib_filtered, {}, "multiplication of columns"),
    (value_counts, joblib_filtered, {}, "value counts"),
    (complicated_arithmetic_operation, joblib_filtered, {}, "complex arithmetic ops"),
    (mean_of_complicated_arithmetic_operation, joblib_filtered, {}, "mean of complex arithmetic ops"),
    (groupby_statistics, joblib_filtered, {}, "groupby statistics"),
    (join_count, joblib_filtered, {'other': other}, "join count"),
    (join_data, joblib_filtered, {'other': other}, "join"),
]

# %% [markdown]
# **Save results**

# %%
df_results_filtered = benchmark_joblib(tasks_filtered, n_jobs=-1, save_path='Results_Joblib_M/joblib_filtered_local_medium')
print(df_results_filtered)
# Out:
# O arquivo Parquet foi salvo em Results_Joblib_M/joblib_filtered_local_medium.
#                                 duration
# task
# read file                       2.048641
# count                           0.000006
# count index length              0.000003
# mean                            0.003099
# standard deviation              0.008298
# mean of columns addition        0.005076
# addition of columns             0.002786
# mean of columns multiplication  0.005400
# multiplication of columns       0.002688
# value counts                    0.013196
# complex arithmetic ops          0.067992
# mean of complex arithmetic ops  0.070887
# groupby statistics              0.063356
# join count                      0.032624
# join                            0.035089

# %% [markdown]
# **Filtered with cProfile**

# %% [markdown]
# After that, a filtered benchmark was also performed for Joblib by selecting only rows where Tip_Amt is between 1 and 5.
#
# This filtered DataFrame was then used to re-run the same set of tasks to evaluate Joblib's performance under common preprocessing conditions.

# %%
joblib_benchmarks_filtered_cprofile = {'duration': [], 'task': []}
joblib_filtered_profile_data = []

# %%
# Execute benchmarks with cProfile
benchmark_cprofile(read_file_parquet, df=None, benchmarks=joblib_benchmarks_filtered_cprofile, name='read file', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(count, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='count', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(count_index_length, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='count index length', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(mean, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='mean', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(standard_deviation, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='standard deviation', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(mean_of_sum, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='mean of columns addition', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(sum_columns, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='addition of columns', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(mean_of_product, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='mean of columns multiplication', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(product_columns, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='multiplication of columns', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(value_counts, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='value counts', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='complex arithmetic ops', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='mean of complex arithmetic ops', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(groupby_statistics, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='groupby statistics', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(join_count, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='join count', other=other, profile_data=joblib_filtered_profile_data)
benchmark_cprofile(join_data, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='join', other=other, profile_data=joblib_filtered_profile_data)
# Out:
# read file took: 1.8703 seconds
#          1787 function calls (1776 primitive calls) in 1.870 seconds
#
#    Ordered by: cumulative time
#    List reduced from 354 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.870    1.870 /var/tmp/ipykernel_3248/3012487071.py:6(read_file_parquet)
#         1    0.000    0.000    1.870    1.870 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:433(read_parquet)
#         1    0.003    0.003    1.870    1.870 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201(read)
#         1    0.000    0.000    1.151    1.151 {method 'to_pandas' of 'pyarrow.lib._PandasConvertible' objects}
#         1    0.000    0.000    1.151    1.151 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756(table_to_blockmanager)
#         1    0.000    0.000    1.149    1.149 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1109(_table_to_blocks)
#         1    1.149    1.149    1.149    1.149 {pyarrow.lib.table_to_blocks}
#         1    0.000    0.000    0.715    0.715 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1551(read_table)
#         1    0.000    0.000    0.713    0.713 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440(read)
#         1    0.713    0.713    0.713    0.713 {method 'to_table' of 'pyarrow._dataset.Dataset' objects}
#         1    0.001    0.001    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377(__init__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:858(_deserialize_column_index)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:195(new_meth)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:495(from_tuples)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:429(from_arrays)
#
#
# count took: 0.0000 seconds
#          9 function calls (7 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/3012487071.py:9(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352(__len__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          7 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/3012487071.py:12(count_index_length)
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# mean took: 0.0030 seconds
#          285 function calls (280 primitive calls) in 0.003 seconds
#
#    Ordered by: cumulative time
#    List reduced from 117 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.003    0.003 /var/tmp/ipykernel_3248/3012487071.py:15(mean)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         4    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258(_get_values)
#         2    0.000    0.000    0.001    0.001 {method 'sum' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45(_sum)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214(_maybe_get_mask)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:61(isna)
#
#
# standard deviation took: 0.0050 seconds
#          279 function calls (278 primitive calls) in 0.005 seconds
#
#    Ordered by: cumulative time
#    List reduced from 90 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.005    0.005 /var/tmp/ipykernel_3248/3012487071.py:18(standard_deviation)
#         1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10610(std)
#         1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10317(std)
#         1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271(_stat_function_ddof)
#         1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#       2/1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838(nanstd)
#         1    0.000    0.000    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.001    0.001    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877(nanvar)
#         1    0.001    0.001    0.001    0.001 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258(_get_values)
#         4    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         3    0.000    0.000    0.001    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214(_maybe_get_mask)
#         3    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45(_sum)
#
#
# mean of columns addition took: 0.0028 seconds
#          516 function calls (513 primitive calls) in 0.003 seconds
#
#    Ordered by: cumulative time
#    List reduced from 169 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.003    0.003 /var/tmp/ipykernel_3248/3012487071.py:21(mean_of_sum)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.001    0.001    0.001    0.001 {built-in method _operator.add}
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#
#
# addition of columns took: 0.0012 seconds
#          299 function calls (297 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 116 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_3248/3012487071.py:24(sum_columns)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.001    0.001    0.001    0.001 {built-in method _operator.add}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#        57    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#
#
# mean of columns multiplication took: 0.0020 seconds
#          455 function calls (453 primitive calls) in 0.002 seconds
#
#    Ordered by: cumulative time
#    List reduced from 157 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 /var/tmp/ipykernel_3248/3012487071.py:29(mean_of_product)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         3    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#
#
# multiplication of columns took: 0.0009 seconds
#          299 function calls (297 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 116 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_3248/3012487071.py:32(product_columns)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.001    0.001    0.001    0.001 {built-in method _operator.mul}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#        57    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#
#
# value counts took: 0.0098 seconds
#          568 function calls (564 primitive calls) in 0.010 seconds
#
#    Ordered by: cumulative time
#    List reduced from 156 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.010    0.010 /var/tmp/ipykernel_3248/3012487071.py:37(value_counts)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/base.py:874(value_counts)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796(value_counts)
#         1    0.009    0.009    0.009    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876(value_counts_arraylike)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/util/_decorators.py:302(wrapper)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258(sort_values)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343(nargsort)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:6279(ensure_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375(__new__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#       135    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931(new_block)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:103(_ensure_data)
#         6    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#
#
# complex arithmetic ops took: 0.0748 seconds
#          6642 function calls (6583 primitive calls) in 0.075 seconds
#
#    Ordered by: cumulative time
#    List reduced from 203 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.075    0.075 /var/tmp/ipykernel_3248/3012487071.py:41(complicated_arithmetic_operation)
#         8    0.000    0.000    0.056    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.051    0.006    0.056    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.019    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.019    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        19    0.000    0.000    0.017    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#        19    0.000    0.000    0.016    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.016    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.016    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         6    0.000    0.000    0.007    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#         6    0.006    0.001    0.006    0.001 {built-in method _operator.truediv}
#         7    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         7    0.005    0.001    0.005    0.001 {built-in method _operator.mul}
#         2    0.000    0.000    0.003    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:98(__sub__)
#         2    0.003    0.001    0.003    0.001 {built-in method _operator.sub}
#
#
# mean of complex arithmetic ops took: 0.0698 seconds
#          6554 function calls (6499 primitive calls) in 0.070 seconds
#
#    Ordered by: cumulative time
#    List reduced from 226 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.070    0.070 /var/tmp/ipykernel_3248/3012487071.py:52(mean_of_complicated_arithmetic_operation)
#         8    0.000    0.000    0.052    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.049    0.006    0.052    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.017    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.017    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        19    0.000    0.000    0.014    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#        19    0.000    0.000    0.014    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.014    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.014    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         7    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         7    0.005    0.001    0.005    0.001 {built-in method _operator.mul}
#         6    0.000    0.000    0.004    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#         2    0.000    0.000    0.003    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:98(__sub__)
#         6    0.003    0.001    0.003    0.001 {built-in method _operator.truediv}
#         2    0.003    0.001    0.003    0.001 {built-in method _operator.sub}
#
#
# groupby statistics took: 0.0535 seconds
#          4084 function calls (4030 primitive calls) in 0.053 seconds
#
#    Ordered by: cumulative time
#    List reduced from 456 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.053    0.053 /var/tmp/ipykernel_3248/3012487071.py:62(groupby_statistics)
#         1    0.000    0.000    0.053    0.053 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:964(aggregate)
#         1    0.000    0.000    0.053    0.053 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:143(agg)
#         1    0.000    0.000    0.053    0.053 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405(agg_dict_like)
#         1    0.000    0.000    0.052    0.052 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:435(<dictcomp>)
#       6/2    0.000    0.000    0.052    0.026 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:225(aggregate)
#         2    0.000    0.000    0.052    0.026 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278(_aggregate_multiple_funcs)
#         2    0.000    0.000    0.032    0.016 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1634(mean)
#         2    0.000    0.000    0.032    0.016 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:322(_cython_agg_general)
#         2    0.000    0.000    0.031    0.016 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:338(array_func)
#         2    0.000    0.000    0.031    0.016 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:991(_cython_operation)
#         2    0.000    0.000    0.019    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:631(cython_operation)
#         2    0.000    0.000    0.019    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:488(_cython_op_ndim_compat)
#         2    0.018    0.009    0.019    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:525(_call_cython_op)
#         2    0.000    0.000    0.018    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1723(std)
#
#
# join count took: 0.0326 seconds
#          3180 function calls (3157 primitive calls) in 0.033 seconds
#
#    Ordered by: cumulative time
#    List reduced from 308 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.033    0.033 /var/tmp/ipykernel_3248/3012487071.py:74(join_count)
#         1    0.000    0.000    0.033    0.033 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.033    0.033 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.032    0.032 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.022    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:944(_get_join_info)
#         1    0.000    0.000    0.022    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:198(join)
#         1    0.000    0.000    0.022    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:3918(join)
#         1    0.018    0.018    0.018    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018(is_unique)
#         1    0.000    0.000    0.010    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#     75/67    0.000    0.000    0.008    0.000 {built-in method builtins.all}
#        11    0.000    0.000    0.008    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#        22    0.000    0.000    0.008    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.008    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#         8    0.000    0.000    0.008    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        16    0.001    0.000    0.008    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#
#
# join took: 0.0078 seconds
#          3134 function calls (3114 primitive calls) in 0.008 seconds
#
#    Ordered by: cumulative time
#    List reduced from 300 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.008    0.008 /var/tmp/ipykernel_3248/3012487071.py:77(join_data)
#         1    0.000    0.000    0.008    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.008    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.008    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#     75/67    0.000    0.000    0.006    0.000 {built-in method builtins.all}
#        11    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#        22    0.000    0.000    0.006    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#         8    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        16    0.000    0.000    0.006    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#         3    0.000    0.000    0.005    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:670(<lambda>)
#         3    0.000    0.000    0.005    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221(_isna_array)
#         3    0.000    0.000    0.005    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259(_isna_string_dtype)
#         3    0.004    0.001    0.004    0.001 {built-in method pandas._libs.missing.isnaobj}
# 0.0077742700000271725

# %%
#Concatenate results
df_filtered_profile_all = pd.concat(joblib_filtered_profile_data, ignore_index=True)

# %%
print_profile_per_task(joblib_filtered_profile_data, metric='percall', top_n=25)
# Out:
# ============================================================
# Tarefa: read file
# Top 25 funções por 'percall':
#
#                                                                                                  function  percall
#                                                                       ~:0 (<pyarrow.lib.table_to_blocks>) 1.148966
#                                           ~:0 (<method 'to_table' of 'pyarrow._dataset.Dataset' objects>) 0.713075
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201 (read) 0.003179
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377 (__init__) 0.001340
#                              /opt/conda/envs/cdle/lib/python3.7/importlib/__init__.py:109 (import_module) 0.000494
#                                                                           ~:0 (<built-in method io.open>) 0.000290
#                                                               ~:0 (<built-in method builtins.isinstance>) 0.000093
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:1073 (_engine) 0.000088
#                                                            ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000076
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/base.py:425 (find) 0.000073
#                            ~:0 (<method 'make_fragment' of 'pyarrow._dataset.ParquetFileFormat' objects>) 0.000069
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756 (table_to_blockmanager) 0.000056
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:794 (_get_extension_dtypes) 0.000048
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440 (read) 0.000047
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1130 (<listcomp>) 0.000046
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:858 (_deserialize_column_index) 0.000045
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000043
#                            ~:0 (<method 'factorize' of 'pandas._libs.hashtable.StringHashTable' objects>) 0.000043
#                                                                      ~:0 (<built-in method builtins.len>) 0.000040
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000039
#                                    ~:0 (<method 'to_pandas' of 'pyarrow.lib._PandasConvertible' objects>) 0.000038
#                                       /opt/conda/envs/cdle/lib/python3.7/json/decoder.py:343 (raw_decode) 0.000034
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.000034
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/api.py:34 (make_block) 0.000033
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:683 (_reconstruct_block) 0.000029
#
# ============================================================
# Tarefa: count
# Top 25 funções por 'percall':
#
#                                                                                   function  percall
#                                                       ~:0 (<built-in method builtins.len>) 0.000007
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352 (__len__) 0.000006
#                                            /var/tmp/ipykernel_3248/3012487071.py:9 (count) 0.000003
#                                                  ~:0 (<built-in method time.perf_counter>) 0.000002
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000002
#                                     ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ============================================================
# Tarefa: count index length
# Top 25 funções por 'percall':
#
#                                                                                   function  percall
#                              /var/tmp/ipykernel_3248/3012487071.py:12 (count_index_length) 0.000004
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000002
#                                                  ~:0 (<built-in method time.perf_counter>) 0.000001
#                                                       ~:0 (<built-in method builtins.len>) 0.000000
#                                     ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ============================================================
# Tarefa: mean
# Top 25 funções por 'percall':
#
#                                                                                                             function  percall
#                                                                     ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.001384
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.001130
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:224 (_rebuild_blknos_and_blklocs) 0.000032
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000020
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000019
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000018
#                                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000015
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000015
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3876 (_get_item_cache) 0.000015
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000014
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000013
#                                                                                 ~:0 (<built-in method numpy.arange>) 0.000012
#                                                                      /var/tmp/ipykernel_3248/3012487071.py:15 (mean) 0.000012
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:977 (iget) 0.000011
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368 (mean) 0.000011
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000010
#                                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000010
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000010
#                                                                          ~:0 (<built-in method builtins.isinstance>) 0.000009
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000009
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000008
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000008
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:87 (<genexpr>) 0.000007
#                                                 ~:0 (<method 'get_loc' of 'pandas._libs.index.IndexEngine' objects>) 0.000007
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3860 (_box_col_values) 0.000007
#
# ============================================================
# Tarefa: standard deviation
# Top 25 funções por 'percall':
#
#                                                                                            function  percall
#                                                    ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.001276
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877 (nanvar) 0.001164
#                                                    ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000820
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000763
#                       ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000708
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838 (nanstd) 0.000017
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000017
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000012
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000011
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271 (_stat_function_ddof) 0.000009
#                                                         ~:0 (<built-in method builtins.isinstance>) 0.000009
#                                       /var/tmp/ipykernel_3248/3012487071.py:18 (standard_deviation) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000008
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000008
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10317 (std) 0.000008
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000008
#                                                          <__array_function__ internals>:2 (putmask) 0.000008
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000007
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000007
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000007
#                                                     ~:0 (<method 'sum' of 'numpy.ndarray' objects>) 0.000006
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000006
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:353 (_wrap_results) 0.000006
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000005
#
# ============================================================
# Tarefa: mean of columns addition
# Top 25 funções por 'percall':
#
#                                                                                              function  percall
#                                                                 ~:0 (<built-in method _operator.add>) 0.001452
#                                                      ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000570
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000225
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000027
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000018
#                                                           ~:0 (<built-in method builtins.isinstance>) 0.000017
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000016
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000015
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000014
#                                                /var/tmp/ipykernel_3248/3012487071.py:21 (mean_of_sum) 0.000013
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000013
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000012
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3876 (_get_item_cache) 0.000010
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90 (__add__) 0.000010
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:977 (iget) 0.000009
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000009
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000009
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000009
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000008
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000008
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000008
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000008
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000007
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185 (arithmetic_op) 0.000007
#
# ============================================================
# Tarefa: addition of columns
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#                                                                  ~:0 (<built-in method _operator.add>) 0.000928
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000014
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000013
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000012
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000009
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000008
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000006
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000006
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000006
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
#                                                 /var/tmp/ipykernel_3248/3012487071.py:24 (sum_columns) 0.000005
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000005
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000005
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000005
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000005
#                                                                   ~:0 (<built-in method builtins.len>) 0.000005
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000004
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000004
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000004
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000004
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/__init__.py:151 (align_method_SERIES) 0.000004
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:577 (name) 0.000004
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000004
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000004
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:371 (to_numpy) 0.000003
#
# ============================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por 'percall':
#
#                                                                                             function  percall
#                                                     ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000741
#                                                                ~:0 (<built-in method _operator.mul>) 0.000620
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000201
#                                                          ~:0 (<built-in method builtins.isinstance>) 0.000024
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000015
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000014
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000013
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000012
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000011
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000011
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000009
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000009
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000008
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000007
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:673 (is_integer_dtype) 0.000007
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000007
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000007
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000007
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000007
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000007
#                                           /var/tmp/ipykernel_3248/3012487071.py:29 (mean_of_product) 0.000007
#                                                             ~:0 (<built-in method builtins.getattr>) 0.000007
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000006
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000005
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000005
#
# ============================================================
# Tarefa: multiplication of columns
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#                                                                  ~:0 (<built-in method _operator.mul>) 0.000677
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000013
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000011
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000009
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000008
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000006
#                                                               ~:0 (<built-in method builtins.getattr>) 0.000006
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000005
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000005
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000005
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000005
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1737 (<genexpr>) 0.000004
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000004
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:565 (_get_root) 0.000004
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000004
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000004
#                                             /var/tmp/ipykernel_3248/3012487071.py:32 (product_columns) 0.000004
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000004
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000004
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000004
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000003
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:631 (_info_axis) 0.000003
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000003
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3876 (_get_item_cache) 0.000003
#
# ============================================================
# Tarefa: value counts
# Top 25 funções por 'percall':
#
#                                                                                                function  percall
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876 (value_counts_arraylike) 0.009270
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343 (nargsort) 0.000031
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000028
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000024
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258 (sort_values) 0.000022
#                                                     ~:0 (<method 'argsort' of 'numpy.ndarray' objects>) 0.000021
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000020
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796 (value_counts) 0.000018
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000014
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4587 (__getitem__) 0.000013
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000011
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:605 (_simple_new) 0.000011
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000010
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000009
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000008
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:183 (_reconstruct_data) 0.000008
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000007
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:6279 (ensure_index) 0.000007
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000007
#                                                              <__array_function__ internals>:2 (nonzero) 0.000007
#                                                                    ~:0 (<built-in method builtins.len>) 0.000007
#                                                                ~:0 (<built-in method builtins.hasattr>) 0.000007
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000007
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000006
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000006
#
# ============================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                          function  percall
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.051271
#                                                         ~:0 (<built-in method _operator.truediv>) 0.006300
#                                                             ~:0 (<built-in method _operator.mul>) 0.004756
#                                                             ~:0 (<built-in method _operator.sub>) 0.002955
#                                                  ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.002318
#                                                             ~:0 (<built-in method _operator.pow>) 0.001025
#                                                             ~:0 (<built-in method _operator.add>) 0.000852
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/roperator.py:12 (rsub) 0.000343
#                                                       ~:0 (<built-in method builtins.isinstance>) 0.000311
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000296
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000180
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000152
#                       /var/tmp/ipykernel_3248/3012487071.py:41 (complicated_arithmetic_operation) 0.000135
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000130
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000114
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000113
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000102
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000099
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000098
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000095
#                                                          ~:0 (<built-in method builtins.getattr>) 0.000082
#                                                              ~:0 (<built-in method builtins.len>) 0.000072
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000071
#                                                          ~:0 (<built-in method builtins.hasattr>) 0.000067
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000064
#
# ============================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                          function  percall
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.048845
#                                                             ~:0 (<built-in method _operator.mul>) 0.005130
#                                                         ~:0 (<built-in method _operator.truediv>) 0.003102
#                                                             ~:0 (<built-in method _operator.sub>) 0.002966
#                                                             ~:0 (<built-in method _operator.pow>) 0.001293
#                                                             ~:0 (<built-in method _operator.add>) 0.000899
#                                                  ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000881
#                                                  ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000768
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000498
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/roperator.py:12 (rsub) 0.000457
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000293
#                                                       ~:0 (<built-in method builtins.isinstance>) 0.000273
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000184
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000134
#               /var/tmp/ipykernel_3248/3012487071.py:52 (mean_of_complicated_arithmetic_operation) 0.000133
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000124
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000116
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000100
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000099
#                                                          ~:0 (<built-in method builtins.getattr>) 0.000099
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000098
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000094
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000086
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000074
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000074
#
# ============================================================
# Tarefa: groupby statistics
# Top 25 funções por 'percall':
#
#                                                                                                        function  percall
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:525 (_call_cython_op) 0.018498
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2790 (_get_cythonized_result) 0.017781
#                                   ~:0 (<method 'factorize' of 'pandas._libs.hashtable.Int64HashTable' objects>) 0.010017
#                                                                  ~:0 (<pandas._libs.algos.take_1d_int64_int64>) 0.001458
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:571 (factorize) 0.000440
#                                                                  ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000207
#                                                                     ~:0 (<built-in method builtins.isinstance>) 0.000192
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000186
#                                                                          ~:0 (<pandas._libs.algos.ensure_int8>) 0.000101
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000090
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278 (_aggregate_multiple_funcs) 0.000080
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000076
#                                                                        ~:0 (<built-in method builtins.hasattr>) 0.000064
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000061
#                                                                            ~:0 (<built-in method builtins.len>) 0.000059
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1811 (_form_blocks) 0.000057
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:680 (get_grouper) 0.000056
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000055
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405 (agg_dict_like) 0.000053
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000048
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:846 (__init__) 0.000047
#                                                                        ~:0 (<built-in method builtins.getattr>) 0.000046
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_asarray.py:14 (asarray) 0.000041
#                                                           <frozen importlib._bootstrap>:1009 (_handle_fromlist) 0.000041
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:322 (_cython_agg_general) 0.000039
#
# ============================================================
# Tarefa: join count
# Top 25 funções por 'percall':
#
#                                                                                                                       function  percall
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.017633
#                                                                           ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.005567
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.004401
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.000927
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259 (_isna_string_dtype) 0.000686
#                                                                                    ~:0 (<built-in method builtins.isinstance>) 0.000158
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:665 (<lambda>) 0.000135
#                                                                               ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000112
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000087
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000086
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000066
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000065
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000062
#                                                                                 ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000052
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000050
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:327 (_inner_indexer) 0.000048
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:517 (_take_preprocess_indexer_and_fill_value) 0.000044
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711 (get_result) 0.000041
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000039
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000038
#                                                                                           ~:0 (<built-in method builtins.all>) 0.000038
#                                                                                            ~:0 (<built-in method numpy.empty>) 0.000037
#                                                                               ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000037
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000037
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000036
#
# ============================================================
# Tarefa: join
# Top 25 funções por 'percall':
#
#                                                                                                           function  percall
#                                                               ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.004457
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:665 (<lambda>) 0.000509
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.000336
#                                                                   ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000152
#                                                                        ~:0 (<built-in method builtins.isinstance>) 0.000106
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000081
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000058
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000057
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000055
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000047
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000047
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000042
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000038
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259 (_isna_string_dtype) 0.000036
#                                                                               ~:0 (<built-in method builtins.all>) 0.000033
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000032
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000032
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000030
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:190 (is_sparse) 0.000029
#                                                                   ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000027
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607 (<genexpr>) 0.000026
#                                                                                ~:0 (<built-in method numpy.empty>) 0.000026
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711 (get_result) 0.000025
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:327 (_inner_indexer) 0.000025
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/base.py:425 (find) 0.000025

# %% [markdown]
# **Operations with cache**

# %% [markdown]
# To simulate a realistic scenario where filtered data is reused across tasks (e.g., in iterative workflows or pipelines), the  joblib.Memory was used to cache intermediate results.
#
# For this process we:
#
# - Set up a cache directory (joblib_cache) where joblib stores memoized outputs.
#
# - Defined a function get_filtered_data(df) to wrap the already-filtered DataFrame.
#
# - Decorated it with @memory.cache, so that if the same input is passed again, the cached version is reused, avoiding recomputation.
#
# This simulates "cached data" behavior, often found in pipelines or repeated analytics tasks.
#
# Then a list of parallel tasks was built using this cached DataFrame (joblib_cache) and benchmarked them using the same benchmark_joblib function.

# %%
from joblib import Memory

# Setup a directory where joblib will store cached results
memory = Memory(location='joblib_cache', verbose=0)

# Wrap the filtering logic (or any intermediate result) in a cached function
@memory.cache
def get_filtered_data(df):
    return df       # In this case, df is already filtered, so we just return it

# Apply the cached function to the filtered DataFrame
joblib_cache = get_filtered_data(joblib_filtered)

# %%
# === Define task list using the cached data ===
tasks_cache = [
    (read_file_parquet, None, {}, "read file"),
    (count, joblib_cache, {}, "count"),
    (count_index_length, joblib_cache, {}, "count index length"),
    (mean, joblib_cache, {}, "mean"),
    (standard_deviation, joblib_cache, {}, "standard deviation"),
    (mean_of_sum, joblib_cache, {}, "mean of columns addition"),
    (sum_columns, joblib_cache, {}, "addition of columns"),
    (mean_of_product, joblib_cache, {}, "mean of columns multiplication"),
    (product_columns, joblib_cache, {}, "multiplication of columns"),
    (value_counts, joblib_cache, {}, "value counts"),
    (complicated_arithmetic_operation, joblib_cache, {}, "complex arithmetic ops"),
    (mean_of_complicated_arithmetic_operation, joblib_cache, {}, "mean of complex arithmetic ops"),
    (groupby_statistics, joblib_cache, {}, "groupby statistics"),
    (join_count, joblib_cache, {'other': other}, "join count"),
    (join_data, joblib_cache, {'other': other}, "join"),
]

# %%
# Run the Joblib benchmark using cached data (simulating in-memory reuse)
df_results_cache = benchmark_joblib(tasks_cache, n_jobs=-1, save_path='Results_Joblib_M/joblib_cache_local_medium')
print(df_results_cache)
# Out:
# O arquivo Parquet foi salvo em Results_Joblib_M/joblib_cache_local_medium.
#                                 duration
# task
# read file                       1.881270
# count                           0.000006
# count index length              0.000005
# mean                            0.002620
# standard deviation              0.005816
# mean of columns addition        0.003850
# addition of columns             0.001683
# mean of columns multiplication  0.003560
# multiplication of columns       0.002343
# value counts                    0.005712
# complex arithmetic ops          0.048858
# mean of complex arithmetic ops  0.063325
# groupby statistics              0.022798
# join count                      0.028350
# join                            0.033769

# %% [markdown]
# **Cache with cProfile**
#
# In this part of the report, cProfile is used to benchmark the performance of several data operations on a cached version of the filtered DataFrame (joblib_cache). By profiling each function individually, it's possible to identify bottlenecks and analyze which tasks are the most computationally expensive in terms of time per call and cumulative execution time.

# %%
# === Benchmarks with cProfile using cached filtered data ===
joblib_benchmarks_cache_cprofile = {'duration': [], 'task': []}
joblib_cache_profile_data = []

# %%
# Execute benchmarks with cProfile
benchmark_cprofile(read_file_parquet, df=None, benchmarks=joblib_benchmarks_cache_cprofile, name='read file', profile_data=joblib_cache_profile_data)
benchmark_cprofile(count, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='count', profile_data=joblib_cache_profile_data)
benchmark_cprofile(count_index_length, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='count index length', profile_data=joblib_cache_profile_data)
benchmark_cprofile(mean, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='mean', profile_data=joblib_cache_profile_data)
benchmark_cprofile(standard_deviation, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='standard deviation', profile_data=joblib_cache_profile_data)
benchmark_cprofile(mean_of_sum, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='mean of columns addition', profile_data=joblib_cache_profile_data)
benchmark_cprofile(sum_columns, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='addition of columns', profile_data=joblib_cache_profile_data)
benchmark_cprofile(mean_of_product, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='mean of columns multiplication', profile_data=joblib_cache_profile_data)
benchmark_cprofile(product_columns, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='multiplication of columns', profile_data=joblib_cache_profile_data)
benchmark_cprofile(value_counts, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='value counts', profile_data=joblib_cache_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='complex arithmetic ops', profile_data=joblib_cache_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='mean of complex arithmetic ops', profile_data=joblib_cache_profile_data)
benchmark_cprofile(groupby_statistics, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='groupby statistics', profile_data=joblib_cache_profile_data)
benchmark_cprofile(join_count, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='join count', other=other, profile_data=joblib_cache_profile_data)
benchmark_cprofile(join_data, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='join', other=other, profile_data=joblib_cache_profile_data)
# Out:
# read file took: 1.5131 seconds
#          1787 function calls (1776 primitive calls) in 1.513 seconds
#
#    Ordered by: cumulative time
#    List reduced from 354 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.513    1.513 /var/tmp/ipykernel_3248/3012487071.py:6(read_file_parquet)
#         1    0.000    0.000    1.513    1.513 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:433(read_parquet)
#         1    0.004    0.004    1.513    1.513 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201(read)
#         1    0.000    0.000    0.956    0.956 {method 'to_pandas' of 'pyarrow.lib._PandasConvertible' objects}
#         1    0.000    0.000    0.956    0.956 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756(table_to_blockmanager)
#         1    0.000    0.000    0.954    0.954 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1109(_table_to_blocks)
#         1    0.953    0.953    0.953    0.953 {pyarrow.lib.table_to_blocks}
#         1    0.000    0.000    0.553    0.553 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1551(read_table)
#         1    0.000    0.000    0.551    0.551 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440(read)
#         1    0.550    0.550    0.550    0.550 {method 'to_table' of 'pyarrow._dataset.Dataset' objects}
#         1    0.002    0.002    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377(__init__)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:858(_deserialize_column_index)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:195(new_meth)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:495(from_tuples)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:429(from_arrays)
#
#
# count took: 0.0000 seconds
#          9 function calls (7 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/3012487071.py:9(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352(__len__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          7 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_3248/3012487071.py:12(count_index_length)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# mean took: 0.0020 seconds
#          184 function calls in 0.002 seconds
#
#    Ordered by: cumulative time
#    List reduced from 78 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 /var/tmp/ipykernel_3248/3012487071.py:15(mean)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258(_get_values)
#         3    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214(_maybe_get_mask)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:61(isna)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:144(_isna)
#         1    0.001    0.001    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221(_isna_array)
#
#
# standard deviation took: 0.0027 seconds
#          279 function calls (278 primitive calls) in 0.003 seconds
#
#    Ordered by: cumulative time
#    List reduced from 90 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.003    0.003 /var/tmp/ipykernel_3248/3012487071.py:18(standard_deviation)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10610(std)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10317(std)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271(_stat_function_ddof)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#       2/1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838(nanstd)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.001    0.001    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877(nanvar)
#         4    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         3    0.000    0.000    0.001    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45(_sum)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258(_get_values)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(putmask)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#
#
# mean of columns addition took: 0.0018 seconds
#          455 function calls (453 primitive calls) in 0.002 seconds
#
#    Ordered by: cumulative time
#    List reduced from 157 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 /var/tmp/ipykernel_3248/3012487071.py:21(mean_of_sum)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#
#
# addition of columns took: 0.0009 seconds
#          299 function calls (297 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 116 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_3248/3012487071.py:24(sum_columns)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.001    0.001    0.001    0.001 {built-in method _operator.add}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#        57    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#
#
# mean of columns multiplication took: 0.0015 seconds
#          455 function calls (453 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 157 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_3248/3012487071.py:29(mean_of_product)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         3    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#
#
# multiplication of columns took: 0.0006 seconds
#          299 function calls (297 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 116 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_3248/3012487071.py:32(product_columns)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.mul}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#        57    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#
#
# value counts took: 0.0055 seconds
#          567 function calls (563 primitive calls) in 0.005 seconds
#
#    Ordered by: cumulative time
#    List reduced from 155 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.005    0.005 /var/tmp/ipykernel_3248/3012487071.py:37(value_counts)
#         1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/base.py:874(value_counts)
#         1    0.000    0.000    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796(value_counts)
#         1    0.004    0.004    0.005    0.005 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876(value_counts_arraylike)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/util/_decorators.py:302(wrapper)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258(sort_values)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343(nargsort)
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:6279(ensure_index)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375(__new__)
#       135    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931(new_block)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4587(__getitem__)
#
#
# complex arithmetic ops took: 0.0472 seconds
#          6398 function calls (6343 primitive calls) in 0.047 seconds
#
#    Ordered by: cumulative time
#    List reduced from 190 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.047    0.047 /var/tmp/ipykernel_3248/3012487071.py:41(complicated_arithmetic_operation)
#         8    0.000    0.000    0.035    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.033    0.004    0.035    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.012    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.012    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        19    0.000    0.000    0.010    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#        19    0.000    0.000    0.010    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.010    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.010    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         7    0.000    0.000    0.004    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         6    0.000    0.000    0.004    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#         7    0.003    0.000    0.003    0.000 {built-in method _operator.mul}
#         6    0.003    0.001    0.003    0.001 {built-in method _operator.truediv}
#         2    0.000    0.000    0.002    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:98(__sub__)
#        28    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#
#
# mean of complex arithmetic ops took: 0.0540 seconds
#          6554 function calls (6499 primitive calls) in 0.054 seconds
#
#    Ordered by: cumulative time
#    List reduced from 226 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.054    0.054 /var/tmp/ipykernel_3248/3012487071.py:52(mean_of_complicated_arithmetic_operation)
#         8    0.000    0.000    0.035    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.032    0.004    0.035    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.018    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.018    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        19    0.000    0.000    0.016    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#        19    0.000    0.000    0.016    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.016    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.016    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         6    0.000    0.000    0.009    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#         6    0.008    0.001    0.008    0.001 {built-in method _operator.truediv}
#         7    0.000    0.000    0.005    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         7    0.004    0.001    0.004    0.001 {built-in method _operator.mul}
#        28    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         2    0.000    0.000    0.002    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:98(__sub__)
#
#
# groupby statistics took: 0.0236 seconds
#          4022 function calls (3968 primitive calls) in 0.024 seconds
#
#    Ordered by: cumulative time
#    List reduced from 446 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.024    0.024 /var/tmp/ipykernel_3248/3012487071.py:62(groupby_statistics)
#         1    0.000    0.000    0.023    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:964(aggregate)
#         1    0.000    0.000    0.023    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:143(agg)
#         1    0.000    0.000    0.023    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405(agg_dict_like)
#         1    0.000    0.000    0.022    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:435(<dictcomp>)
#       6/2    0.000    0.000    0.022    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:225(aggregate)
#         2    0.000    0.000    0.022    0.011 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278(_aggregate_multiple_funcs)
#         2    0.000    0.000    0.012    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1634(mean)
#         2    0.000    0.000    0.012    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:322(_cython_agg_general)
#         2    0.000    0.000    0.012    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:338(array_func)
#         2    0.000    0.000    0.012    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:991(_cython_operation)
#         2    0.000    0.000    0.008    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1723(std)
#         2    0.008    0.004    0.008    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2790(_get_cythonized_result)
#         2    0.000    0.000    0.007    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:631(cython_operation)
#         2    0.000    0.000    0.007    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:488(_cython_op_ndim_compat)
#
#
# join count took: 0.0084 seconds
#          3139 function calls (3117 primitive calls) in 0.008 seconds
#
#    Ordered by: cumulative time
#    List reduced from 301 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.008    0.008 /var/tmp/ipykernel_3248/3012487071.py:74(join_count)
#         1    0.000    0.000    0.008    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.008    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.008    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.008    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#     75/67    0.000    0.000    0.006    0.000 {built-in method builtins.all}
#        11    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#        22    0.000    0.000    0.006    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#         8    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        16    0.001    0.000    0.006    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#         3    0.000    0.000    0.005    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:670(<lambda>)
#         3    0.000    0.000    0.005    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221(_isna_array)
#         3    0.000    0.000    0.004    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259(_isna_string_dtype)
#         3    0.004    0.001    0.004    0.001 {built-in method pandas._libs.missing.isnaobj}
#
#
# join took: 0.0077 seconds
#          3134 function calls (3114 primitive calls) in 0.008 seconds
#
#    Ordered by: cumulative time
#    List reduced from 300 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.008    0.008 /var/tmp/ipykernel_3248/3012487071.py:77(join_data)
#         1    0.000    0.000    0.008    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.008    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.008    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#     75/67    0.000    0.000    0.006    0.000 {built-in method builtins.all}
#        11    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#        22    0.000    0.000    0.006    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#         8    0.000    0.000    0.006    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        16    0.001    0.000    0.006    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#         3    0.000    0.000    0.005    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:670(<lambda>)
#         3    0.000    0.000    0.005    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221(_isna_array)
#         3    0.000    0.000    0.005    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259(_isna_string_dtype)
#         3    0.005    0.002    0.005    0.002 {built-in method pandas._libs.missing.isnaobj}
# 0.007664640000029976

# %%
# Concatenate all results
df_cache_profile_all = pd.concat(joblib_cache_profile_data, ignore_index=True)

# %%
print_profile_per_task(joblib_cache_profile_data, metric='percall', top_n=25)
# Out:
# ============================================================
# Tarefa: read file
# Top 25 funções por 'percall':
#
#                                                                                                   function  percall
#                                                                        ~:0 (<pyarrow.lib.table_to_blocks>) 0.953218
#                                            ~:0 (<method 'to_table' of 'pyarrow._dataset.Dataset' objects>) 0.550454
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201 (read) 0.003886
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377 (__init__) 0.001989
#                                                             ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000205
#                                                                ~:0 (<built-in method builtins.isinstance>) 0.000112
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:1073 (_engine) 0.000093
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440 (read) 0.000064
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000062
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756 (table_to_blockmanager) 0.000062
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/api.py:34 (make_block) 0.000059
#                                                                            ~:0 (<built-in method io.open>) 0.000057
#                             ~:0 (<method 'make_fragment' of 'pyarrow._dataset.ParquetFileFormat' objects>) 0.000055
#                                        /opt/conda/envs/cdle/lib/python3.7/json/decoder.py:343 (raw_decode) 0.000053
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1130 (<listcomp>) 0.000050
#                                     ~:0 (<method 'to_pandas' of 'pyarrow.lib._PandasConvertible' objects>) 0.000049
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:794 (_get_extension_dtypes) 0.000049
#                                                                       ~:0 (<built-in method builtins.len>) 0.000045
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:858 (_deserialize_column_index) 0.000043
#                             ~:0 (<method 'factorize' of 'pandas._libs.hashtable.StringHashTable' objects>) 0.000041
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:571 (factorize) 0.000039
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.000039
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/base.py:425 (find) 0.000037
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1968 (sequence_to_dt64ns) 0.000037
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:361 (__init__) 0.000036
#
# ============================================================
# Tarefa: count
# Top 25 funções por 'percall':
#
#                                                                                   function  percall
#                                                       ~:0 (<built-in method builtins.len>) 0.000008
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352 (__len__) 0.000005
#                                            /var/tmp/ipykernel_3248/3012487071.py:9 (count) 0.000002
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000002
#                                                  ~:0 (<built-in method time.perf_counter>) 0.000001
#                                     ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ============================================================
# Tarefa: count index length
# Top 25 funções por 'percall':
#
#                                                                                   function  percall
#                              /var/tmp/ipykernel_3248/3012487071.py:12 (count_index_length) 0.000003
#                                                  ~:0 (<built-in method time.perf_counter>) 0.000002
#                                                       ~:0 (<built-in method builtins.len>) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000001
#                                     ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ============================================================
# Tarefa: mean
# Top 25 funções por 'percall':
#
#                                                                                                                 function  percall
#                                                                         ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000989
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000788
#                                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000014
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000013
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000013
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000013
#                                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000011
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000009
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000009
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000009
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000008
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000007
#                                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000007
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000007
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000006
#                                                                          /var/tmp/ipykernel_3248/3012487071.py:15 (mean) 0.000006
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214 (_maybe_get_mask) 0.000006
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:144 (_isna) 0.000005
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000005
#                                                                          ~:0 (<method 'sum' of 'numpy.ndarray' objects>) 0.000005
#                                                                              ~:0 (<built-in method builtins.isinstance>) 0.000005
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:673 (is_integer_dtype) 0.000005
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1141 (needs_i8_conversion) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4638 (_can_hold_identifiers_and_holds_name) 0.000004
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:433 (__enter__) 0.000004
#
# ============================================================
# Tarefa: standard deviation
# Top 25 funções por 'percall':
#
#                                                                                                      function  percall
#                                                              ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000708
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877 (nanvar) 0.000655
#                                 ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000381
#                                                              ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000362
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000307
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000016
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000016
#                                                                   ~:0 (<built-in method builtins.isinstance>) 0.000013
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000012
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838 (nanstd) 0.000011
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000010
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:61 (isna) 0.000009
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000009
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000009
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271 (_stat_function_ddof) 0.000008
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000008
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000007
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000007
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000006
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000005
#                                                                    <__array_function__ internals>:2 (putmask) 0.000005
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1585 (_ensure_numeric) 0.000005
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:87 (<genexpr>) 0.000005
#                                                               ~:0 (<method 'sum' of 'numpy.ndarray' objects>) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1420 (is_extension_array_dtype) 0.000004
#
# ============================================================
# Tarefa: mean of columns addition
# Top 25 funções por 'percall':
#
#                                                                                              function  percall
#                                                                 ~:0 (<built-in method _operator.add>) 0.000603
#                                                      ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000459
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000191
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000022
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000021
#                                                           ~:0 (<built-in method builtins.isinstance>) 0.000014
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000012
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000012
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000012
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000011
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000010
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000010
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000010
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000010
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000010
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000009
#                                                /var/tmp/ipykernel_3248/3012487071.py:21 (mean_of_sum) 0.000009
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000009
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000009
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000008
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000008
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000008
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000007
#                                                              ~:0 (<built-in method builtins.getattr>) 0.000007
#
# ============================================================
# Tarefa: addition of columns
# Top 25 funções por 'percall':
#
#                                                                                                        function  percall
#                                                                           ~:0 (<built-in method _operator.add>) 0.000629
#                                                                     ~:0 (<built-in method builtins.isinstance>) 0.000015
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000015
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000012
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000011
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000010
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000009
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000008
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000007
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000006
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/__init__.py:151 (align_method_SERIES) 0.000005
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185 (arithmetic_op) 0.000005
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000005
#                                                                        ~:0 (<built-in method builtins.getattr>) 0.000005
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000005
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000004
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2218 (is_object) 0.000004
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000004
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/inference.py:321 (is_hashable) 0.000004
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000004
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000004
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54 (new_method) 0.000004
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000004
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/missing.py:140 (dispatch_fill_zeros) 0.000004
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:441 (maybe_prepare_scalar_for_op) 0.000004
#
# ============================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por 'percall':
#
#                                                                                            function  percall
#                                                    ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000478
#                                                               ~:0 (<built-in method _operator.mul>) 0.000456
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000133
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000034
#                                                         ~:0 (<built-in method builtins.isinstance>) 0.000015
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000013
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000013
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000011
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000011
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000009
#                                          /var/tmp/ipykernel_3248/3012487071.py:29 (mean_of_product) 0.000009
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000009
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000008
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000008
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000007
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000007
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000006
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000006
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000005
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000005
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000005
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:87 (<genexpr>) 0.000004
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000004
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000004
#
# ============================================================
# Tarefa: multiplication of columns
# Top 25 funções por 'percall':
#
#                                                                                                                 function  percall
#                                                                                    ~:0 (<built-in method _operator.mul>) 0.000428
#                                                                              ~:0 (<built-in method builtins.isinstance>) 0.000014
#                                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000012
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000009
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000009
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000006
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000006
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000005
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000005
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000005
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1718 (validate_all_hashable) 0.000004
#                                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000004
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000004
#                                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000004
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/__init__.py:151 (align_method_SERIES) 0.000004
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000003
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000003
#                                                               /var/tmp/ipykernel_3248/3012487071.py:32 (product_columns) 0.000003
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54 (new_method) 0.000003
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:114 (_get_option) 0.000003
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000003
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000003
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4638 (_can_hold_identifiers_and_holds_name) 0.000003
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000003
#                                                                                 ~:0 (<built-in method builtins.hasattr>) 0.000003
#
# ============================================================
# Tarefa: value counts
# Top 25 funções por 'percall':
#
#                                                                                                function  percall
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876 (value_counts_arraylike) 0.004421
#                                                     ~:0 (<method 'argsort' of 'numpy.ndarray' objects>) 0.000442
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343 (nargsort) 0.000050
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000032
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000031
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258 (sort_values) 0.000026
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000021
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796 (value_counts) 0.000017
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4587 (__getitem__) 0.000016
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000014
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:605 (_simple_new) 0.000013
#                           ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000011
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000011
#                                                                ~:0 (<built-in method builtins.getattr>) 0.000011
#                                                                    ~:0 (<built-in method numpy.arange>) 0.000009
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:183 (_reconstruct_data) 0.000009
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000009
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000009
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000008
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000008
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000007
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/numeric.py:140 (_ensure_array) 0.000007
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000007
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1663 (dtype) 0.000007
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569 (from_array) 0.000006
#
# ============================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                              function  percall
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.032732
#                                                                 ~:0 (<built-in method _operator.mul>) 0.003160
#                                                             ~:0 (<built-in method _operator.truediv>) 0.003041
#                                                                 ~:0 (<built-in method _operator.sub>) 0.001761
#                                                                 ~:0 (<built-in method _operator.pow>) 0.000989
#                                                      ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000597
#                                                                 ~:0 (<built-in method _operator.add>) 0.000378
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000268
#                                                           ~:0 (<built-in method builtins.isinstance>) 0.000252
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/roperator.py:12 (rsub) 0.000239
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000189
#                           /var/tmp/ipykernel_3248/3012487071.py:41 (complicated_arithmetic_operation) 0.000130
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000126
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000101
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000095
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000094
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000092
#                                                              ~:0 (<built-in method builtins.getattr>) 0.000089
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000086
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000084
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000076
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000075
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000075
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000065
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000063
#
# ============================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                          function  percall
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.032441
#                                                         ~:0 (<built-in method _operator.truediv>) 0.008084
#                                                             ~:0 (<built-in method _operator.mul>) 0.004309
#                                                             ~:0 (<built-in method _operator.sub>) 0.001376
#                                                  ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000986
#                                                             ~:0 (<built-in method _operator.pow>) 0.000790
#                                                             ~:0 (<built-in method _operator.add>) 0.000516
#                                                  ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000506
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/roperator.py:12 (rsub) 0.000453
#                                                       ~:0 (<built-in method builtins.isinstance>) 0.000254
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000242
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000226
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000171
#               /var/tmp/ipykernel_3248/3012487071.py:52 (mean_of_complicated_arithmetic_operation) 0.000117
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000112
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000110
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000086
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000086
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000084
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000078
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000076
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000075
#                                                          ~:0 (<built-in method builtins.getattr>) 0.000071
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000067
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000063
#
# ============================================================
# Tarefa: groupby statistics
# Top 25 funções por 'percall':
#
#                                                                                                        function  percall
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2790 (_get_cythonized_result) 0.007795
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:525 (_call_cython_op) 0.006829
#                                   ~:0 (<method 'factorize' of 'pandas._libs.hashtable.Int64HashTable' objects>) 0.003157
#                                                                  ~:0 (<pandas._libs.algos.take_1d_int64_int64>) 0.001074
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:571 (factorize) 0.000385
#                                                                  ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000183
#                                                                     ~:0 (<built-in method builtins.isinstance>) 0.000173
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000146
#                                                                        ~:0 (<built-in method builtins.hasattr>) 0.000065
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000065
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278 (_aggregate_multiple_funcs) 0.000061
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000059
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1811 (_form_blocks) 0.000057
#                                                                            ~:0 (<pandas._libs.lib.infer_dtype>) 0.000056
#                                                                            ~:0 (<built-in method builtins.len>) 0.000055
#                                                                        ~:0 (<built-in method builtins.getattr>) 0.000049
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000043
#                                                                             ~:0 (<built-in method numpy.empty>) 0.000042
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405 (agg_dict_like) 0.000039
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000038
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:680 (get_grouper) 0.000036
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:846 (__init__) 0.000035
#                                                                             ~:0 (<built-in method numpy.array>) 0.000034
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/concat.py:626 (_make_concat_multiindex) 0.000034
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000032
#
# ============================================================
# Tarefa: join count
# Top 25 funções por 'percall':
#
#                                                                                                                       function  percall
#                                                                           ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.004407
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.000878
#                                                                               ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000143
#                                                                                    ~:0 (<built-in method builtins.isinstance>) 0.000118
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000105
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000083
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000073
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259 (_isna_string_dtype) 0.000068
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000060
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000057
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000056
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711 (get_result) 0.000050
#                                                                               ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000048
#                                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381 (is_na) 0.000047
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000045
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:517 (_take_preprocess_indexer_and_fill_value) 0.000044
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000042
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:551 (_get_empty_dtype) 0.000042
#                                                                                           ~:0 (<built-in method builtins.all>) 0.000041
#                                                                                           ~:0 (<built-in method builtins.len>) 0.000040
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585 (_is_uniform_join_units) 0.000035
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000035
#                                                                           ~:0 (<pandas._libs.algos.take_2d_axis1_int64_int64>) 0.000035
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000034
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:552 (na_value_for_dtype) 0.000033
#
# ============================================================
# Tarefa: join
# Top 25 funções por 'percall':
#
#                                                                                                                       function  percall
#                                                                           ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.004713
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.000505
#                                                                                    ~:0 (<built-in method builtins.isinstance>) 0.000110
#                                                                               ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000097
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000076
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000061
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000055
#                                                                               ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000055
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000048
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000042
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000042
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259 (_isna_string_dtype) 0.000040
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000040
#                                                                                           ~:0 (<built-in method builtins.all>) 0.000035
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000035
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:665 (<lambda>) 0.000032
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000031
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1946 (check_ndim) 0.000031
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000030
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:327 (_inner_indexer) 0.000029
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:517 (_take_preprocess_indexer_and_fill_value) 0.000029
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:552 (na_value_for_dtype) 0.000028
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:190 (is_sparse) 0.000027
#                                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381 (is_na) 0.000027
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:551 (_get_empty_dtype) 0.000026
