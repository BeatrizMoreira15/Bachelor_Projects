# %% [markdown]
# # Modin_Joblib - Large Dataset

# %% [markdown]
# **Summary of this notebook**
#
# This notebook presents a benchmarking analysis of common data processing operations using Joblib and Modin on the **large dataset**. The tasks include filtering, arithmetic operations, aggregations, groupbys, joins, and profiling with cProfile, allowing a performance comparison between the two libraries.

# %% [markdown]
# **Setup and configurations**

# %%
# Importing required packages
import pandas as pd
import pyspark
import pyarrow
import numpy as np
import os
import requests
import time
import joblib
import modin.pandas as md
from dask.distributed import Client, LocalCluster
import modin.config as cfg
from joblib import parallel_backend, Parallel, delayed
from joblib import Parallel, delayed, dump, load
import dask.dataframe as dd

# Check versions
print("pandas version:", pd.__version__)
print("pyspark version:", pyspark.__version__)
print("pyarrow version:", pyarrow.__version__)
print("numpy version:", np.__version__)
print("modin version:", md.__version__)
print("joblib version:", joblib.__version__)
# Out:
# pandas version: 1.3.5
# pyspark version: 3.4.4
# pyarrow version: 1.0.1
# numpy version: 1.19.5
# modin version: 0.12.1
# joblib version: 1.3.2

# %%
#Supress warnings to reduce output clutter
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# Modin was configured to use Dask as its execution engine, and a Dask client was started. After that, the dataset was read with Modin and basic information about the DataFrame was displayed.

# %%
# Configure Modin to use Dask
cfg.Engine.put("dask")

# %%
client = Client()

# %%
modin_data = md.read_parquet("Samples/sample_2009_2010_large_clean.parquet")

# %%
modin_data.info()
# Out:
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 119381 entries, 0 to 119380
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ---------------------  ---------------  -----
#  0   index                  119381 non-null  int64
#  1   vendor_name            119381 non-null  object
#  2   Trip_Pickup_DateTime   119381 non-null  object
#  3   Trip_Dropoff_DateTime  119381 non-null  object
#  4   Passenger_Count        119381 non-null  int64
#  5   Trip_Distance          119381 non-null  float64
#  6   Start_Lon              119381 non-null  float64
#  7   Start_Lat              119381 non-null  float64
#  8   End_Lon                119381 non-null  float64
#  9   End_Lat                119381 non-null  float64
#  10  Payment_Type           119381 non-null  object
#  11  Fare_Amt               119381 non-null  float64
#  12  surcharge              119381 non-null  float64
#  13  Tip_Amt                119381 non-null  float64
#  14  Tolls_Amt              119381 non-null  float64
#  15  Total_Amt              119381 non-null  float64
#  16  pickup_date            119381 non-null  datetime64[ns]
#  17  year_month             119381 non-null  period[M]
#  18  day                    119381 non-null  int64
# dtypes: float64(10), object(4), int64(3), datetime64[ns](1), period[M](1)
# memory usage: 17.3 MB

# %% [markdown]
# # Benchmark

# %% [markdown]
# # Modin

# %% [markdown]
# Several benchmark functions were defined to measure execution time of different operations using Modin. Then, benchmark results are stored in dictionaries for standard, filtered, and cached scenarios.

# %%
def benchmark(f, df, benchmarks, name, **kwargs):
    """Benchmark the given function against the given DataFrame.

    Parameters
    ----------
    f: function to benchmark
    df: data frame
    benchmarks: container for benchmark results
    name: task name

    Returns
    -------
    Duration (in seconds, high precision) of the given operation
    """
    start_time = time.perf_counter()  # alta precisão
    ret = f(df, **kwargs)
    duration = time.perf_counter() - start_time
    benchmarks['duration'].append(duration)
    benchmarks['task'].append(name)
    print(f"{name} took: {duration:.6f} seconds")
    return duration

def get_results(benchmarks):
    """Return a pandas DataFrame containing benchmark results."""
    return pd.DataFrame.from_dict(benchmarks)

# %%
def read_file_parquet(df=None):
    return md.read_parquet("Samples/sample_2009_2010_large_clean.parquet")

def count(df=None):
    return len(df)

def count_index_length(df=None):
    return len(df.index)

def mean(df):
    return df.Fare_Amt.mean()

def standard_deviation(df):
    return df.Fare_Amt.std()

def mean_of_sum(df):
    return (df.Fare_Amt + df.Tip_Amt).mean()

def sum_columns(df):
    x = df.Fare_Amt + df.Tip_Amt

    return x

def mean_of_product(df):
    return (df.Fare_Amt * df.Tip_Amt).mean()

def product_columns(df):
    x = df.Fare_Amt * df.Tip_Amt

    return x

def value_counts(df):
    val_counts = df.Fare_Amt.value_counts()
    return val_counts

def complicated_arithmetic_operation(df):
    theta_1 = df.Start_Lon
    phi_1 = df.Start_Lat
    theta_2 = df.End_Lon
    phi_2 = df.End_Lat
    temp = (np.sin((theta_2 - theta_1) / 2 * np.pi / 180) ** 2
           + np.cos(theta_1 * np.pi / 180) * np.cos(theta_2 * np.pi / 180) * np.sin((phi_2 - phi_1) / 2 * np.pi / 180) ** 2)
    ret = np.multiply(np.arctan2(np.sqrt(temp), np.sqrt(1-temp)),2)

    return ret

def mean_of_complicated_arithmetic_operation(df):
    theta_1 = df.Start_Lon
    phi_1 = df.Start_Lat
    theta_2 = df.End_Lon
    phi_2 = df.End_Lat
    temp = (np.sin((theta_2 - theta_1) / 2 * np.pi / 180) ** 2
           + np.cos(theta_1 * np.pi / 180) * np.cos(theta_2 * np.pi / 180) * np.sin((phi_2 - phi_1) / 2 * np.pi / 180) ** 2)
    ret = np.multiply(np.arctan2(np.sqrt(temp), np.sqrt(1-temp)),2)
    return ret.mean()

def groupby_statistics(df):
    gb = df.groupby(by='Passenger_Count').agg(
      {
        'Fare_Amt': ['mean', 'std'],
        'Tip_Amt': ['mean', 'std']
      }
    )
    return gb

other = md.DataFrame(groupby_statistics(modin_data))
other.columns = md.Index([e[0]+'_' + e[1] for e in other.columns.tolist()])

def join_count(df, other):
    return len(df.merge(other, left_index=True, right_index=True))

def join_data(df, other):
    return df.merge(other, left_index=True, right_index=True)

# %%
modin_benchmarks = {
    'duration': [],  # in seconds
    'task': [],
}

modin_benchmarks_filtered = {
    'duration': [],  # in seconds
    'task': [],
}

modin_benchmarks_cache = {
    'duration': [],  # in seconds
    'task': [],
}

# %% [markdown]
# After that, each function was benchmarked using the benchmark() utility. The tasks were applied to the Modin DataFrame.

# %%
# Execute benchmark
benchmark(read_file_parquet, df=None, benchmarks=modin_benchmarks, name='read file')
benchmark(count, df=modin_data, benchmarks=modin_benchmarks, name='count')
benchmark(count_index_length, df=modin_data, benchmarks=modin_benchmarks, name='count index length')
benchmark(mean, df=modin_data, benchmarks=modin_benchmarks, name='mean')
benchmark(standard_deviation, df=modin_data, benchmarks=modin_benchmarks, name='standard deviation')
benchmark(mean_of_sum, df=modin_data, benchmarks=modin_benchmarks, name='mean of columns addition')
benchmark(sum_columns, df=modin_data, benchmarks=modin_benchmarks, name='addition of columns')
benchmark(mean_of_product, df=modin_data, benchmarks=modin_benchmarks, name='mean of columns multiplication')
benchmark(product_columns, df=modin_data, benchmarks=modin_benchmarks, name='multiplication of columns')
benchmark(value_counts, df=modin_data, benchmarks=modin_benchmarks, name='value counts')
benchmark(complicated_arithmetic_operation, df=modin_data, benchmarks=modin_benchmarks, name='complex arithmetic ops')
benchmark(mean_of_complicated_arithmetic_operation, df=modin_data, benchmarks=modin_benchmarks, name='mean of complex arithmetic ops')
benchmark(groupby_statistics, df=modin_data, benchmarks=modin_benchmarks, name='groupby statistics')
benchmark(join_count, modin_data, benchmarks=modin_benchmarks, name='join count', other=other)
benchmark(join_data, modin_data, benchmarks=modin_benchmarks, name='join', other=other)
# Out:
# read file took: 0.117772 seconds
# count took: 0.000016 seconds
# count index length took: 0.000006 seconds
# mean took: 0.101373 seconds
# standard deviation took: 0.087905 seconds
# mean of columns addition took: 0.416451 seconds
# addition of columns took: 0.302091 seconds
# mean of columns multiplication took: 0.419809 seconds
# multiplication of columns took: 0.326410 seconds
# value counts took: 0.469306 seconds
# complex arithmetic ops took: 3.305906 seconds
# mean of complex arithmetic ops took: 3.398100 seconds
# groupby statistics took: 0.203323 seconds
# join count took: 0.288933 seconds
# join took: 0.252153 seconds
# 0.25215276400012954

# %%
# Retrieve benchmark results and remove duplicate task entries
modin_res_temp = get_results(modin_benchmarks).drop_duplicates(subset='task').set_index('task')

# Print the result DataFrame
print(modin_res_temp)

# Define the file path for saving
filename = 'Results_Modin_L/modin_local_large'

# Save the result DataFrame as a Parquet file
modin_res_temp.to_parquet(filename)

print(f'O arquivo Parquet foi salvo em {filename}.')
# Out:
#                                 duration
# task
# read file                       0.117772
# count                           0.000016
# count index length              0.000006
# mean                            0.101373
# standard deviation              0.087905
# mean of columns addition        0.416451
# addition of columns             0.302091
# mean of columns multiplication  0.419809
# multiplication of columns       0.326410
# value counts                    0.469306
# complex arithmetic ops          3.305906
# mean of complex arithmetic ops  3.398100
# groupby statistics              0.203323
# join count                      0.288933
# join                            0.252153
# O arquivo Parquet foi salvo em Results_Modin_L/modin_local_large.

# %% [markdown]
# ## cProfile

# %% [markdown]
# In this section, the same Modin benchmarks were executed using the cProfile module to collect detailed profiling statistics. This allows for deeper analysis of function performance by identifying the most time-consuming operations. Execution times and profiling data were saved for later comparison.

# %%
import cProfile
import matplotlib.pyplot as plt
from io import StringIO
import pstats

# %%
def benchmark_cprofile(f, df, benchmarks, name, profile_data=None, **kwargs):
    """
    Benchmark and profile the execution of a function using cProfile (without file I/O).
    
    Parameters:
    - f: function to benchmark
    - df: input dataframe (or None)
    - benchmarks: dictionary to store timing results
    - name: name of the benchmark task
    - profile_data: optional list to store detailed profiling data
    - kwargs: other keyword arguments passed to the function
    """
    pr = cProfile.Profile()     #Create a profile object
    pr.enable()                 #Start profiling

    start_time = time.perf_counter()
    ret = f(df, **kwargs)
    duration = time.perf_counter() - start_time

    pr.disable()

    benchmarks['duration'].append(duration)
    benchmarks['task'].append(name)
    print(f"{name} took: {duration:.4f} seconds")

    # Print top 15 most time-consuming operations to the terminal 
    ps = pstats.Stats(pr)
    ps.sort_stats(pstats.SortKey.CUMULATIVE)
    ps.print_stats(15)

    # Store detailed profiling data for later visualization
    if profile_data is not None:
        stats_data = []
        for func, stat in ps.stats.items():
            filename, lineno, function = func
            ncalls, _, percall, cumtime, _ = stat
            stats_data.append({
                'task': name,
                'function': f"{filename}:{lineno} ({function})",
                'percall': percall,
                'cumtime': cumtime,
                'ncalls': ncalls
            })
        profile_data.append(pd.DataFrame(stats_data))

    return duration

# %%
# Store benchmark durations and task names
modin_benchmarks_cprofile = {'duration': [], 'task': []}
# Store profiling details per function
modin_profile_data = []

# Run the benchmarks with profiling enabled
benchmark_cprofile(read_file_parquet, df=None, benchmarks=modin_benchmarks_cprofile, name='read file', profile_data=modin_profile_data)
benchmark_cprofile(count, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='count', profile_data=modin_profile_data)
benchmark_cprofile(count_index_length, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='count index length', profile_data=modin_profile_data)
benchmark_cprofile(mean, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='mean', profile_data=modin_profile_data)
benchmark_cprofile(standard_deviation, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='standard deviation', profile_data=modin_profile_data)
benchmark_cprofile(mean_of_sum, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='mean of columns addition', profile_data=modin_profile_data)
benchmark_cprofile(sum_columns, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='addition of columns', profile_data=modin_profile_data)
benchmark_cprofile(mean_of_product, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='mean of columns multiplication', profile_data=modin_profile_data)
benchmark_cprofile(product_columns, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='multiplication of columns', profile_data=modin_profile_data)
benchmark_cprofile(value_counts, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='value counts', profile_data=modin_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='complex arithmetic ops', profile_data=modin_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='mean of complex arithmetic ops', profile_data=modin_profile_data)
benchmark_cprofile(groupby_statistics, df=modin_data, benchmarks=modin_benchmarks_cprofile, name='groupby statistics', profile_data=modin_profile_data)
benchmark_cprofile(join_count, modin_data, benchmarks=modin_benchmarks_cprofile, name='join count', other=other, profile_data=modin_profile_data)
benchmark_cprofile(join_data, modin_data, benchmarks=modin_benchmarks_cprofile, name='join', other=other, profile_data=modin_profile_data)
# Out:
# read file took: 0.1367 seconds
#          63851 function calls (60706 primitive calls) in 0.137 seconds
#
#    Ordered by: cumulative time
#    List reduced from 535 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.137    0.137 /var/tmp/ipykernel_14262/2978216308.py:1(read_file_parquet)
#         1    0.000    0.000    0.137    0.137 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/io.py:203(read_parquet)
#         1    0.000    0.000    0.137    0.137 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/dispatcher.py:172(read_parquet)
#         1    0.000    0.000    0.137    0.137 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/factories.py:189(_read_parquet)
#         1    0.000    0.000    0.137    0.137 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/file_dispatcher.py:128(read)
#         1    0.000    0.000    0.137    0.137 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/parquet_dispatcher.py:31(_read)
#         1    0.000    0.000    0.133    0.133 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/column_store_dispatcher.py:197(build_query_compiler)
#         2    0.000    0.000    0.101    0.050 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/common/task_wrapper.py:48(materialize)
#         2    0.000    0.000    0.101    0.050 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2093(gather)
#         2    0.000    0.000    0.101    0.050 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    0.101    0.050 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    0.100    0.050 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    0.100    0.050 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    0.100    0.050 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    0.100    0.013    0.100    0.013 {method 'acquire' of '_thread.lock' objects}
#
#
# count took: 0.0000 seconds
#          14 function calls (11 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/2978216308.py:4(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023(__len__)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806(__len__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          12 function calls (10 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/2978216308.py:7(count_index_length)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# mean took: 0.1208 seconds
#          117434 function calls (113969 primitive calls) in 0.121 seconds
#
#    Ordered by: cumulative time
#    List reduced from 787 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.121    0.121 /var/tmp/ipykernel_14262/2978216308.py:10(mean)
#         1    0.000    0.000    0.119    0.119 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1724(mean)
#         1    0.000    0.000    0.119    0.119 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.100    0.100 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:721(mean)
#         1    0.000    0.000    0.100    0.100 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/map_reduce.py:43(caller)
#         1    0.000    0.000    0.100    0.100 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1256(map_reduce)
#        29    0.000    0.000    0.063    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        29    0.000    0.000    0.059    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.055    0.055 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.055    0.055 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         3    0.000    0.000    0.053    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         3    0.000    0.000    0.053    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         3    0.000    0.000    0.053    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         3    0.000    0.000    0.053    0.018 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         3    0.000    0.000    0.053    0.018 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# standard deviation took: 0.1155 seconds
#          127339 function calls (123399 primitive calls) in 0.115 seconds
#
#    Ordered by: cumulative time
#    List reduced from 791 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.115    0.115 /var/tmp/ipykernel_14262/2978216308.py:13(standard_deviation)
#         1    0.000    0.000    0.114    0.114 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2448(std)
#         1    0.000    0.000    0.113    0.113 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.077    0.077 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/reduction.py:42(caller)
#         1    0.000    0.000    0.077    0.077 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1234(fold_reduce)
#         1    0.000    0.000    0.077    0.077 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.077    0.077 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#        29    0.001    0.000    0.063    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        29    0.000    0.000    0.056    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.047    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    0.047    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    0.046    0.023 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    0.046    0.023 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    0.046    0.023 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    0.046    0.006    0.046    0.006 {method 'acquire' of '_thread.lock' objects}
#
#
# mean of columns addition took: 0.5356 seconds
#          624068 function calls (604677 primitive calls) in 0.536 seconds
#
#    Ordered by: cumulative time
#    List reduced from 868 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.536    0.536 /var/tmp/ipykernel_14262/2978216308.py:16(mean_of_sum)
#         1    0.000    0.000    0.420    0.420 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.419    0.419 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.418    0.418 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.418    0.418 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.418    0.418 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.416    0.416 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       157    0.003    0.000    0.322    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       157    0.002    0.000    0.301    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.206    0.206 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#        10    0.000    0.000    0.199    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.199    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        10    0.000    0.000    0.199    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.199    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.199    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# addition of columns took: 0.4216 seconds
#          518938 function calls (502089 primitive calls) in 0.422 seconds
#
#    Ordered by: cumulative time
#    List reduced from 644 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.422    0.422 /var/tmp/ipykernel_14262/2978216308.py:19(sum_columns)
#         1    0.000    0.000    0.419    0.419 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.418    0.418 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       128    0.004    0.000    0.275    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       128    0.002    0.000    0.256    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.213    0.213 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#       128    0.001    0.000    0.148    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       128    0.000    0.000    0.145    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#       128    0.001    0.000    0.145    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:946(getsourcelines)
#         1    0.000    0.000    0.141    0.141 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1266(<listcomp>)
#         4    0.000    0.000    0.141    0.035 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#
#
# mean of columns multiplication took: 0.5216 seconds
#          624061 function calls (604671 primitive calls) in 0.522 seconds
#
#    Ordered by: cumulative time
#    List reduced from 868 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.522    0.522 /var/tmp/ipykernel_14262/2978216308.py:24(mean_of_product)
#         1    0.000    0.000    0.404    0.404 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.403    0.403 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.402    0.402 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.402    0.402 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.402    0.402 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.401    0.401 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       157    0.004    0.000    0.332    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       157    0.002    0.000    0.303    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.212    0.212 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#       157    0.002    0.000    0.176    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#        10    0.000    0.000    0.174    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.174    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        10    0.000    0.000    0.174    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.174    0.017 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#
#
# multiplication of columns took: 0.4256 seconds
#          518940 function calls (502091 primitive calls) in 0.426 seconds
#
#    Ordered by: cumulative time
#    List reduced from 644 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.426    0.426 /var/tmp/ipykernel_14262/2978216308.py:27(product_columns)
#         1    0.000    0.000    0.423    0.423 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.421    0.421 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.419    0.419 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.419    0.419 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.419    0.419 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.418    0.418 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       128    0.004    0.000    0.265    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       128    0.002    0.000    0.244    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.200    0.200 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#         7    0.000    0.000    0.148    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.148    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.148    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.148    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.148    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# value counts took: 0.6039 seconds
#          589422 function calls (572802 primitive calls) in 0.604 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1080 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.604    0.604 /var/tmp/ipykernel_14262/2978216308.py:32(value_counts)
#         1    0.000    0.000    0.602    0.602 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1974(value_counts)
#         1    0.000    0.000    0.602    0.602 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2888(value_counts)
#         1    0.000    0.000    0.330    0.330 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:581(size)
#       139    0.003    0.000    0.299    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#         1    0.000    0.000    0.295    0.295 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:913(_wrap_aggregation)
#         1    0.000    0.000    0.295    0.295 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2495(groupby_size)
#         1    0.000    0.000    0.294    0.294 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2518(_groupby_dict_reduce)
#         1    0.000    0.000    0.294    0.294 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/groupby.py:67(<lambda>)
#         1    0.000    0.000    0.294    0.294 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/groupby.py:239(caller)
#         1    0.000    0.000    0.294    0.294 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2107(groupby_reduce)
#        16    0.000    0.000    0.277    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        16    0.000    0.000    0.277    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        16    0.000    0.000    0.276    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        16    0.000    0.000    0.276    0.017 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#
#
# complex arithmetic ops took: 3.9898 seconds
#          3898994 function calls (3784550 primitive calls) in 3.988 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1051 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.008    0.008    3.989    3.989 /var/tmp/ipykernel_14262/2978216308.py:36(complicated_arithmetic_operation)
#        18    0.000    0.000    2.526    0.140 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.524    0.140 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         5    0.000    0.000    2.009    0.402 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       940    0.018    0.000    1.950    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       192    0.002    0.000    1.807    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       192    0.002    0.000    1.804    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       192    0.000    0.000    1.795    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       192    0.001    0.000    1.795    0.009 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       192    0.001    0.000    1.794    0.009 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       768    1.792    0.002    1.792    0.002 {method 'acquire' of '_thread.lock' objects}
#       940    0.015    0.000    1.791    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       132    0.001    0.000    1.112    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       940    0.009    0.000    1.064    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       940    0.001    0.000    1.042    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#
#
# mean of complex arithmetic ops took: 4.3306 seconds
#          4014462 function calls (3896645 primitive calls) in 4.329 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1089 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.008    0.008    4.330    4.330 /var/tmp/ipykernel_14262/2978216308.py:47(mean_of_complicated_arithmetic_operation)
#        18    0.000    0.000    2.714    0.151 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.712    0.151 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         5    0.000    0.000    2.168    0.434 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       969    0.020    0.000    2.094    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       195    0.002    0.000    1.998    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       195    0.002    0.000    1.995    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       195    0.000    0.000    1.985    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       195    0.001    0.000    1.985    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       195    0.001    0.000    1.984    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       780    1.982    0.003    1.982    0.003 {method 'acquire' of '_thread.lock' objects}
#       969    0.013    0.000    1.939    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       133    0.001    0.000    1.165    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       969    0.010    0.000    1.110    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#         6    0.000    0.000    1.109    0.185 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#
#
# groupby statistics took: 0.2644 seconds
#          237515 function calls (230856 primitive calls) in 0.264 seconds
#
#    Ordered by: cumulative time
#    List reduced from 697 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.264    0.264 /var/tmp/ipykernel_14262/2978216308.py:57(groupby_statistics)
#         1    0.000    0.000    0.263    0.263 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:442(aggregate)
#         1    0.000    0.000    0.263    0.263 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:1014(_apply_agg_function)
#         1    0.000    0.000    0.263    0.263 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2606(groupby_agg)
#         1    0.000    0.000    0.262    0.262 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1810(broadcast_apply_full_axis)
#         7    0.000    0.000    0.137    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.137    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.136    0.019 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.136    0.019 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.136    0.019 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        28    0.136    0.005    0.136    0.005 {method 'acquire' of '_thread.lock' objects}
#        59    0.001    0.000    0.122    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#         1    0.000    0.000    0.113    0.113 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1875(<listcomp>)
#         2    0.000    0.000    0.113    0.057 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:291(_compute_axis_labels)
#         2    0.000    0.000    0.113    0.057 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/partition_manager.py:40(get_indices)
#
#
# join count took: 0.3944 seconds
#          497580 function calls (482644 primitive calls) in 0.394 seconds
#
#    Ordered by: cumulative time
#    List reduced from 807 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.394    0.394 /var/tmp/ipykernel_14262/2978216308.py:69(join_count)
#         1    0.000    0.000    0.394    0.394 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.394    0.394 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.386    0.386 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.385    0.385 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.270    0.270 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#       124    0.002    0.000    0.263    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       124    0.002    0.000    0.245    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.225    0.113 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         2    0.000    0.000    0.225    0.113 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         2    0.000    0.000    0.173    0.087 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:443(<listcomp>)
#         5    0.000    0.000    0.173    0.035 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#         5    0.000    0.000    0.173    0.035 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:50(deploy_axis_func)
#         5    0.000    0.000    0.166    0.033 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:97(<listcomp>)
#       124    0.001    0.000    0.147    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#
#
# join took: 0.3474 seconds
#          432347 function calls (420377 primitive calls) in 0.347 seconds
#
#    Ordered by: cumulative time
#    List reduced from 794 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.347    0.347 /var/tmp/ipykernel_14262/2978216308.py:72(join_data)
#         1    0.000    0.000    0.347    0.347 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.347    0.347 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.342    0.342 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.341    0.341 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.244    0.244 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#       112    0.001    0.000    0.240    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       112    0.001    0.000    0.216    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.207    0.103 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         2    0.000    0.000    0.206    0.103 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         2    0.000    0.000    0.180    0.090 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:443(<listcomp>)
#         5    0.000    0.000    0.180    0.036 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#         5    0.000    0.000    0.179    0.036 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:50(deploy_axis_func)
#         5    0.000    0.000    0.172    0.034 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:97(<listcomp>)
#       112    0.001    0.000    0.131    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
# 0.34741706900013014

# %%
# Concatenate all DataFrames
df_profile_all = pd.concat(modin_profile_data, ignore_index=True)

# %% [markdown]
# **NOTE:**
#
# Instead of generating plots to visualize the profiling results, we opted to use the print function, as rendering multiple plots made the notebook too heavy and unresponsive when running in Google Cloud Platform (GCP).

# %% [markdown]
# In this way, the print_profile_per_task function provides a textual summary of the slowest internal functions (based on profiling) for each benchmarked operation, directly printed to the console instead of generating visual plots.
#
# The printed output includes:
#
# - A separate section for each benchmarked operation;
# - For each operation, the top N internal functions (based on profiling metrics) are listed in descending order of execution time.
# - The two available profiling metrics are:
#   - 'percall': Average time per individual call to the function (in seconds).
#
#   - 'cumtime': Total cumulative time spent in the function, including all nested calls.
#
# - For each listed function, the name, file, and line number are shown alongside the corresponding metric value.
#
# This function is especially useful when working in resource-constrained environments like Google Cloud Platform (GCP), where generating heavy visual plots can make notebooks sluggish or unusable. Instead, print_profile_per_task provides a lightweight and effective way to analyze performance bottlenecks.

# %%
def print_profile_per_task(profile_data_list, metric='percall', top_n=10):
    """
    Prints the top slowest functions (by percall or cumtime) for each benchmark task.
    
    Parameters:
    - profile_data_list: list of DataFrames (one per benchmark task), each containing profiling data
    - metric: the metric to sort by ('percall' or 'cumtime')
    - top_n: number of slowest functions to display per task
    """
    for df in profile_data_list:
        task_name = df['task'].iloc[0]  # All rows in this DataFrame refer to the same task
        df_sorted = df.sort_values(by=metric, ascending=False).head(top_n)

        print(f"\n{'='*50}")
        print(f"Tarefa: {task_name}")
        print(f"Top {top_n} funções por {metric}:\n")
        print(df_sorted[['function', metric]].to_string(index=False))

# %%
print_profile_per_task(modin_profile_data, metric='percall', top_n=25)
# Out:
# ==================================================
# Tarefa: read file
# Top 25 funções por percall:
#
#                                                                             function  percall
#                                   ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.100361
#                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.003218
#                       /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.002192
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001784
#                 ~:0 (<method 'finish' of 'pyarrow._dataset.DatasetFactory' objects>) 0.001607
#                                       ~:0 (<method 'match' of 're.Pattern' objects>) 0.001350
#                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001047
#                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.000946
#                               /opt/conda/envs/cdle/lib/python3.7/pickle.py:464 (put) 0.000697
#                                                   ~:0 (<built-in method posix.stat>) 0.000694
#                                    ~:0 (<method 'send' of '_socket.socket' objects>) 0.000675
#                              /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.000671
#                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000614
#                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000607
#                                               ~:0 (<method 'get' of 'dict' objects>) 0.000607
#                                             ~:0 (<method 'encode' of 'str' objects>) 0.000596
#                         /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.000575
# /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.000489
#                                      ~:0 (<method 'write' of '_io.BytesIO' objects>) 0.000471
#                                                  ~:0 (<built-in method builtins.id>) 0.000415
#                       /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.000407
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000387
#                                    <frozen importlib._bootstrap>:929 (_sanity_check) 0.000372
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/base.py:846 (tokenize) 0.000368
#                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:865 (_batch_setitems) 0.000363
#
# ==================================================
# Tarefa: count
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000003
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023 (__len__) 0.000003
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000003
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000003
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000002
#                                                                     /var/tmp/ipykernel_14262/2978216308.py:4 (count) 0.000002
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000001
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000001
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806 (__len__) 0.000001
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ==================================================
# Tarefa: count index length
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                                                        /var/tmp/ipykernel_14262/2978216308.py:7 (count_index_length) 0.000003
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000003
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000002
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000002
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806 (__len__) 0.000001
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000000
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000000
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000000
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ==================================================
# Tarefa: mean
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.052507
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.009361
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.005698
#                                                                      ~:0 (<built-in method posix.stat>) 0.004097
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.003541
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.002995
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002529
#                                                                   ~:0 (<built-in method posix.urandom>) 0.002480
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001845
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.001843
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001360
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001123
#                                                                                    <string>:1 (__new__) 0.001122
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.001090
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001030
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.001007
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000928
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000767
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000719
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.000681
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.000643
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000639
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000625
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.000575
#                                                                    ~:0 (<built-in method builtins.len>) 0.000500
#
# ==================================================
# Tarefa: standard deviation
# Top 25 funções por percall:
#
#                                                                             function  percall
#                                   ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.046431
#                       /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.009069
#                                       ~:0 (<method 'match' of 're.Pattern' objects>) 0.005259
#                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.004050
#                                                   ~:0 (<built-in method posix.stat>) 0.003608
#                              /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.002885
#                         /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002509
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.002200
#                       /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.001820
#                        /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001369
# /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.001360
#                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.001161
#                                    ~:0 (<method 'send' of '_socket.socket' objects>) 0.001129
#                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001124
#                            /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001119
#                                                                 <string>:1 (__new__) 0.001025
#                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000829
#                                               ~:0 (<method 'get' of 'dict' objects>) 0.000820
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000818
#                               /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000812
#                                                ~:0 (<built-in method posix.urandom>) 0.000799
#                                          ~:0 (<built-in method builtins.isinstance>) 0.000753
#                     ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.000680
#                               /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000678
#                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000642
#
# ==================================================
# Tarefa: mean of columns addition
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.198408
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.048040
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.029538
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.019952
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.015060
#                                                                      ~:0 (<built-in method posix.stat>) 0.012733
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012542
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010621
#                                                                   ~:0 (<built-in method posix.urandom>) 0.010618
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009722
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.007016
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006035
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005772
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005724
#                                                                                    <string>:1 (__new__) 0.005307
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.004847
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004490
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004447
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003820
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003720
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.003695
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003458
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003340
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002960
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.002661
#
# ==================================================
# Tarefa: addition of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.137101
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.038961
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.024070
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.017743
#                                                                      ~:0 (<built-in method posix.stat>) 0.016416
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012273
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010325
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.009183
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007802
#                                                                   ~:0 (<built-in method posix.urandom>) 0.006939
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005674
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005140
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005098
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004944
#                                                                                    <string>:1 (__new__) 0.004395
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003931
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003855
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003589
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003258
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003255
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.003185
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.002907
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002726
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002691
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002475
#
# ==================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.173619
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.048363
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.029633
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.020214
#                                                                   ~:0 (<built-in method posix.urandom>) 0.016991
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.014958
#                                                                      ~:0 (<built-in method posix.stat>) 0.013075
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012887
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010543
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009504
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.007088
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006060
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005786
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005752
#                                                                                    <string>:1 (__new__) 0.005286
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004562
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004465
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.004287
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.004139
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003840
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003704
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.003703
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003411
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003317
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003099
#
# ==================================================
# Tarefa: multiplication of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.147787
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.038132
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.023553
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.017208
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.011888
#                                                                   ~:0 (<built-in method posix.urandom>) 0.010114
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010017
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.009054
#                                                                      ~:0 (<built-in method posix.stat>) 0.008767
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007570
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005619
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.005267
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004946
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004858
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004774
#                                                                                    <string>:1 (__new__) 0.004312
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003994
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003611
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003579
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003215
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003160
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.002979
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002744
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002670
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002412
#
# ==================================================
# Tarefa: value counts
# Top 25 funções por percall:
#
#                                                                             function  percall
#                                   ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.275547
#                       /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.047046
#                                       ~:0 (<method 'match' of 're.Pattern' objects>) 0.026926
#                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.017300
#                              /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.015085
#                         /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012907
#                                                   ~:0 (<built-in method posix.stat>) 0.010499
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.009377
#                       /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009359
#                                                ~:0 (<built-in method posix.urandom>) 0.007108
#                        /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.006794
#                            /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.005881
#                                                                 <string>:1 (__new__) 0.005284
#                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005267
#                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004965
#                                    ~:0 (<method 'send' of '_socket.socket' objects>) 0.004817
#                               /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004309
#                     ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.003642
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003639
#                                          ~:0 (<built-in method builtins.isinstance>) 0.003488
#                                               ~:0 (<method 'get' of 'dict' objects>) 0.003392
#                               /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003342
#                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:865 (_batch_setitems) 0.003316
#                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003240
# /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.002833
#
# ==================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 1.792288
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.295647
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.178264
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.112528
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.093511
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.078809
#                                                                      ~:0 (<built-in method posix.stat>) 0.071166
#                                                                   ~:0 (<built-in method posix.urandom>) 0.067177
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.061179
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.058472
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.042984
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.037218
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.036680
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.034533
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.033440
#                                                                                    <string>:1 (__new__) 0.033088
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.027307
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.025612
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.025249
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.022631
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.021585
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.021225
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.020385
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.018444
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.018398
#
# ==================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                             function  percall
#                                   ~:0 (<method 'acquire' of '_thread.lock' objects>) 1.981952
#                       /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.309217
#                                       ~:0 (<method 'match' of 're.Pattern' objects>) 0.184382
#                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.116721
#                              /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.097387
#                         /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.082008
#           /opt/conda/envs/cdle/lib/python3.7/collections/__init__.py:931 (<genexpr>) 0.079729
#                                                   ~:0 (<built-in method posix.stat>) 0.076131
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.062636
#                       /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.060951
#                                                ~:0 (<built-in method posix.urandom>) 0.060026
#                        /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.044791
#                            /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.039221
#                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.035467
#                                                                 <string>:1 (__new__) 0.034925
#                                    ~:0 (<method 'send' of '_socket.socket' objects>) 0.034867
#                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.034550
#                               /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.028084
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.026340
#                                          ~:0 (<built-in method builtins.isinstance>) 0.026282
#                     ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.023575
#                                               ~:0 (<method 'get' of 'dict' objects>) 0.022145
#                               /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.021424
#                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.021030
# /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.019742
#
# ==================================================
# Tarefa: groupby statistics
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.136186
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.019379
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.011284
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.007051
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.006267
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.005149
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.004009
#                                                                      ~:0 (<built-in method posix.stat>) 0.003994
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.003909
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.002726
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.002387
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.002196
#                                                                                    <string>:1 (__new__) 0.002115
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.002080
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.001750
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.001472
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.001469
#                                                                   ~:0 (<built-in method posix.urandom>) 0.001409
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.001405
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.001362
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.001362
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.001326
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.001221
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.001162
#                                                         ~:0 (<method 'write' of '_io.BytesIO' objects>) 0.001033
#
# ==================================================
# Tarefa: join count
# Top 25 funções por percall:
#
#                                                                                                    function  percall
#                                                          ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.107213
#                                              /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039238
#                                                              ~:0 (<method 'match' of 're.Pattern' objects>) 0.024190
#                                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.015349
#                                                                          ~:0 (<built-in method posix.stat>) 0.015175
#                                                     /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012356
#                                                /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010377
#                                                                       ~:0 (<built-in method posix.urandom>) 0.008352
#                                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008158
#                                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007912
#                                                           ~:0 (<method 'send' of '_socket.socket' objects>) 0.006322
#                                               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005705
#                                                   /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004951
#                                                    /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004542
#                                                                                        <string>:1 (__new__) 0.004425
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004362
#                                                      /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003663
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003420
#                                                                      ~:0 (<method 'get' of 'dict' objects>) 0.003014
#                                            ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.002995
#                                               /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.002949
#                                                          ~:0 (<method 'astype' of 'numpy.ndarray' objects>) 0.002799
#                                                                 ~:0 (<built-in method builtins.isinstance>) 0.002708
#                                                      /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002697
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.002383
#
# ==================================================
# Tarefa: join
# Top 25 funções por percall:
#
#                                                                                                    function  percall
#                                                          ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.085781
#                                              /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.036035
#                                                              ~:0 (<method 'match' of 're.Pattern' objects>) 0.022117
#                                                                       ~:0 (<built-in method posix.urandom>) 0.014782
#                                                     /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.013098
#                                                     /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.011108
#                                                                          ~:0 (<built-in method posix.stat>) 0.010579
#                                                /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.009692
#                                                  /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.007313
#                                              /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007150
#                                               /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005116
#                                                   /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004619
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004042
#                                                                                        <string>:1 (__new__) 0.003943
#                                                    /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.003868
#                                                           ~:0 (<method 'send' of '_socket.socket' objects>) 0.003629
#                                                      /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003258
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.002961
#                                                          ~:0 (<method 'astype' of 'numpy.ndarray' objects>) 0.002817
#                                            ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.002801
#                                                                 ~:0 (<built-in method builtins.isinstance>) 0.002617
#                                                                      ~:0 (<method 'get' of 'dict' objects>) 0.002456
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.002430
#                                                      /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002410
#                                               /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.002376

# %% [markdown]
# **Operations with filtering**

# %% [markdown]
# The **filtered benchmarks** focus on evaluating performance after applying a data filtering operation.
#
# The dataset is filtered to include only rows where the Tip_Amt is between 1 and 5 (inclusive), simulating a common preprocessing step.
#
# This filtered DataFrame is then passed through the same benchmarking pipeline as before, testing various operations like count, mean, groupby, and joins.
#
# This allows us to compare the performance of Modin on both raw and pre-filtered data, which is often more representative of real-world data workflows.

# %%
expr_filter = 'Tip_Amt >= 1 and Tip_Amt <= 5'
filtered = modin_data.query(expr_filter)

if not isinstance(filtered, (pd.DataFrame, md.DataFrame)):
    filtered = md.DataFrame(filtered) if isinstance(data_filtered, md.DataFrame) else pd.DataFrame(filtered)

modin_filtered = filtered

# %%
benchmark(read_file_parquet, df=None, benchmarks=modin_benchmarks_filtered, name='read file')
benchmark(count, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='count')
benchmark(count_index_length, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='count index length')
benchmark(mean, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='mean')
benchmark(standard_deviation, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='standard deviation')
benchmark(mean_of_sum, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='mean of columns addition')
benchmark(sum_columns, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='addition of columns')
benchmark(mean_of_product, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='mean of columns multiplication')
benchmark(product_columns, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='multiplication of columns')
benchmark(value_counts, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='value counts')
benchmark(complicated_arithmetic_operation, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='complex arithmetic ops')
benchmark(mean_of_complicated_arithmetic_operation, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='mean of complex arithmetic ops')
benchmark(groupby_statistics, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='groupby statistics')
benchmark(join_count, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='join count', other=other)
benchmark(join_data, df=modin_filtered, benchmarks=modin_benchmarks_filtered, name='join', other=other)
# Out:
# read file took: 0.115653 seconds
# count took: 0.000020 seconds
# count index length took: 0.000009 seconds
# mean took: 0.100783 seconds
# standard deviation took: 0.088433 seconds
# mean of columns addition took: 0.412853 seconds
# addition of columns took: 0.331521 seconds
# mean of columns multiplication took: 0.426356 seconds
# multiplication of columns took: 0.322304 seconds
# value counts took: 0.601175 seconds
# complex arithmetic ops took: 3.334508 seconds
# mean of complex arithmetic ops took: 3.641059 seconds
# groupby statistics took: 0.275250 seconds
# join count took: 0.299877 seconds
# join took: 0.297289 seconds
# 0.29728893199990125

# %% [markdown]
# **Save results**

# %%
modin_res_filtered = get_results(modin_benchmarks_filtered).drop_duplicates(subset='task').set_index('task')
print(modin_res_filtered)
# Out:
#                                 duration
# task
# read file                       0.115653
# count                           0.000020
# count index length              0.000009
# mean                            0.100783
# standard deviation              0.088433
# mean of columns addition        0.412853
# addition of columns             0.331521
# mean of columns multiplication  0.426356
# multiplication of columns       0.322304
# value counts                    0.601175
# complex arithmetic ops          3.334508
# mean of complex arithmetic ops  3.641059
# groupby statistics              0.275250
# join count                      0.299877
# join                            0.297289

# %%
filename_filter = 'Results_Modin_L/modin_filtered_local_large'
modin_res_filtered.to_parquet(filename_filter)
print(f'O arquivo Parquet foi salvo em {filename_filter}.')
# Out:
# O arquivo Parquet foi salvo em Results_Modin_L/modin_filtered_local_large.

# %% [markdown]
# **Operations with filtering using cProfile**

# %% [markdown]
# The filtered cProfile benchmarks collect detailed performance insights for each filtered operation using the cProfile module.
#
# - Each operation (e.g., count, mean, groupby) is executed on the previously filtered dataset, and function-level profiling data is collected.
#
# - The profiling results are stored in a list of DataFrames, one per benchmarked task, capturing execution time per function call.
#
# - Once again, since graphical profiling plots were too resource-intensive for GCP notebooks, the top 25 slowest functions per operation are printed to screen using print_profile_per_task, based on average time per call (percall).

# %%
modin_benchmarks_filtered_cprofile = {'duration': [], 'task': []}
modin_filtered_profile_data = []

# %%
# Execute benchmarks with cProfile
benchmark_cprofile(read_file_parquet, df=None, benchmarks=modin_benchmarks_filtered_cprofile, name='read file', profile_data=modin_filtered_profile_data)
benchmark_cprofile(count, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='count', profile_data=modin_filtered_profile_data)
benchmark_cprofile(count_index_length, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='count index length', profile_data=modin_filtered_profile_data)
benchmark_cprofile(mean, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='mean', profile_data=modin_filtered_profile_data)
benchmark_cprofile(standard_deviation, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='standard deviation', profile_data=modin_filtered_profile_data)
benchmark_cprofile(mean_of_sum, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='mean of columns addition', profile_data=modin_filtered_profile_data)
benchmark_cprofile(sum_columns, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='addition of columns', profile_data=modin_filtered_profile_data)
benchmark_cprofile(mean_of_product, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='mean of columns multiplication', profile_data=modin_filtered_profile_data)
benchmark_cprofile(product_columns, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='multiplication of columns', profile_data=modin_filtered_profile_data)
benchmark_cprofile(value_counts, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='value counts', profile_data=modin_filtered_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='complex arithmetic ops', profile_data=modin_filtered_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='mean of complex arithmetic ops', profile_data=modin_filtered_profile_data)
benchmark_cprofile(groupby_statistics, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='groupby statistics', profile_data=modin_filtered_profile_data)
benchmark_cprofile(join_count, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='join count', other=other, profile_data=modin_filtered_profile_data)
benchmark_cprofile(join_data, df=modin_filtered, benchmarks=modin_benchmarks_filtered_cprofile, name='join', other=other, profile_data=modin_filtered_profile_data)
# Out:
# read file took: 0.1396 seconds
#          63856 function calls (60711 primitive calls) in 0.140 seconds
#
#    Ordered by: cumulative time
#    List reduced from 535 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.140    0.140 /var/tmp/ipykernel_14262/2978216308.py:1(read_file_parquet)
#         1    0.000    0.000    0.140    0.140 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/io.py:203(read_parquet)
#         1    0.000    0.000    0.140    0.140 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/dispatcher.py:172(read_parquet)
#         1    0.000    0.000    0.140    0.140 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/factories.py:189(_read_parquet)
#         1    0.000    0.000    0.139    0.139 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/file_dispatcher.py:128(read)
#         1    0.000    0.000    0.139    0.139 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/parquet_dispatcher.py:31(_read)
#         1    0.000    0.000    0.136    0.136 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/column_store_dispatcher.py:197(build_query_compiler)
#         2    0.000    0.000    0.101    0.051 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/common/task_wrapper.py:48(materialize)
#         2    0.000    0.000    0.101    0.051 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2093(gather)
#         2    0.000    0.000    0.101    0.051 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    0.101    0.051 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    0.101    0.051 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    0.101    0.051 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    0.101    0.051 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    0.101    0.013    0.101    0.013 {method 'acquire' of '_thread.lock' objects}
#
#
# count took: 0.0000 seconds
#          14 function calls (11 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/2978216308.py:4(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023(__len__)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          12 function calls (10 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/2978216308.py:7(count_index_length)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# mean took: 0.1358 seconds
#          124637 function calls (121144 primitive calls) in 0.136 seconds
#
#    Ordered by: cumulative time
#    List reduced from 792 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.136    0.136 /var/tmp/ipykernel_14262/2978216308.py:10(mean)
#         1    0.000    0.000    0.129    0.129 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1724(mean)
#         1    0.000    0.000    0.129    0.129 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.104    0.104 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:721(mean)
#         1    0.000    0.000    0.104    0.104 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/map_reduce.py:43(caller)
#         1    0.000    0.000    0.104    0.104 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1256(map_reduce)
#         3    0.000    0.000    0.066    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         3    0.000    0.000    0.066    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         3    0.000    0.000    0.065    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         3    0.000    0.000    0.065    0.022 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         3    0.000    0.000    0.065    0.022 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        12    0.065    0.005    0.065    0.005 {method 'acquire' of '_thread.lock' objects}
#        33    0.001    0.000    0.065    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        33    0.000    0.000    0.061    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.058    0.058 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#
#
# standard deviation took: 0.1237 seconds
#          134533 function calls (130566 primitive calls) in 0.124 seconds
#
#    Ordered by: cumulative time
#    List reduced from 786 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.124    0.124 /var/tmp/ipykernel_14262/2978216308.py:13(standard_deviation)
#         1    0.000    0.000    0.117    0.117 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2448(std)
#         1    0.000    0.000    0.116    0.116 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.086    0.086 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/reduction.py:42(caller)
#         1    0.000    0.000    0.086    0.086 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1234(fold_reduce)
#         1    0.000    0.000    0.085    0.085 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.085    0.085 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#        33    0.001    0.000    0.075    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        33    0.000    0.000    0.067    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.042    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    0.042    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    0.042    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    0.042    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    0.042    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    0.042    0.005    0.042    0.005 {method 'acquire' of '_thread.lock' objects}
#
#
# mean of columns addition took: 0.5643 seconds
#          631675 function calls (612258 primitive calls) in 0.564 seconds
#
#    Ordered by: cumulative time
#    List reduced from 867 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.564    0.564 /var/tmp/ipykernel_14262/2978216308.py:16(mean_of_sum)
#         1    0.000    0.000    0.434    0.434 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.434    0.434 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.433    0.433 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.433    0.433 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.433    0.433 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.431    0.431 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       165    0.005    0.000    0.343    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       161    0.003    0.000    0.319    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.217    0.217 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#        10    0.000    0.000    0.206    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.206    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        10    0.000    0.000    0.205    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.205    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.205    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# addition of columns took: 0.4314 seconds
#          526552 function calls (509676 primitive calls) in 0.431 seconds
#
#    Ordered by: cumulative time
#    List reduced from 594 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.431    0.431 /var/tmp/ipykernel_14262/2978216308.py:19(sum_columns)
#         1    0.000    0.000    0.424    0.424 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.423    0.423 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.422    0.422 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.422    0.422 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.422    0.422 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.421    0.421 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       136    0.002    0.000    0.264    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       132    0.002    0.000    0.247    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.202    0.202 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#         7    0.000    0.000    0.157    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.157    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.156    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.156    0.022 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.156    0.022 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# mean of columns multiplication took: 0.5491 seconds
#          631679 function calls (612262 primitive calls) in 0.549 seconds
#
#    Ordered by: cumulative time
#    List reduced from 867 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.549    0.549 /var/tmp/ipykernel_14262/2978216308.py:24(mean_of_product)
#         1    0.000    0.000    0.426    0.426 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.426    0.426 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.425    0.425 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.425    0.425 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.425    0.425 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.424    0.424 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       165    0.005    0.000    0.329    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       161    0.002    0.000    0.307    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#        10    0.000    0.000    0.206    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.206    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        10    0.000    0.000    0.206    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.206    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.206    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        40    0.205    0.005    0.205    0.005 {method 'acquire' of '_thread.lock' objects}
#
#
# multiplication of columns took: 0.4260 seconds
#          526556 function calls (509680 primitive calls) in 0.426 seconds
#
#    Ordered by: cumulative time
#    List reduced from 594 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.426    0.426 /var/tmp/ipykernel_14262/2978216308.py:27(product_columns)
#         1    0.000    0.000    0.419    0.419 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.418    0.418 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.416    0.416 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       136    0.002    0.000    0.272    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       132    0.002    0.000    0.256    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.206    0.206 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#       132    0.001    0.000    0.145    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       132    0.000    0.000    0.142    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#       132    0.001    0.000    0.142    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:946(getsourcelines)
#         7    0.000    0.000    0.142    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.142    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#
#
# value counts took: 0.7298 seconds
#          705385 function calls (685376 primitive calls) in 0.730 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1080 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.730    0.730 /var/tmp/ipykernel_14262/2978216308.py:32(value_counts)
#         1    0.000    0.000    0.727    0.727 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1974(value_counts)
#         1    0.000    0.000    0.727    0.727 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2888(value_counts)
#         1    0.000    0.000    0.447    0.447 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:581(size)
#         1    0.000    0.000    0.410    0.410 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:913(_wrap_aggregation)
#       172    0.003    0.000    0.372    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       168    0.002    0.000    0.338    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#        19    0.000    0.000    0.327    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        19    0.000    0.000    0.327    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        19    0.000    0.000    0.326    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        19    0.000    0.000    0.326    0.017 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        19    0.000    0.000    0.325    0.017 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        76    0.325    0.004    0.325    0.004 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.290    0.290 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2495(groupby_size)
#         1    0.000    0.000    0.289    0.289 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2518(_groupby_dict_reduce)
#
#
# complex arithmetic ops took: 4.1541 seconds
#          3921999 function calls (3807621 primitive calls) in 4.153 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1034 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003    4.154    4.154 /var/tmp/ipykernel_14262/2978216308.py:36(complicated_arithmetic_operation)
#        18    0.000    0.000    2.641    0.147 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.639    0.147 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         5    0.000    0.000    2.103    0.421 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       956    0.019    0.000    2.015    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       192    0.002    0.000    1.892    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       192    0.002    0.000    1.889    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       192    0.000    0.000    1.879    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       192    0.001    0.000    1.879    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       192    0.001    0.000    1.877    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       768    1.876    0.002    1.876    0.002 {method 'acquire' of '_thread.lock' objects}
#       944    0.013    0.000    1.837    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       132    0.001    0.000    1.129    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       944    0.010    0.000    1.093    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       944    0.001    0.000    1.070    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#
#
# mean of complex arithmetic ops took: 4.3451 seconds
#          4037428 function calls (3919677 primitive calls) in 4.344 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1058 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003    4.345    4.345 /var/tmp/ipykernel_14262/2978216308.py:47(mean_of_complicated_arithmetic_operation)
#        18    0.000    0.000    2.688    0.149 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.686    0.149 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         5    0.000    0.000    2.170    0.434 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       985    0.024    0.000    2.090    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       195    0.002    0.000    2.012    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       195    0.002    0.000    2.009    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       195    0.000    0.000    1.999    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       195    0.001    0.000    1.999    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       195    0.001    0.000    1.998    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       780    1.996    0.003    1.996    0.003 {method 'acquire' of '_thread.lock' objects}
#       973    0.013    0.000    1.890    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       133    0.001    0.000    1.168    0.009 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       973    0.010    0.000    1.128    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       973    0.001    0.000    1.104    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#
#
# groupby statistics took: 0.2631 seconds
#          244662 function calls (237975 primitive calls) in 0.263 seconds
#
#    Ordered by: cumulative time
#    List reduced from 644 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.263    0.263 /var/tmp/ipykernel_14262/2978216308.py:57(groupby_statistics)
#         1    0.000    0.000    0.257    0.257 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:442(aggregate)
#         1    0.000    0.000    0.257    0.257 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:1014(_apply_agg_function)
#         1    0.000    0.000    0.257    0.257 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2606(groupby_agg)
#         1    0.000    0.000    0.256    0.256 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1810(broadcast_apply_full_axis)
#        63    0.001    0.000    0.130    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#         7    0.000    0.000    0.126    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.126    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.126    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.126    0.018 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.126    0.018 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        28    0.126    0.004    0.126    0.004 {method 'acquire' of '_thread.lock' objects}
#        63    0.001    0.000    0.117    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.102    0.102 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1875(<listcomp>)
#         2    0.000    0.000    0.102    0.051 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:291(_compute_axis_labels)
#
#
# join count took: 0.3924 seconds
#          496684 function calls (481748 primitive calls) in 0.392 seconds
#
#    Ordered by: cumulative time
#    List reduced from 802 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.392    0.392 /var/tmp/ipykernel_14262/2978216308.py:69(join_count)
#         1    0.000    0.000    0.392    0.392 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.392    0.392 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.387    0.387 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.386    0.386 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.272    0.272 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#       124    0.003    0.000    0.269    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       124    0.002    0.000    0.247    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.235    0.118 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         2    0.000    0.000    0.235    0.118 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         2    0.000    0.000    0.180    0.090 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:443(<listcomp>)
#         5    0.000    0.000    0.180    0.036 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#         5    0.000    0.000    0.179    0.036 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:50(deploy_axis_func)
#         5    0.000    0.000    0.172    0.034 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:97(<listcomp>)
#       124    0.001    0.000    0.146    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#
#
# join took: 0.3736 seconds
#          431597 function calls (419627 primitive calls) in 0.374 seconds
#
#    Ordered by: cumulative time
#    List reduced from 790 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.374    0.374 /var/tmp/ipykernel_14262/2978216308.py:72(join_data)
#         1    0.000    0.000    0.374    0.374 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.374    0.374 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.368    0.368 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.367    0.367 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.257    0.257 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#       112    0.003    0.000    0.220    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       112    0.002    0.000    0.206    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.189    0.095 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         2    0.000    0.000    0.189    0.095 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         2    0.000    0.000    0.164    0.082 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:443(<listcomp>)
#         5    0.000    0.000    0.164    0.033 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#         5    0.000    0.000    0.164    0.033 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:50(deploy_axis_func)
#         5    0.000    0.000    0.156    0.031 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:97(<listcomp>)
#         8    0.000    0.000    0.139    0.017 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
# 0.3736066469996331

# %%
# Concatenate all results
df_filtered_profile_all = pd.concat(modin_filtered_profile_data, ignore_index=True)

# %%
print_profile_per_task(modin_filtered_profile_data, metric='percall', top_n=25)
# Out:
# ==================================================
# Tarefa: read file
# Top 25 funções por percall:
#
#                                                                             function  percall
#                                   ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.101164
#                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.003049
#                                                   ~:0 (<built-in method posix.stat>) 0.002320
#                       /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.002008
# /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.001835
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001750
#                                    ~:0 (<method 'send' of '_socket.socket' objects>) 0.001562
#                 ~:0 (<method 'finish' of 'pyarrow._dataset.DatasetFactory' objects>) 0.001492
#                                       ~:0 (<method 'match' of 're.Pattern' objects>) 0.001290
#                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001077
#                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.000942
#                               /opt/conda/envs/cdle/lib/python3.7/pickle.py:464 (put) 0.000627
#                              /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.000620
#                                               ~:0 (<method 'get' of 'dict' objects>) 0.000602
#                                             ~:0 (<method 'encode' of 'str' objects>) 0.000570
#                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000570
#                         /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.000560
#                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000553
#                                      ~:0 (<method 'write' of '_io.BytesIO' objects>) 0.000464
#                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:865 (_batch_setitems) 0.000392
#                       /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.000386
#                                                  ~:0 (<built-in method builtins.id>) 0.000384
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/base.py:846 (tokenize) 0.000381
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000377
#                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:567 (save_reduce) 0.000327
#
# ==================================================
# Tarefa: count
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000005
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000005
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000004
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000002
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023 (__len__) 0.000002
#                                                                     /var/tmp/ipykernel_14262/2978216308.py:4 (count) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000001
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000001
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000000
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ==================================================
# Tarefa: count index length
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000005
#                                                        /var/tmp/ipykernel_14262/2978216308.py:7 (count_index_length) 0.000004
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000003
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000002
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000001
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000001
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000001
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000000
#
# ==================================================
# Tarefa: mean
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.065337
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.010069
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.005854
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.003566
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.003216
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002631
#                                                                   ~:0 (<built-in method posix.urandom>) 0.002478
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.001976
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001815
#                                                                      ~:0 (<built-in method posix.stat>) 0.001632
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001367
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001271
#                                                                                    <string>:1 (__new__) 0.001134
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.001047
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001028
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000958
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.000846
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000782
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000780
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.000755
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.000753
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000688
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000662
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.000654
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.000615
#
# ==================================================
# Tarefa: standard deviation
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.041988
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.010545
#                                                                      ~:0 (<built-in method posix.stat>) 0.005780
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.005749
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.004453
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.003391
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002860
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.002392
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.002096
#                                                                   ~:0 (<built-in method posix.urandom>) 0.001652
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001523
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001308
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001264
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.001204
#                                                                                    <string>:1 (__new__) 0.001155
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.001127
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.001108
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000958
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000913
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000878
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000847
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.000821
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.000801
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000801
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.000741
#
# ==================================================
# Tarefa: mean of columns addition
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.204772
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.050721
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.031010
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.020775
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.015969
#                                                                      ~:0 (<built-in method posix.stat>) 0.014981
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.013425
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010942
#                                                                   ~:0 (<built-in method posix.urandom>) 0.010461
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.010121
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.007384
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006319
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005959
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005861
#                                                                                    <string>:1 (__new__) 0.005600
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.004905
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.004878
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004840
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004625
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.004230
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.004008
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003794
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003603
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003531
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003306
#
# ==================================================
# Tarefa: addition of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.156151
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039134
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.023986
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.016855
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012365
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010365
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.009086
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007682
#                                                                   ~:0 (<built-in method posix.urandom>) 0.007061
#                                                                      ~:0 (<built-in method posix.stat>) 0.006951
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005722
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005033
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004977
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004881
#                                                                                    <string>:1 (__new__) 0.004275
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003911
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.003819
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003647
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003283
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003143
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.003018
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002819
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002778
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002584
#                                                         ~:0 (<method 'write' of '_io.BytesIO' objects>) 0.002306
#
# ==================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.205386
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.049012
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.029709
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.019815
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.015419
#                                                                      ~:0 (<built-in method posix.stat>) 0.013673
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.013204
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010379
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009405
#                                                                   ~:0 (<built-in method posix.urandom>) 0.009070
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.006898
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006058
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005793
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005730
#                                                                                    <string>:1 (__new__) 0.005451
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004639
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004629
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.004596
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003805
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.003796
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003750
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.003623
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003441
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003374
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003188
#
# ==================================================
# Tarefa: multiplication of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.141421
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039640
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.024494
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.017636
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012783
#                                                                      ~:0 (<built-in method posix.stat>) 0.011128
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010803
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.009442
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007868
#                                                                   ~:0 (<built-in method posix.urandom>) 0.005894
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005695
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.005026
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004983
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004915
#                                                                                    <string>:1 (__new__) 0.004425
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004023
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003647
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003361
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003331
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.003193
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.003009
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002795
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002706
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002603
#                                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:865 (_batch_setitems) 0.002382
#
# ==================================================
# Tarefa: value counts
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.325171
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.056585
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.032964
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.020896
#                                                                      ~:0 (<built-in method posix.stat>) 0.020134
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.018095
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.015110
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.011493
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.011348
#                                                                   ~:0 (<built-in method posix.urandom>) 0.009844
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.008398
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.007262
#                                                                                    <string>:1 (__new__) 0.006311
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.006225
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.006173
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.005858
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.005217
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004485
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.004432
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.004333
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003952
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003921
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003867
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003510
#                                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.002943
#
# ==================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 1.875597
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.299137
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.180678
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.113454
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.095760
#                                                                      ~:0 (<built-in method posix.stat>) 0.081767
#                                                                   ~:0 (<built-in method posix.urandom>) 0.080721
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.080305
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.062048
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.059338
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.043366
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.040039
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.037692
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.034769
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.033795
#                                                                                    <string>:1 (__new__) 0.033673
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.027684
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.026572
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.026173
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.023456
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.022422
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.021094
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.020903
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.019534
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.019354
#
# ==================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 1.995910
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.309016
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.185760
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.117866
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.098810
#                                                                   ~:0 (<built-in method posix.urandom>) 0.097483
#                                                                      ~:0 (<built-in method posix.stat>) 0.084531
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.083543
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.064296
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.061495
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.045219
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.038873
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.035946
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.035296
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.035042
#                                                                                    <string>:1 (__new__) 0.034776
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.028676
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.027234
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.026747
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.024170
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.024075
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.022642
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.021894
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.021375
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.019922
#
# ==================================================
# Tarefa: groupby statistics
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.125777
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.020345
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.012032
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.007245
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.006522
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.005626
#                                                                      ~:0 (<built-in method posix.stat>) 0.005564
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.003950
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.003902
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.002951
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.002577
#                                                                                    <string>:1 (__new__) 0.002236
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.002207
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.002171
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.001929
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.001845
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.001522
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.001509
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.001470
#                                                                   ~:0 (<built-in method posix.urandom>) 0.001439
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.001395
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.001391
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.001379
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.001349
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.001305
#
# ==================================================
# Tarefa: join count
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.107953
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039497
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.024710
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.016002
#                                                                      ~:0 (<built-in method posix.stat>) 0.012572
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012404
#                                                                   ~:0 (<built-in method posix.urandom>) 0.010445
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010435
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008395
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.008071
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005745
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004947
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004642
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004572
#                                                                                    <string>:1 (__new__) 0.004442
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.004217
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003671
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003651
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003076
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003072
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.003021
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.002960
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002842
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002795
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002613
#
# ==================================================
# Tarefa: join
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.138284
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.035076
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.021214
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.012833
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.010763
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.009163
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.007010
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.006770
#                                                                      ~:0 (<built-in method posix.stat>) 0.005519
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005098
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.004528
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004384
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004026
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.003918
#                                                                                    <string>:1 (__new__) 0.003851
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003161
#                                                                   ~:0 (<built-in method posix.urandom>) 0.003098
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003062
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.002879
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.002566
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002556
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.002416
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002354
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.002322
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002221

# %% [markdown]
# **Operations with cache**

# %% [markdown]
# In this section, the filtered Modin DataFrame was first converted to a Pandas DataFrame, then transformed into a Dask DataFrame with multiple partitions to leverage parallel processing and better memory management.
#
# The Dask DataFrame was persisted in memory to speed up repeated computations. Subsequently, a series of benchmark functions were executed on this cached data to measure performance across various operations.
#
# For join operations, the auxiliary dataset was also converted to Dask format to maintain consistency.
#
# Finally, the benchmark results were collected, deduplicated by task, saved to a Parquet file for future analysis, and printed.

# %%
# Convert Modin DataFrame to Pandas DataFrame
dask_df = modin_filtered._to_pandas()
print("Conversão para Pandas realizada com sucesso.")

# Convert Pandas DataFrame to Dask DataFrame with 10 partitions
dask_df = dd.from_pandas(dask_df, npartitions=10)

# Persist the Dask DataFrame in memory for faster access
dask_df = client.persist(dask_df)
modin_cache = dask_df
# Out:
# Conversão para Pandas realizada com sucesso.

# %%
# Run benchmarks on cached data
benchmark(read_file_parquet, df=None, benchmarks=modin_benchmarks_cache, name='read file')
benchmark(count, df=modin_cache, benchmarks=modin_benchmarks_cache, name='count')
benchmark(count_index_length, df=modin_cache, benchmarks=modin_benchmarks_cache, name='count index length')
benchmark(mean, df=modin_cache, benchmarks=modin_benchmarks_cache, name='mean')
benchmark(standard_deviation, df=modin_cache, benchmarks=modin_benchmarks_cache, name='standard deviation')
benchmark(mean_of_sum, df=modin_cache, benchmarks=modin_benchmarks_cache, name='mean of columns addition')
benchmark(sum_columns, df=modin_cache, benchmarks=modin_benchmarks_cache, name='addition of columns')
benchmark(mean_of_product, df=modin_cache, benchmarks=modin_benchmarks_cache, name='mean of columns multiplication')
benchmark(product_columns, df=modin_cache, benchmarks=modin_benchmarks_cache, name='multiplication of columns')
benchmark(value_counts, df=modin_cache, benchmarks=modin_benchmarks_cache, name='value counts')
benchmark(complicated_arithmetic_operation, df=modin_cache, benchmarks=modin_benchmarks_cache, name='complex arithmetic ops')
benchmark(groupby_statistics, df=modin_cache, benchmarks=modin_benchmarks_cache, name='groupby statistics')

# Prepare 'other' DataFrame for join operations, converting from Modin to Dask
other_dask = dd.from_pandas(other._to_pandas(), npartitions=10)  

benchmark(join_count, df=modin_cache, benchmarks=modin_benchmarks_cache, name='join count', other=other_dask)
benchmark(join_data, df=modin_cache, benchmarks=modin_benchmarks_cache, name='join', other=other_dask)
# Out:
# read file took: 0.124047 seconds
# count took: 0.293025 seconds
# count index length took: 0.024386 seconds
# mean took: 0.003109 seconds
# standard deviation took: 0.003164 seconds
# mean of columns addition took: 0.002922 seconds
# addition of columns took: 0.000687 seconds
# mean of columns multiplication took: 0.003184 seconds
# multiplication of columns took: 0.000659 seconds
# value counts took: 0.000949 seconds
# complex arithmetic ops took: 0.009707 seconds
# groupby statistics took: 0.059726 seconds
# join count took: 0.168288 seconds
# join took: 0.010282 seconds
# 0.010282319999987521

# %%
# Retrieve benchmark results, drop duplicate tasks and set index to 'task'
modin_res_cache = get_results(modin_benchmarks_cache).drop_duplicates(subset='task').set_index('task')
print(modin_res_cache)
# Out:
#                                 duration
# task
# read file                       0.124047
# count                           0.293025
# count index length              0.024386
# mean                            0.003109
# standard deviation              0.003164
# mean of columns addition        0.002922
# addition of columns             0.000687
# mean of columns multiplication  0.003184
# multiplication of columns       0.000659
# value counts                    0.000949
# complex arithmetic ops          0.009707
# groupby statistics              0.059726
# join count                      0.168288
# join                            0.010282

# %%
# Save results to Parquet file
filename_cache = 'Results_Modin_L/modin_cache_local_large'
modin_res_cache.to_parquet(filename_cache)
print(f'O arquivo Parquet foi salvo em {filename_cache}.')
# Out:
# O arquivo Parquet foi salvo em Results_Modin_L/modin_cache_local_large.

# %% [markdown]
# **Cache with cprofile**

# %% [markdown]
# In this section, performance profiling was conducted using cProfile for the previously cached Dask DataFrame (modin_cache). The goal was to capture fine-grained profiling data (function call durations and frequencies) across various common operations such as count, mean, groupby, and arithmetic operations. Each function was profiled individually using benchmark_cprofile, and the profiling data was stored in a list. At the end, all collected profiling results were concatenated into a single DataFrame and visualized using a custom print_profile_per_task function to highlight the top functions sorted by time per call (percall). Finally, the Dask client was restarted to clear memory and reset the environment.
#
# This approach allows deeper analysis of function-level performance bottlenecks and behavior when working with cached data using Dask after converting from Modin.

# %%
# === Benchmarks with cProfile for cached Modin data ===
modin_benchmarks_cache_cprofile = {'duration': [], 'task': []}
modin_cache_profile_data = []

# %%
# Run benchmarks with cProfile
benchmark_cprofile(read_file_parquet, df=None, benchmarks=modin_benchmarks_cache_cprofile, name='read file', profile_data=modin_cache_profile_data)
benchmark_cprofile(count, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='count', profile_data=modin_cache_profile_data)
benchmark_cprofile(count_index_length, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='count index length', profile_data=modin_cache_profile_data)
benchmark_cprofile(mean, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='mean', profile_data=modin_cache_profile_data)
benchmark_cprofile(standard_deviation, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='standard deviation', profile_data=modin_cache_profile_data)
benchmark_cprofile(mean_of_sum, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='mean of columns addition', profile_data=modin_cache_profile_data)
benchmark_cprofile(sum_columns, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='addition of columns', profile_data=modin_cache_profile_data)
benchmark_cprofile(mean_of_product, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='mean of columns multiplication', profile_data=modin_cache_profile_data)
benchmark_cprofile(product_columns, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='multiplication of columns', profile_data=modin_cache_profile_data)
benchmark_cprofile(value_counts, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='value counts', profile_data=modin_cache_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='complex arithmetic ops', profile_data=modin_cache_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='mean of complex arithmetic ops', profile_data=modin_cache_profile_data)
benchmark_cprofile(groupby_statistics, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='groupby statistics', profile_data=modin_cache_profile_data)
benchmark_cprofile(join_count, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='join count', other=other, profile_data=modin_cache_profile_data)
benchmark_cprofile(join_data, df=modin_cache, benchmarks=modin_benchmarks_cache_cprofile, name='join', other=other, profile_data=modin_cache_profile_data)
# Out:
# read file took: 0.1282 seconds
#          63840 function calls (60696 primitive calls) in 0.128 seconds
#
#    Ordered by: cumulative time
#    List reduced from 535 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.128    0.128 /var/tmp/ipykernel_14262/2978216308.py:1(read_file_parquet)
#         1    0.000    0.000    0.128    0.128 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/io.py:203(read_parquet)
#         1    0.000    0.000    0.128    0.128 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/dispatcher.py:172(read_parquet)
#         1    0.000    0.000    0.128    0.128 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dispatching/factories/factories.py:189(_read_parquet)
#         1    0.000    0.000    0.128    0.128 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/file_dispatcher.py:128(read)
#         1    0.000    0.000    0.128    0.128 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/parquet_dispatcher.py:31(_read)
#         1    0.000    0.000    0.126    0.126 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/io/column_stores/column_store_dispatcher.py:197(build_query_compiler)
#         2    0.000    0.000    0.095    0.047 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/common/task_wrapper.py:48(materialize)
#         2    0.000    0.000    0.095    0.047 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2093(gather)
#         2    0.000    0.000    0.095    0.047 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         2    0.000    0.000    0.095    0.047 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         2    0.000    0.000    0.095    0.047 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         2    0.000    0.000    0.095    0.047 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         2    0.000    0.000    0.095    0.047 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#         8    0.095    0.012    0.095    0.012 {method 'acquire' of '_thread.lock' objects}
#
#
# count took: 0.0000 seconds
#          14 function calls (11 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/2978216308.py:4(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023(__len__)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          12 function calls (10 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/2978216308.py:7(count_index_length)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075(__getattribute__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71(<lambda>)
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220(_get_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# mean took: 0.1356 seconds
#          124637 function calls (121144 primitive calls) in 0.136 seconds
#
#    Ordered by: cumulative time
#    List reduced from 792 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.136    0.136 /var/tmp/ipykernel_14262/2978216308.py:10(mean)
#         1    0.000    0.000    0.129    0.129 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1724(mean)
#         1    0.000    0.000    0.129    0.129 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.107    0.107 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:721(mean)
#         1    0.000    0.000    0.107    0.107 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/map_reduce.py:43(caller)
#         1    0.000    0.000    0.107    0.107 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1256(map_reduce)
#        33    0.000    0.000    0.066    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#         3    0.000    0.000    0.064    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         3    0.000    0.000    0.064    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         3    0.000    0.000    0.064    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         3    0.000    0.000    0.064    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         3    0.000    0.000    0.064    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        12    0.064    0.005    0.064    0.005 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.063    0.063 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.063    0.063 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#
#
# standard deviation took: 0.1220 seconds
#          134533 function calls (130566 primitive calls) in 0.122 seconds
#
#    Ordered by: cumulative time
#    List reduced from 786 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.122    0.122 /var/tmp/ipykernel_14262/2978216308.py:13(standard_deviation)
#         1    0.000    0.000    0.116    0.116 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2448(std)
#         1    0.000    0.000    0.115    0.115 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1648(_stat_operation)
#         1    0.000    0.000    0.091    0.091 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/reduction.py:42(caller)
#         1    0.000    0.000    0.091    0.091 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1234(fold_reduce)
#         1    0.000    0.000    0.090    0.090 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         1    0.000    0.000    0.090    0.090 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#        33    0.001    0.000    0.079    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        33    0.000    0.000    0.067    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.043    0.043 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:443(<listcomp>)
#         1    0.000    0.000    0.042    0.042 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#         1    0.000    0.000    0.042    0.042 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:50(deploy_axis_func)
#        33    0.000    0.000    0.041    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#         1    0.000    0.000    0.041    0.041 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:97(<listcomp>)
#        33    0.000    0.000    0.040    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#
#
# mean of columns addition took: 0.5397 seconds
#          624517 function calls (605124 primitive calls) in 0.540 seconds
#
#    Ordered by: cumulative time
#    List reduced from 867 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.540    0.540 /var/tmp/ipykernel_14262/2978216308.py:16(mean_of_sum)
#         1    0.000    0.000    0.416    0.416 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.415    0.415 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.414    0.414 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.414    0.414 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.414    0.414 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.413    0.413 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       165    0.002    0.000    0.328    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       157    0.002    0.000    0.306    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.209    0.209 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#        10    0.000    0.000    0.195    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.195    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        10    0.000    0.000    0.195    0.019 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.195    0.019 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.195    0.019 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# addition of columns took: 0.4283 seconds
#          526552 function calls (509676 primitive calls) in 0.428 seconds
#
#    Ordered by: cumulative time
#    List reduced from 594 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.428    0.428 /var/tmp/ipykernel_14262/2978216308.py:19(sum_columns)
#         1    0.000    0.000    0.419    0.419 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:200(__add__)
#         1    0.000    0.000    0.418    0.418 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:548(add)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:580(add)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.415    0.415 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       136    0.003    0.000    0.275    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       132    0.002    0.000    0.255    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.212    0.212 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#       132    0.001    0.000    0.146    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       132    0.000    0.000    0.143    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#       132    0.001    0.000    0.142    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:946(getsourcelines)
#         7    0.000    0.000    0.142    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.141    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#
#
# mean of columns multiplication took: 0.5462 seconds
#          631677 function calls (612260 primitive calls) in 0.546 seconds
#
#    Ordered by: cumulative time
#    List reduced from 867 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.546    0.546 /var/tmp/ipykernel_14262/2978216308.py:24(mean_of_product)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.417    0.417 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.416    0.416 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.416    0.416 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.416    0.416 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.415    0.415 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       165    0.003    0.000    0.328    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       161    0.003    0.000    0.308    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#        10    0.000    0.000    0.204    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        10    0.000    0.000    0.204    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         1    0.000    0.000    0.203    0.203 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#        10    0.000    0.000    0.203    0.020 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        10    0.000    0.000    0.203    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        10    0.000    0.000    0.203    0.020 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# multiplication of columns took: 0.4292 seconds
#          526552 function calls (509676 primitive calls) in 0.429 seconds
#
#    Ordered by: cumulative time
#    List reduced from 594 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.429    0.429 /var/tmp/ipykernel_14262/2978216308.py:27(product_columns)
#         1    0.000    0.000    0.421    0.421 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:404(__mul__)
#         1    0.000    0.000    0.420    0.420 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1292(mul)
#         1    0.000    0.000    0.419    0.419 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:1774(mul)
#         1    0.000    0.000    0.419    0.419 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#         1    0.000    0.000    0.419    0.419 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         1    0.000    0.000    0.418    0.418 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       136    0.002    0.000    0.266    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       132    0.002    0.000    0.250    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.201    0.201 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:1235(binary_operation)
#         7    0.000    0.000    0.151    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.151    0.022 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.150    0.021 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.150    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.150    0.021 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#
#
# value counts took: 0.7389 seconds
#          712556 function calls (692522 primitive calls) in 0.739 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1080 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.739    0.739 /var/tmp/ipykernel_14262/2978216308.py:32(value_counts)
#         1    0.000    0.000    0.732    0.732 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/series.py:1974(value_counts)
#         1    0.000    0.000    0.732    0.732 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:2888(value_counts)
#         1    0.000    0.000    0.447    0.447 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:581(size)
#         1    0.000    0.000    0.411    0.411 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:913(_wrap_aggregation)
#       172    0.004    0.000    0.365    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#        19    0.000    0.000    0.339    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#        19    0.000    0.000    0.339    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#        19    0.000    0.000    0.338    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#        19    0.000    0.000    0.338    0.018 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#        19    0.000    0.000    0.338    0.018 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        76    0.338    0.004    0.338    0.004 {method 'acquire' of '_thread.lock' objects}
#       172    0.003    0.000    0.328    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.291    0.291 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2495(groupby_size)
#         1    0.000    0.000    0.290    0.290 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2518(_groupby_dict_reduce)
#
#
# complex arithmetic ops took: 4.2402 seconds
#          3922011 function calls (3807633 primitive calls) in 4.239 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1034 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003    4.240    4.240 /var/tmp/ipykernel_14262/2978216308.py:36(complicated_arithmetic_operation)
#        18    0.000    0.000    2.601    0.144 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.000    0.000    2.599    0.144 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         5    0.000    0.000    2.072    0.414 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       192    0.002    0.000    2.007    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       192    0.002    0.000    2.004    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       192    0.000    0.000    1.993    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       192    0.001    0.000    1.993    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       192    0.001    0.000    1.991    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       768    1.989    0.003    1.989    0.003 {method 'acquire' of '_thread.lock' objects}
#       956    0.019    0.000    1.989    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       944    0.013    0.000    1.834    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       132    0.001    0.000    1.266    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       944    0.010    0.000    1.094    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       112    0.001    0.000    1.085    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/partition.py:56(get)
#
#
# mean of complex arithmetic ops took: 4.2675 seconds
#          4037442 function calls (3919691 primitive calls) in 4.266 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1058 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003    4.267    4.267 /var/tmp/ipykernel_14262/2978216308.py:47(mean_of_complicated_arithmetic_operation)
#        18    0.000    0.000    2.670    0.148 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:383(_binary_op)
#        18    0.001    0.000    2.668    0.148 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/algebra/binary.py:45(caller)
#         5    0.000    0.000    2.140    0.428 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2010(binary_op)
#       985    0.026    0.000    2.081    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       195    0.002    0.000    1.940    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#       195    0.002    0.000    1.937    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#       195    0.000    0.000    1.926    0.010 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#       195    0.001    0.000    1.926    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#       195    0.001    0.000    1.925    0.010 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#       780    1.923    0.002    1.923    0.002 {method 'acquire' of '_thread.lock' objects}
#       973    0.013    0.000    1.901    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#       973    0.010    0.000    1.137    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#       133    0.001    0.000    1.126    0.008 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:248(result)
#       973    0.001    0.000    1.114    0.001 /opt/conda/envs/cdle/lib/python3.7/inspect.py:967(getsource)
#
#
# groupby statistics took: 0.2574 seconds
#          244662 function calls (237975 primitive calls) in 0.257 seconds
#
#    Ordered by: cumulative time
#    List reduced from 644 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.257    0.257 /var/tmp/ipykernel_14262/2978216308.py:57(groupby_statistics)
#         1    0.000    0.000    0.251    0.251 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:442(aggregate)
#         1    0.000    0.000    0.251    0.251 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/groupby.py:1014(_apply_agg_function)
#         1    0.000    0.000    0.251    0.251 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2606(groupby_agg)
#         1    0.000    0.000    0.251    0.251 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1810(broadcast_apply_full_axis)
#        63    0.001    0.000    0.127    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#         7    0.000    0.000    0.124    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:297(sync)
#         7    0.000    0.000    0.124    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:326(sync)
#         7    0.000    0.000    0.123    0.018 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/utils.py:359(wait)
#         7    0.000    0.000    0.123    0.018 /opt/conda/envs/cdle/lib/python3.7/threading.py:534(wait)
#         7    0.000    0.000    0.123    0.018 /opt/conda/envs/cdle/lib/python3.7/threading.py:264(wait)
#        28    0.123    0.004    0.123    0.004 {method 'acquire' of '_thread.lock' objects}
#        63    0.001    0.000    0.115    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         1    0.000    0.000    0.103    0.103 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1875(<listcomp>)
#         2    0.000    0.000    0.103    0.051 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:291(_compute_axis_labels)
#
#
# join count took: 0.3902 seconds
#          496686 function calls (481750 primitive calls) in 0.390 seconds
#
#    Ordered by: cumulative time
#    List reduced from 802 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.390    0.390 /var/tmp/ipykernel_14262/2978216308.py:69(join_count)
#         1    0.000    0.000    0.390    0.390 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.390    0.390 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.385    0.385 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.382    0.382 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#       124    0.002    0.000    0.275    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#         1    0.000    0.000    0.266    0.266 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#       124    0.002    0.000    0.251    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.243    0.122 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         2    0.000    0.000    0.243    0.122 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         2    0.000    0.000    0.178    0.089 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:443(<listcomp>)
#         5    0.000    0.000    0.178    0.036 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#         5    0.000    0.000    0.178    0.036 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:50(deploy_axis_func)
#         5    0.000    0.000    0.171    0.034 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:97(<listcomp>)
#       124    0.001    0.000    0.149    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
#
#
# join took: 0.3566 seconds
#          431595 function calls (419625 primitive calls) in 0.357 seconds
#
#    Ordered by: cumulative time
#    List reduced from 790 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.357    0.357 /var/tmp/ipykernel_14262/2978216308.py:72(join_data)
#         1    0.000    0.000    0.357    0.357 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1379(merge)
#         1    0.000    0.000    0.357    0.357 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/dataframe.py:1260(join)
#         1    0.000    0.000    0.352    0.352 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:305(concat)
#         1    0.000    0.000    0.351    0.351 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2039(concat)
#         1    0.000    0.000    0.244    0.244 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:1899(_copartition)
#       112    0.002    0.000    0.240    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628(submit)
#       112    0.001    0.000    0.216    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840(_graph_to_futures)
#         2    0.000    0.000    0.208    0.104 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:509(map_axis_partitions)
#         2    0.000    0.000    0.208    0.104 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:369(broadcast_axis_partitions)
#         2    0.000    0.000    0.178    0.089 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:443(<listcomp>)
#         5    0.000    0.000    0.178    0.036 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/partitioning/axis_partition.py:31(apply)
#         5    0.000    0.000    0.178    0.036 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:50(deploy_axis_func)
#         5    0.000    0.000    0.171    0.034 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/axis_partition.py:97(<listcomp>)
#       112    0.001    0.000    0.130    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2784(_get_computation_code)
# 0.35657611800024824

# %%
# Concatenate all profiling results
df_cache_profile_all = pd.concat(modin_cache_profile_data, ignore_index=True)

# %%
print_profile_per_task(modin_cache_profile_data, metric='percall', top_n=25)
# Out:
# ==================================================
# Tarefa: read file
# Top 25 funções por percall:
#
#                                                                             function  percall
#                                   ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.094616
#                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.003054
#                       /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.001983
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001701
#                                       ~:0 (<method 'match' of 're.Pattern' objects>) 0.001362
#                 ~:0 (<method 'finish' of 'pyarrow._dataset.DatasetFactory' objects>) 0.001329
#                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001004
#                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.000897
#                                                   ~:0 (<built-in method posix.stat>) 0.000656
#                              /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.000650
#                               /opt/conda/envs/cdle/lib/python3.7/pickle.py:464 (put) 0.000639
#                                             ~:0 (<method 'encode' of 'str' objects>) 0.000578
#                         /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.000574
#                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000572
#                                               ~:0 (<method 'get' of 'dict' objects>) 0.000563
#                   ~:0 (<method 'get_file_info' of 'pyarrow._fs.FileSystem' objects>) 0.000560
#                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000548
# /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.000464
#                                      ~:0 (<method 'write' of '_io.BytesIO' objects>) 0.000454
#                       /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.000394
#                                                  ~:0 (<built-in method builtins.id>) 0.000381
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000378
#                                            ~:0 (<method 'replace' of 'str' objects>) 0.000367
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/base.py:846 (tokenize) 0.000352
#                   /opt/conda/envs/cdle/lib/python3.7/pickle.py:865 (_batch_setitems) 0.000350
#
# ==================================================
# Tarefa: count
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000005
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3023 (__len__) 0.000004
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000003
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000003
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000003
#                                                                     /var/tmp/ipykernel_14262/2978216308.py:4 (count) 0.000002
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000001
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000000
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ==================================================
# Tarefa: count index length
# Top 25 funções por percall:
#
#                                                                                                             function  percall
#                                                        /var/tmp/ipykernel_14262/2978216308.py:7 (count_index_length) 0.000004
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:3075 (__getattribute__) 0.000004
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/storage_formats/pandas/query_compiler.py:71 (<lambda>) 0.000002
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/pandas/base.py:567 (_get_index) 0.000002
# /opt/conda/envs/cdle/lib/python3.7/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:220 (_get_index) 0.000001
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000001
#                                                                            ~:0 (<built-in method time.perf_counter>) 0.000000
#                                                                                 ~:0 (<built-in method builtins.len>) 0.000000
#                                                               ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ==================================================
# Tarefa: mean
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.064081
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.010520
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.006401
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.003497
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.003320
#                                                                   ~:0 (<built-in method posix.urandom>) 0.003107
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002752
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.002115
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.001946
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001477
#                                                                      ~:0 (<built-in method posix.stat>) 0.001397
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001257
#                                                                                    <string>:1 (__new__) 0.001182
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001071
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.000986
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000932
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000804
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000795
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.000770
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.000722
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.000703
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.000695
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000688
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000673
#                                                                    ~:0 (<built-in method builtins.len>) 0.000537
#
# ==================================================
# Tarefa: standard deviation
# Top 25 funções por percall:
#
#                                                                             function  percall
#                                   ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.037341
#                       /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.010455
#                                       ~:0 (<method 'match' of 're.Pattern' objects>) 0.006109
#                                                   ~:0 (<built-in method posix.stat>) 0.005922
#                                                ~:0 (<built-in method posix.urandom>) 0.005781
#                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.004247
#                              /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.003366
#                         /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.002972
#                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.002364
#                       /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.002062
#                        /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.001562
#                            /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.001395
#                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.001253
#                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.001209
# /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.001206
#                                                                 <string>:1 (__new__) 0.001173
#                                    ~:0 (<method 'send' of '_socket.socket' objects>) 0.001020
#                               /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.000933
#                        /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.000906
#                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.000880
#                     ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.000796
#                                          ~:0 (<built-in method builtins.isinstance>) 0.000787
#                                               ~:0 (<method 'get' of 'dict' objects>) 0.000781
#                               /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.000735
#                       /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.000716
#
# ==================================================
# Tarefa: mean of columns addition
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.194416
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.048589
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.030100
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.020173
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.015188
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012726
#                                                                      ~:0 (<built-in method posix.stat>) 0.011772
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010838
#                                                                   ~:0 (<built-in method posix.urandom>) 0.010661
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009601
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.006863
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006212
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005862
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005728
#                                                                                    <string>:1 (__new__) 0.005375
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.004935
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004517
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004508
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.003778
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003741
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003738
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003443
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003328
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003168
#                                                                    ~:0 (<built-in method builtins.len>) 0.002578
#
# ==================================================
# Tarefa: addition of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.140914
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039960
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.025029
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.017357
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012454
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010627
#                                                                      ~:0 (<built-in method posix.stat>) 0.010074
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.009180
#                                                                   ~:0 (<built-in method posix.urandom>) 0.008856
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007982
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005936
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.005135
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005031
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004979
#                                                                                    <string>:1 (__new__) 0.004458
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003878
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003733
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.003429
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003321
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003275
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003013
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.003003
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002833
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002755
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002650
#
# ==================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.202772
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.048728
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.029854
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.019763
#                                                                      ~:0 (<built-in method posix.stat>) 0.015631
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.015517
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.012947
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.010610
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.009508
#                                                                   ~:0 (<built-in method posix.urandom>) 0.008138
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.006828
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.006066
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005720
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.005653
#                                                                                    <string>:1 (__new__) 0.005342
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.004538
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004517
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.004076
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.003691
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003691
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003590
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.003493
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.003377
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:2840 (_graph_to_futures) 0.003305
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003094
#
# ==================================================
# Tarefa: multiplication of columns
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.150040
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039204
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.024100
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.017296
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012315
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010218
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.009203
#                                                                      ~:0 (<built-in method posix.stat>) 0.008421
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007773
#                                                                   ~:0 (<built-in method posix.urandom>) 0.005998
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005576
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.005276
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.005026
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004885
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004818
#                                                                                    <string>:1 (__new__) 0.004378
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003850
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003634
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003294
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003167
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.002934
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002895
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002744
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002606
#                                          /opt/conda/envs/cdle/lib/python3.7/pickle.py:943 (save_global) 0.002310
#
# ==================================================
# Tarefa: value counts
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.337790
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.056208
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.033054
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.020918
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.017921
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.015424
#                                                                   ~:0 (<built-in method posix.urandom>) 0.013477
#                                                                      ~:0 (<built-in method posix.stat>) 0.012666
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.011322
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.011206
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.008310
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.007473
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.007132
#                                                                                    <string>:1 (__new__) 0.006393
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.006194
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.006007
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.005391
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.004428
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.004349
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.004240
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.004005
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003824
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.003823
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.003581
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.003504
#
# ==================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 1.989250
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.298295
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.178416
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.112596
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.094942
#                                                                      ~:0 (<built-in method posix.stat>) 0.087043
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.080357
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.061444
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.058587
#                                                                   ~:0 (<built-in method posix.urandom>) 0.056554
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.042818
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.037825
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.034428
#                                                                                    <string>:1 (__new__) 0.033915
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.033910
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.033069
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.029027
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.026326
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.025716
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.022862
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.021920
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.020961
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.020613
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.019527
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.019356
#
# ==================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 1.922611
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.310982
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.188480
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.116550
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.098384
#                                                                      ~:0 (<built-in method posix.stat>) 0.089165
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.083101
#                                                                   ~:0 (<built-in method posix.urandom>) 0.075215
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.063773
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.061646
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.044791
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.039168
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.035853
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.035180
#                                                                                    <string>:1 (__new__) 0.034474
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.034332
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.028748
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.027361
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.026620
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.025861
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.023526
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.022635
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.021989
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.021714
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.019601
#
# ==================================================
# Tarefa: groupby statistics
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.123087
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.020518
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.012104
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.007267
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.006473
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.005447
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.004085
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.003889
#                                                                      ~:0 (<built-in method posix.stat>) 0.003873
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.002875
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.002519
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.002515
#                                                                                    <string>:1 (__new__) 0.002263
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.002174
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.002065
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.001829
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.001549
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.001498
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.001415
#                                                                   ~:0 (<built-in method posix.urandom>) 0.001407
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.001398
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.001373
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.001322
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.001320
#                                                         ~:0 (<method 'write' of '_io.BytesIO' objects>) 0.001063
#
# ==================================================
# Tarefa: join count
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.098589
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.039637
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.023814
#                                                                      ~:0 (<built-in method posix.stat>) 0.017152
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.015872
#                                                                   ~:0 (<built-in method posix.urandom>) 0.013670
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.012094
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.010470
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.008535
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.007784
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005654
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.005332
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004891
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.004516
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004513
#                                                                                    <string>:1 (__new__) 0.004310
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003610
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.003523
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.003018
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.002988
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.002890
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002867
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002765
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002503
#                                      /opt/conda/envs/cdle/lib/python3.7/pickle.py:865 (_batch_setitems) 0.002323
#
# ==================================================
# Tarefa: join
# Top 25 funções por percall:
#
#                                                                                                function  percall
#                                                      ~:0 (<method 'acquire' of '_thread.lock' objects>) 0.102945
#                                          /opt/conda/envs/cdle/lib/python3.7/tokenize.py:487 (_tokenize) 0.035180
#                                                          ~:0 (<method 'match' of 're.Pattern' objects>) 0.021768
#                                                                   ~:0 (<built-in method posix.urandom>) 0.013585
#                                                 /opt/conda/envs/cdle/lib/python3.7/pickle.py:485 (save) 0.013062
#                                                                      ~:0 (<built-in method posix.stat>) 0.011536
#                                                 /opt/conda/envs/cdle/lib/python3.7/re.py:273 (_compile) 0.010958
#                                            /opt/conda/envs/cdle/lib/python3.7/inspect.py:935 (getblock) 0.009120
#                                              /opt/conda/envs/cdle/lib/python3.7/pickle.py:441 (memoize) 0.007053
#                                          /opt/conda/envs/cdle/lib/python3.7/inspect.py:891 (tokeneater) 0.006833
#                                           /opt/conda/envs/cdle/lib/python3.7/tokenize.py:147 (_compile) 0.005136
#                                               /opt/conda/envs/cdle/lib/python3.7/types.py:164 (__get__) 0.004402
#                                             /opt/conda/envs/cdle/lib/python3.7/pickle.py:738 (save_str) 0.004071
#                                                /opt/conda/envs/cdle/lib/python3.7/pickle.py:225 (write) 0.003889
#                                                                                    <string>:1 (__new__) 0.003822
#                                                       ~:0 (<method 'send' of '_socket.socket' objects>) 0.003497
#                                                  /opt/conda/envs/cdle/lib/python3.7/re.py:234 (compile) 0.003232
#                                         /opt/conda/envs/cdle/lib/python3.7/pickle.py:201 (commit_frame) 0.002891
#                                        ~:0 (<built-in method __new__ of type object at 0x55ded16126e0>) 0.002651
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.002579
#                                                  /opt/conda/envs/cdle/lib/python3.7/enum.py:633 (value) 0.002463
#                                                                  ~:0 (<method 'get' of 'dict' objects>) 0.002451
#                                           /opt/conda/envs/cdle/lib/python3.7/pickle.py:761 (save_tuple) 0.002374
# /opt/conda/envs/cdle/lib/python3.7/site-packages/dask/highlevelgraph.py:317 (__dask_distributed_pack__) 0.002277
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/distributed/client.py:1628 (submit) 0.001989

# %%
# Restart the Dask client to clear cluster state and free resources
client.restart()
# Out:
# <Client: 'tcp://127.0.0.1:38683' processes=0 threads=0, memory=0 B>

# %% [markdown]
# # Joblib

# %% [markdown]
# This part of the notebook defines a set of benchmark functions to evaluate the performance of common data processing operations using Joblib.
#
# The dataset is loaded from a Parquet file and a benchmark_joblib function is also provided to run all tasks in parallel using Joblib and measure execution time.
#
# The goal is to compare execution speed across different backends or configurations.

# %%
joblib_data = pd.read_parquet("Samples/sample_2009_2010_large_clean.parquet")

# %%
# Helper function to convert benchmark results into a pandas DataFrame
def get_results(benchmarks):
    """Returns a pandas DataFrame containing benchmark results"""
    return pd.DataFrame.from_dict(benchmarks)

# Funções de operações
def read_file_parquet(df=None):
    return pd.read_parquet("Samples/sample_2009_2010_large_clean.parquet")

def count(df=None):
    return len(df)

def count_index_length(df=None):
    return len(df.index)

def mean(df):
    return df.Fare_Amt.mean()

def standard_deviation(df):
    return df.Fare_Amt.std()

def mean_of_sum(df):
    return (df.Fare_Amt + df.Tip_Amt).mean()

def sum_columns(df):
    x = df.Fare_Amt + df.Tip_Amt

    return x

def mean_of_product(df):
    return (df.Fare_Amt * df.Tip_Amt).mean()

def product_columns(df):
    x = df.Fare_Amt * df.Tip_Amt

    return x

def value_counts(df):
    val_counts = df.Fare_Amt.value_counts()
    return val_counts

def complicated_arithmetic_operation(df):
    theta_1 = df.Start_Lon
    phi_1 = df.Start_Lat
    theta_2 = df.End_Lon
    phi_2 = df.End_Lat
    temp = (np.sin((theta_2 - theta_1) / 2 * np.pi / 180) ** 2
           + np.cos(theta_1 * np.pi / 180) * np.cos(theta_2 * np.pi / 180) * np.sin((phi_2 - phi_1) / 2 * np.pi / 180) ** 2)
    ret = np.multiply(np.arctan2(np.sqrt(temp), np.sqrt(1-temp)),2)

    return ret

def mean_of_complicated_arithmetic_operation(df):
    theta_1 = df.Start_Lon
    phi_1 = df.Start_Lat
    theta_2 = df.End_Lon
    phi_2 = df.End_Lat
    temp = (np.sin((theta_2 - theta_1) / 2 * np.pi / 180) ** 2
           + np.cos(theta_1 * np.pi / 180) * np.cos(theta_2 * np.pi / 180) * np.sin((phi_2 - phi_1) / 2 * np.pi / 180) ** 2)
    ret = np.multiply(np.arctan2(np.sqrt(temp), np.sqrt(1-temp)),2)
    return ret.mean()

def groupby_statistics(df):
    gb = df.groupby(by='Passenger_Count').agg(
      {
        'Fare_Amt': ['mean', 'std'],
        'Tip_Amt': ['mean', 'std']
      }
    )
    return gb

other = pd.DataFrame(groupby_statistics(joblib_data))
other.columns = pd.Index([e[0]+'_' + e[1] for e in other.columns.tolist()])

def join_count(df, other):
    return len(df.merge(other, left_index=True, right_index=True))

def join_data(df, other):
    return df.merge(other, left_index=True, right_index=True)

# %%
# === Joblib benchmarking utility ===

# Run benchmark tasks in parallel using Joblib
def benchmark_joblib(tasks, n_jobs=-1, save_path=None):
    """
    Executes parallel benchmarks for a list of tasks and optionally saves the results.
    
    tasks: list of tuples (function, df, kwargs dict, task name)
    n_jobs: number of parallel jobs (-1 = use all cores)
    save_path: optional path to save results as a Parquet file
    
    Returns: DataFrame with 'task' as index and 'duration' in seconds
    """

    def run_task(f, df, kwargs, name):
        start = time.perf_counter()
        f(df, **kwargs)
        elapsed = time.perf_counter() - start
        return (name, elapsed)

    # Run all tasks in parallel
    results = Parallel(n_jobs=n_jobs)(
        delayed(run_task)(f, df, kwargs, name) for f, df, kwargs, name in tasks
    )

    # Create DataFrame and clean duplicates
    df_results = pd.DataFrame(results, columns=['task', 'duration']) \
                   .drop_duplicates(subset='task') \
                   .set_index('task')

    # Save to Parquet if specified
    if save_path:
        df_results.to_parquet(save_path)
        print(f'O arquivo Parquet foi salvo em {save_path}.')

    return df_results

# %% [markdown]
# Three dictionaries (joblib_benchmarks, joblib_benchmarks_filtered, joblib_benchmarks_cache) are initialized to store benchmark results.
#
# Then, a list of tasks is defined, where each task represents a function to benchmark (e.g., count, mean, groupby) along with its inputs.
#
# These tasks will be executed in parallel using Joblib to evaluate the performance of various data processing operations.

# %%
joblib_benchmarks = {
    'duration': [],  # in seconds
    'task': [],
}

joblib_benchmarks_filtered = {
    'duration': [],  # in seconds
    'task': [],
}

joblib_benchmarks_cache = {
    'duration': [],  # in seconds
    'task': [],
}

# %%
# === Define the list of tasks to run in parallel using Joblib ===
tasks = [
    (read_file_parquet, None, {}, "read file"),
    (count, joblib_data, {}, "count"),
    (count_index_length, joblib_data, {}, "count index length"),
    (mean, joblib_data, {}, "mean"),
    (standard_deviation, joblib_data, {}, "standard deviation"),
    (mean_of_sum, joblib_data, {}, "mean of columns addition"),
    (sum_columns, joblib_data, {}, "addition of columns"),
    (mean_of_product, joblib_data, {}, "mean of columns multiplication"),
    (product_columns, joblib_data, {}, "multiplication of columns"),
    (value_counts, joblib_data, {}, "value counts"),
    (complicated_arithmetic_operation, joblib_data, {}, "complex arithmetic ops"),
    (mean_of_complicated_arithmetic_operation, joblib_data, {}, "mean of complex arithmetic ops"),
    (groupby_statistics, joblib_data, {}, "groupby statistics"),
    (join_count, joblib_data, {'other': other}, "join count"),
    (join_data, joblib_data, {'other': other}, "join"),
]

# %%
df_results = benchmark_joblib(tasks, n_jobs=-1, save_path='Results_Joblib_L/joblib_local_large')
print(df_results)
# Out:
# O arquivo Parquet foi salvo em Results_Joblib_L/joblib_local_large.
#                                 duration
# task
# read file                       0.146607
# count                           0.000011
# count index length              0.000004
# mean                            0.000722
# standard deviation              0.002493
# mean of columns addition        0.001134
# addition of columns             0.001031
# mean of columns multiplication  0.001218
# multiplication of columns       0.000955
# value counts                    0.002205
# complex arithmetic ops          0.011912
# mean of complex arithmetic ops  0.011562
# groupby statistics              0.006491
# join count                      0.003327
# join                            0.003092

# %% [markdown]
# # cProfile

# %% [markdown]
# The function benchmark_cprofile benchmarks and profiles the execution of data processing functions using Python’s cProfile.
#
# It collects both execution time and profiling statistics, then runs it for a set of predefined tasks. Finally, it aggregates all profiling statistics into a single DataFrame for further analysis or visualization.

# %%
def benchmark_cprofile(f, df, benchmarks, name, profile_data=None, **kwargs):
    """
    Benchmark and profile the execution of a function using cProfile (without I/O).
    
    Parameters:
        f (callable): The function to benchmark.
        df (DataFrame): The DataFrame or data to pass as input.
        benchmarks (dict): Dictionary to store duration and task name.
        name (str): Name of the task/function.
        profile_data (list): List to store detailed profiling statistics.
        **kwargs: Additional arguments passed to the function.
    """ 
    pr = cProfile.Profile()
    pr.enable()

    start_time = time.perf_counter()
    ret = f(df, **kwargs)
    duration = time.perf_counter() - start_time

    pr.disable()

    benchmarks['duration'].append(duration)
    benchmarks['task'].append(name)
    print(f"{name} took: {duration:.4f} seconds")

    # Display top 15 most time-consuming function calls
    ps = pstats.Stats(pr)
    ps.sort_stats(pstats.SortKey.CUMULATIVE)
    ps.print_stats(15)

    # Save detailed profiling statistics into a list of DataFrames
    if profile_data is not None:
        stats_data = []
        for func, stat in ps.stats.items():
            filename, lineno, function = func
            ncalls, _, percall, cumtime, _ = stat
            stats_data.append({
                'task': name,
                'function': f"{filename}:{lineno} ({function})",
                'percall': percall,
                'cumtime': cumtime,
                'ncalls': ncalls
            })
        profile_data.append(pd.DataFrame(stats_data))

    return duration

# %%
joblib_benchmarks_cprofile = {'duration': [], 'task': []}
joblib_profile_data = []

# === Execute benchmarks with cProfile for all tasks ===
benchmark_cprofile(read_file_parquet, df=None, benchmarks=joblib_benchmarks_cprofile, name='read file', profile_data=joblib_profile_data)
benchmark_cprofile(count, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='count', profile_data=joblib_profile_data)
benchmark_cprofile(count_index_length, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='count index length', profile_data=joblib_profile_data)
benchmark_cprofile(mean, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='mean', profile_data=joblib_profile_data)
benchmark_cprofile(standard_deviation, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='standard deviation', profile_data=joblib_profile_data)
benchmark_cprofile(mean_of_sum, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='mean of columns addition', profile_data=joblib_profile_data)
benchmark_cprofile(sum_columns, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='addition of columns', profile_data=joblib_profile_data)
benchmark_cprofile(mean_of_product, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='mean of columns multiplication', profile_data=joblib_profile_data)
benchmark_cprofile(product_columns, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='multiplication of columns', profile_data=joblib_profile_data)
benchmark_cprofile(value_counts, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='value counts', profile_data=joblib_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='complex arithmetic ops', profile_data=joblib_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='mean of complex arithmetic ops', profile_data=joblib_profile_data)
benchmark_cprofile(groupby_statistics, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='groupby statistics', profile_data=joblib_profile_data)
benchmark_cprofile(join_count, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='join count', other=other, profile_data=joblib_profile_data)
benchmark_cprofile(join_data, df=joblib_data, benchmarks=joblib_benchmarks_cprofile, name='join', other=other, profile_data=joblib_profile_data)
# Out:
# read file took: 0.1022 seconds
#          2473 function calls (2462 primitive calls) in 0.102 seconds
#
#    Ordered by: cumulative time
#    List reduced from 400 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.102    0.102 /var/tmp/ipykernel_14262/3872611389.py:6(read_file_parquet)
#         1    0.000    0.000    0.102    0.102 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:433(read_parquet)
#         1    0.000    0.000    0.102    0.102 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201(read)
#         1    0.000    0.000    0.056    0.056 {method 'to_pandas' of 'pyarrow.lib._PandasConvertible' objects}
#         1    0.000    0.000    0.056    0.056 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756(table_to_blockmanager)
#         1    0.000    0.000    0.054    0.054 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1109(_table_to_blocks)
#         1    0.052    0.052    0.052    0.052 {pyarrow.lib.table_to_blocks}
#         1    0.000    0.000    0.045    0.045 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1551(read_table)
#         1    0.000    0.000    0.043    0.043 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440(read)
#         1    0.043    0.043    0.043    0.043 {method 'to_table' of 'pyarrow._dataset.Dataset' objects}
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1116(<listcomp>)
#         5    0.000    0.000    0.003    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:683(_reconstruct_block)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:984(__from_arrow__)
#         1    0.002    0.002    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377(__init__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:858(_deserialize_column_index)
#
#
# count took: 0.0000 seconds
#          9 function calls (7 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:9(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352(__len__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          7 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:12(count_index_length)
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806(__len__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#
#
# mean took: 0.0007 seconds
#          185 function calls in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 79 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:15(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258(_get_values)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214(_maybe_get_mask)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:61(isna)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:144(_isna)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221(_isna_array)
#         3    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#
#
# standard deviation took: 0.0012 seconds
#          279 function calls (278 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 90 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:18(standard_deviation)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10610(std)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10317(std)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271(_stat_function_ddof)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#       2/1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838(nanstd)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.001    0.001    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877(nanvar)
#         3    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45(_sum)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258(_get_values)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(putmask)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214(_maybe_get_mask)
#
#
# mean of columns addition took: 0.0006 seconds
#          455 function calls (453 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 156 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:21(mean_of_sum)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         3    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#
#
# addition of columns took: 0.0004 seconds
#          299 function calls (297 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#    List reduced from 115 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:24(sum_columns)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#        58    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#
#
# mean of columns multiplication took: 0.0007 seconds
#          455 function calls (453 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 156 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:29(mean_of_product)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.mul}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#
#
# multiplication of columns took: 0.0005 seconds
#          299 function calls (297 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#    List reduced from 115 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:32(product_columns)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.mul}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#        58    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:74(get_op_result_name)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#
#
# value counts took: 0.0015 seconds
#          568 function calls (564 primitive calls) in 0.002 seconds
#
#    Ordered by: cumulative time
#    List reduced from 156 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:37(value_counts)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/base.py:874(value_counts)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796(value_counts)
#         1    0.001    0.001    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876(value_counts_arraylike)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/util/_decorators.py:302(wrapper)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258(sort_values)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343(nargsort)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:6279(ensure_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375(__new__)
#       135    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931(new_block)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:103(_ensure_data)
#
#
# complex arithmetic ops took: 0.0142 seconds
#          6642 function calls (6583 primitive calls) in 0.014 seconds
#
#    Ordered by: cumulative time
#    List reduced from 202 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.014    0.014 /var/tmp/ipykernel_14262/3872611389.py:41(complicated_arithmetic_operation)
#         8    0.000    0.000    0.009    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.007    0.001    0.009    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.005    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.005    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        19    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#        19    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#        32    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         6    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#        19    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         6    0.001    0.000    0.001    0.000 {built-in method _operator.truediv}
#         3    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:305(<genexpr>)
#
#
# mean of complex arithmetic ops took: 0.0125 seconds
#          6554 function calls (6499 primitive calls) in 0.012 seconds
#
#    Ordered by: cumulative time
#    List reduced from 225 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.012    0.012 /var/tmp/ipykernel_14262/3872611389.py:52(mean_of_complicated_arithmetic_operation)
#         8    0.000    0.000    0.008    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.007    0.001    0.008    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.004    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.004    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        28    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#        19    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#        19    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         6    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:318(reconstruct)
#        26    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#
#
# groupby statistics took: 0.0070 seconds
#          4022 function calls (3968 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time
#    List reduced from 447 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 /var/tmp/ipykernel_14262/3872611389.py:62(groupby_statistics)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:964(aggregate)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:143(agg)
#         1    0.000    0.000    0.007    0.007 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405(agg_dict_like)
#         1    0.000    0.000    0.006    0.006 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:435(<dictcomp>)
#       6/2    0.000    0.000    0.006    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:225(aggregate)
#         2    0.000    0.000    0.006    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278(_aggregate_multiple_funcs)
#         2    0.000    0.000    0.003    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1634(mean)
#         2    0.000    0.000    0.003    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:322(_cython_agg_general)
#         2    0.000    0.000    0.003    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:338(array_func)
#         2    0.000    0.000    0.003    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:991(_cython_operation)
#         2    0.000    0.000    0.002    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1723(std)
#         2    0.002    0.001    0.002    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2790(_get_cythonized_result)
#         2    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:631(cython_operation)
#         2    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:488(_cython_op_ndim_compat)
#
#
# join count took: 0.0039 seconds
#          3220 function calls (3191 primitive calls) in 0.004 seconds
#
#    Ordered by: cumulative time
#    List reduced from 347 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.004    0.004 /var/tmp/ipykernel_14262/3872611389.py:74(join_count)
#         1    0.000    0.000    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#     74/66    0.000    0.000    0.002    0.000 {built-in method builtins.all}
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#        22    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#         8    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        16    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475(_concatenate_join_units)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:670(<lambda>)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221(_isna_array)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259(_isna_string_dtype)
#
#
# join took: 0.0034 seconds
#          3024 function calls (3003 primitive calls) in 0.003 seconds
#
#    Ordered by: cumulative time
#    List reduced from 311 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.003    0.003 /var/tmp/ipykernel_14262/3872611389.py:77(join_data)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#     74/66    0.000    0.000    0.002    0.000 {built-in method builtins.all}
#        11    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#        22    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#         8    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        16    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:670(<lambda>)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221(_isna_array)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475(_concatenate_join_units)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259(_isna_string_dtype)
# 0.0034254100000907783

# %%
# Concatenate all DataFrames
df_profile_all = pd.concat(joblib_profile_data, ignore_index=True)

# %% [markdown]
# Once again, The print_profile_per_task function is used to print the slowest functions for each task that was profiled using cProfile.
#
# Each task (like 'mean', 'join', etc.) has a corresponding DataFrame in the profile_data_list, which contains profiling information (e.g. time per function call and total cumulative time).
#
# The function works as follows:
#
# - Iterates over each DataFrame in the list (one per task).
# - For each task, it sorts the profiling stats by the selected metric (percall or cumtime).
# - Prints the top N slowest functions according to the selected metric.
# - Displays the task name and a table with the function name and the chosen metric.

# %%
def print_profile_per_task(profile_data_list, metric='percall', top_n=10):
    for df in profile_data_list:
        task_name = df['task'].iloc[0]  # todas as linhas têm o mesmo 'task'
        df_sorted = df.sort_values(by=metric, ascending=False).head(top_n)

        print(f"\n{'=' * 60}")
        print(f"Tarefa: {task_name}")
        print(f"Top {top_n} funções por '{metric}':\n")
        print(df_sorted[['function', metric]].to_string(index=False))

# %%
print_profile_per_task(joblib_profile_data, metric='percall', top_n=25)
# Out:
# ============================================================
# Tarefa: read file
# Top 25 funções por 'percall':
#
#                                                                                                                function  percall
#                                                                                     ~:0 (<pyarrow.lib.table_to_blocks>) 0.051906
#                                                         ~:0 (<method 'to_table' of 'pyarrow._dataset.Dataset' objects>) 0.043043
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377 (__init__) 0.001684
#                                                                                     ~:0 (<built-in method numpy.array>) 0.000493
#                                                                        ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000385
#                                           ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000357
#                                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201 (read) 0.000214
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:984 (__from_arrow__) 0.000165
#                                                                             ~:0 (<built-in method builtins.isinstance>) 0.000152
#                                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440 (read) 0.000100
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/_arrow_utils.py:49 (__init__) 0.000089
#                                                                          ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000082
#                                                                                         ~:0 (<built-in method io.open>) 0.000076
#                                                           ~:0 (<built-in method pandas._libs.tslibs.offsets.to_offset>) 0.000076
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:1073 (_engine) 0.000070
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/_arrow_utils.py:9 (pyarrow_array_to_numpy_and_mask) 0.000064
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/base.py:425 (find) 0.000056
#                                          ~:0 (<method 'make_fragment' of 'pyarrow._dataset.ParquetFileFormat' objects>) 0.000055
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756 (table_to_blockmanager) 0.000053
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:683 (_reconstruct_block) 0.000052
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:794 (_get_extension_dtypes) 0.000050
#                                                     /opt/conda/envs/cdle/lib/python3.7/json/encoder.py:204 (iterencode) 0.000049
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000049
#                                                     /opt/conda/envs/cdle/lib/python3.7/json/decoder.py:343 (raw_decode) 0.000048
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1130 (<listcomp>) 0.000047
#
# ============================================================
# Tarefa: count
# Top 25 funções por 'percall':
#
#                                                                                    function  percall
#                                                        ~:0 (<built-in method builtins.len>) 0.000004
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352 (__len__) 0.000003
#                                            /var/tmp/ipykernel_14262/3872611389.py:9 (count) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806 (__len__) 0.000001
#                                                   ~:0 (<built-in method time.perf_counter>) 0.000000
#                                      ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ============================================================
# Tarefa: count index length
# Top 25 funções por 'percall':
#
#                                                                                    function  percall
#                              /var/tmp/ipykernel_14262/3872611389.py:12 (count_index_length) 0.000003
#                                                        ~:0 (<built-in method builtins.len>) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/range.py:806 (__len__) 0.000001
#                                      ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000001
#                                                   ~:0 (<built-in method time.perf_counter>) 0.000000
#
# ============================================================
# Tarefa: mean
# Top 25 funções por 'percall':
#
#                                                                                             function  percall
#                                                     ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000226
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000222
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000016
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000016
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000015
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000014
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000012
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000011
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000011
#                                                     /var/tmp/ipykernel_14262/3872611389.py:15 (mean) 0.000010
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000009
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:87 (<genexpr>) 0.000008
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368 (mean) 0.000008
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000008
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000007
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000007
#                                                          ~:0 (<built-in method builtins.isinstance>) 0.000007
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000006
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740 (mean) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000005
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:80 (check) 0.000004
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2218 (is_object) 0.000004
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:144 (_isna) 0.000004
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396 (new_func) 0.000004
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:673 (is_integer_dtype) 0.000004
#
# ============================================================
# Tarefa: standard deviation
# Top 25 funções por 'percall':
#
#                                                                                             function  percall
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877 (nanvar) 0.000507
#                                                     ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000156
#                        ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000079
#                                                     ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000070
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000058
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000046
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838 (nanstd) 0.000020
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000016
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000012
#                                       /var/tmp/ipykernel_14262/3872611389.py:18 (standard_deviation) 0.000011
#                                                          ~:0 (<built-in method builtins.isinstance>) 0.000011
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271 (_stat_function_ddof) 0.000010
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000010
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10317 (std) 0.000009
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000008
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000008
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45 (_sum) 0.000007
#                                                           <__array_function__ internals>:2 (putmask) 0.000007
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:673 (is_integer_dtype) 0.000006
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000006
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000006
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10610 (std) 0.000005
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000005
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000005
#
# ============================================================
# Tarefa: mean of columns addition
# Top 25 funções por 'percall':
#
#                                                                                              function  percall
#                                                      ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000114
#                                                                 ~:0 (<built-in method _operator.add>) 0.000077
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000031
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000024
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000016
#                                                           ~:0 (<built-in method builtins.isinstance>) 0.000016
#                                               /var/tmp/ipykernel_14262/3872611389.py:21 (mean_of_sum) 0.000014
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000011
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000011
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000010
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000009
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000009
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185 (arithmetic_op) 0.000009
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000008
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000008
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54 (new_method) 0.000007
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000007
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000007
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000007
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000006
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000005
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:438 (__exit__) 0.000005
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000005
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000005
#
# ============================================================
# Tarefa: addition of columns
# Top 25 funções por 'percall':
#
#                                                                                                   function  percall
#                                                                      ~:0 (<built-in method _operator.add>) 0.000155
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000013
#                                                                ~:0 (<built-in method builtins.isinstance>) 0.000010
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000009
#                                                                   ~:0 (<built-in method builtins.getattr>) 0.000008
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000008
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000008
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000007
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000006
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1718 (validate_all_hashable) 0.000005
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000005
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000005
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000004
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000004
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000004
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000004
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/__init__.py:151 (align_method_SERIES) 0.000004
#                                                                       ~:0 (<built-in method builtins.len>) 0.000004
#                                                    /var/tmp/ipykernel_14262/3872611389.py:24 (sum_columns) 0.000004
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000003
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:577 (name) 0.000003
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:565 (_get_root) 0.000003
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000003
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185 (arithmetic_op) 0.000003
#
# ============================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por 'percall':
#
#                                                                                              function  percall
#                                                                 ~:0 (<built-in method _operator.mul>) 0.000212
#                                                      ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000116
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000031
#                                                           ~:0 (<built-in method builtins.isinstance>) 0.000019
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185 (arithmetic_op) 0.000017
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000014
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000013
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000012
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000012
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000008
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000007
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000007
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000007
#                                           /var/tmp/ipykernel_14262/3872611389.py:29 (mean_of_product) 0.000007
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000007
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000006
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000006
#                                                              ~:0 (<built-in method builtins.getattr>) 0.000006
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000005
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000005
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000005
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000004
#
# ============================================================
# Tarefa: multiplication of columns
# Top 25 funções por 'percall':
#
#                                                                                              function  percall
#                                                                 ~:0 (<built-in method _operator.mul>) 0.000156
#                                                           ~:0 (<built-in method builtins.isinstance>) 0.000046
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000012
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000009
#                                                              ~:0 (<built-in method builtins.getattr>) 0.000008
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000008
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000007
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000006
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000006
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000006
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000006
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000005
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000005
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000005
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000005
#                                           /var/tmp/ipykernel_14262/3872611389.py:32 (product_columns) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000005
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000004
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000004
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/inference.py:321 (is_hashable) 0.000004
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000004
#                                                                  ~:0 (<built-in method builtins.len>) 0.000004
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000004
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:96 (_maybe_match_name) 0.000004
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185 (arithmetic_op) 0.000004
#
# ============================================================
# Tarefa: value counts
# Top 25 funções por 'percall':
#
#                                                                                                      function  percall
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876 (value_counts_arraylike) 0.000947
#                                                           ~:0 (<method 'argsort' of 'numpy.ndarray' objects>) 0.000041
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343 (nargsort) 0.000033
#                                                                   ~:0 (<built-in method builtins.isinstance>) 0.000033
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000024
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258 (sort_values) 0.000018
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796 (value_counts) 0.000018
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000013
#                                                                          ~:0 (<built-in method numpy.arange>) 0.000012
#                                 ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000012
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000011
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000009
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4587 (__getitem__) 0.000009
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000009
#                                                      /var/tmp/ipykernel_14262/3872611389.py:37 (value_counts) 0.000009
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:605 (_simple_new) 0.000009
#                                                                    <__array_function__ internals>:2 (nonzero) 0.000008
#                                                                          ~:0 (<built-in method builtins.len>) 0.000008
#                                                                      ~:0 (<built-in method builtins.getattr>) 0.000008
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000007
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000007
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000007
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/numeric.py:140 (_ensure_array) 0.000006
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1420 (is_extension_array_dtype) 0.000005
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000005
#
# ============================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.007425
#                                                              ~:0 (<built-in method _operator.truediv>) 0.001093
#                                                                  ~:0 (<built-in method _operator.mul>) 0.000566
#                                                       ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000500
#                                                                  ~:0 (<built-in method _operator.sub>) 0.000281
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000269
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000227
#                                                                  ~:0 (<built-in method _operator.pow>) 0.000177
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000141
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000133
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000106
#                           /var/tmp/ipykernel_14262/3872611389.py:41 (complicated_arithmetic_operation) 0.000106
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000100
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000095
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000085
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000082
#                                                               ~:0 (<built-in method builtins.getattr>) 0.000078
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000070
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000070
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000070
#                                                                  ~:0 (<built-in method _operator.add>) 0.000066
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000060
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000059
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/roperator.py:12 (rsub) 0.000056
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000054
#
# ============================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                                    function  percall
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.006974
#                                                                   ~:0 (<built-in method _operator.truediv>) 0.000536
#                                                                       ~:0 (<built-in method _operator.mul>) 0.000379
#                                                                 ~:0 (<built-in method builtins.isinstance>) 0.000244
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000214
#                                                                       ~:0 (<built-in method _operator.sub>) 0.000177
#                                                                       ~:0 (<built-in method _operator.pow>) 0.000153
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000125
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000124
#                                                            ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000119
#                                                            ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000116
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000107
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1858 (maybe_coerce_values) 0.000099
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000093
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000085
#                        /var/tmp/ipykernel_14262/3872611389.py:52 (mean_of_complicated_arithmetic_operation) 0.000083
#                                                                       ~:0 (<built-in method _operator.add>) 0.000078
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000078
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000077
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000076
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/roperator.py:12 (rsub) 0.000074
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000072
#                                                                    ~:0 (<built-in method builtins.getattr>) 0.000072
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000071
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000069
#
# ============================================================
# Tarefa: groupby statistics
# Top 25 funções por 'percall':
#
#                                                                                                        function  percall
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2790 (_get_cythonized_result) 0.001599
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:525 (_call_cython_op) 0.001265
#                                   ~:0 (<method 'factorize' of 'pandas._libs.hashtable.Int64HashTable' objects>) 0.000691
#                                                                     ~:0 (<built-in method builtins.isinstance>) 0.000148
#                                                                  ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000127
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000104
#                                                                  ~:0 (<pandas._libs.algos.take_1d_int64_int64>) 0.000088
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:571 (factorize) 0.000056
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278 (_aggregate_multiple_funcs) 0.000054
#                                                                        ~:0 (<built-in method builtins.getattr>) 0.000048
#                                                                            ~:0 (<built-in method builtins.len>) 0.000048
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000046
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405 (agg_dict_like) 0.000043
#                                                                        ~:0 (<built-in method builtins.hasattr>) 0.000042
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:680 (get_grouper) 0.000042
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000041
#                                                           <frozen importlib._bootstrap>:1009 (_handle_fromlist) 0.000037
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1811 (_form_blocks) 0.000033
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000033
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:846 (__init__) 0.000032
#                                                                             ~:0 (<built-in method numpy.array>) 0.000030
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000029
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/concat.py:626 (_make_concat_multiindex) 0.000028
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/common.py:224 (asarray_tuplesafe) 0.000028
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:7515 (groupby) 0.000028
#
# ============================================================
# Tarefa: join count
# Top 25 funções por 'percall':
#
#                                                                                                                       function  percall
#                                                                           ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.000865
#                                                                                           ~:0 (<built-in method numpy.arange>) 0.000222
#                                                                               ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000097
#                                                                                    ~:0 (<built-in method builtins.isinstance>) 0.000095
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000067
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000064
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.000057
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:327 (_inner_indexer) 0.000051
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000050
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000049
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.000046
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000044
#                                                                                           ~:0 (<built-in method builtins.all>) 0.000041
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000041
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000038
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000038
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000036
#                                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/base.py:425 (find) 0.000033
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:517 (_take_preprocess_indexer_and_fill_value) 0.000032
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711 (get_result) 0.000029
#                                                                                 ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000029
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:551 (_get_empty_dtype) 0.000029
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/base.py:208 (construct_from_string) 0.000027
#                                                                                           ~:0 (<built-in method builtins.len>) 0.000027
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:3126 (_intersection_via_get_indexer) 0.000027
#
# ============================================================
# Tarefa: join
# Top 25 funções por 'percall':
#
#                                                                                                                       function  percall
#                                                                           ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.000867
#                                                                               ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000333
#                                                                                    ~:0 (<built-in method builtins.isinstance>) 0.000078
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000073
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:935 (__eq__) 0.000065
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.000060
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000054
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000049
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000048
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000047
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000038
#                                                                                           ~:0 (<built-in method builtins.all>) 0.000036
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000033
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:190 (is_sparse) 0.000033
#                                                                                           ~:0 (<built-in method builtins.len>) 0.000030
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000029
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:517 (_take_preprocess_indexer_and_fill_value) 0.000029
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:665 (<lambda>) 0.000028
#                                                                          <frozen importlib._bootstrap>:1009 (_handle_fromlist) 0.000027
#                                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381 (is_na) 0.000026
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:551 (_get_empty_dtype) 0.000026
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000026
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000026
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607 (<genexpr>) 0.000025
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585 (_is_uniform_join_units) 0.000024

# %% [markdown]
# **Operations with filtering**

# %%
print(f"Tipo do DataFrame : {type(joblib_data)}")

# Apply filter using query
expr_filter = 'Tip_Amt >= 1 and Tip_Amt <= 5'
joblib_filtered = joblib_data.query(expr_filter)

print(f"Tipo do DataFrame filtrado: {type(joblib_filtered)}")
# Out:
# Tipo do DataFrame : <class 'pandas.core.frame.DataFrame'>
# Tipo do DataFrame filtrado: <class 'pandas.core.frame.DataFrame'>

# %%
tasks_filtered = [
    (read_file_parquet, None, {}, "read file"),
    (count, joblib_filtered, {}, "count"),
    (count_index_length, joblib_filtered, {}, "count index length"),
    (mean, joblib_filtered, {}, "mean"),
    (standard_deviation, joblib_filtered, {}, "standard deviation"),
    (mean_of_sum, joblib_filtered, {}, "mean of columns addition"),
    (sum_columns, joblib_filtered, {}, "addition of columns"),
    (mean_of_product, joblib_filtered, {}, "mean of columns multiplication"),
    (product_columns, joblib_filtered, {}, "multiplication of columns"),
    (value_counts, joblib_filtered, {}, "value counts"),
    (complicated_arithmetic_operation, joblib_filtered, {}, "complex arithmetic ops"),
    (mean_of_complicated_arithmetic_operation, joblib_filtered, {}, "mean of complex arithmetic ops"),
    (groupby_statistics, joblib_filtered, {}, "groupby statistics"),
    (join_count, joblib_filtered, {'other': other}, "join count"),
    (join_data, joblib_filtered, {'other': other}, "join"),
]

# %% [markdown]
# **Save Results**

# %%
df_results_filtered = benchmark_joblib(tasks_filtered, n_jobs=-1, save_path='Results_Joblib_L/joblib_filtered_local_large')
print(df_results_filtered)
# Out:
# O arquivo Parquet foi salvo em Results_Joblib_L/joblib_filtered_local_large.
#                                 duration
# task
# read file                       0.134185
# count                           0.000005
# count index length              0.000003
# mean                            0.000587
# standard deviation              0.000595
# mean of columns addition        0.000707
# addition of columns             0.000549
# mean of columns multiplication  0.000676
# multiplication of columns       0.000546
# value counts                    0.000893
# complex arithmetic ops          0.005339
# mean of complex arithmetic ops  0.005209
# groupby statistics              0.003475
# join count                      0.002593
# join                            0.002739

# %% [markdown]
# **Filtered with cProfile**

# %% [markdown]
# After that, a filtered benchmark was also performed for Joblib by selecting only rows where Tip_Amt is between 1 and 5.
#
# This filtered DataFrame was then used to re-run the same set of tasks to evaluate Joblib's performance under common preprocessing conditions.

# %%
joblib_benchmarks_filtered_cprofile = {'duration': [], 'task': []}
joblib_filtered_profile_data = []

# %%
# Execute benchmarks with cProfile
benchmark_cprofile(read_file_parquet, df=None, benchmarks=joblib_benchmarks_filtered_cprofile, name='read file', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(count, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='count', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(count_index_length, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='count index length', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(mean, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='mean', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(standard_deviation, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='standard deviation', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(mean_of_sum, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='mean of columns addition', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(sum_columns, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='addition of columns', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(mean_of_product, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='mean of columns multiplication', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(product_columns, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='multiplication of columns', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(value_counts, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='value counts', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='complex arithmetic ops', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='mean of complex arithmetic ops', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(groupby_statistics, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='groupby statistics', profile_data=joblib_filtered_profile_data)
benchmark_cprofile(join_count, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='join count', other=other, profile_data=joblib_filtered_profile_data)
benchmark_cprofile(join_data, df=joblib_filtered, benchmarks=joblib_benchmarks_filtered_cprofile, name='join', other=other, profile_data=joblib_filtered_profile_data)
# Out:
# read file took: 0.1016 seconds
#          2473 function calls (2462 primitive calls) in 0.102 seconds
#
#    Ordered by: cumulative time
#    List reduced from 400 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.102    0.102 /var/tmp/ipykernel_14262/3872611389.py:6(read_file_parquet)
#         1    0.000    0.000    0.102    0.102 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:433(read_parquet)
#         1    0.000    0.000    0.101    0.101 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201(read)
#         1    0.000    0.000    0.055    0.055 {method 'to_pandas' of 'pyarrow.lib._PandasConvertible' objects}
#         1    0.000    0.000    0.055    0.055 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756(table_to_blockmanager)
#         1    0.000    0.000    0.053    0.053 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1109(_table_to_blocks)
#         1    0.051    0.051    0.051    0.051 {pyarrow.lib.table_to_blocks}
#         1    0.000    0.000    0.045    0.045 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1551(read_table)
#         1    0.000    0.000    0.043    0.043 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440(read)
#         1    0.043    0.043    0.043    0.043 {method 'to_table' of 'pyarrow._dataset.Dataset' objects}
#         1    0.002    0.002    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377(__init__)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1116(<listcomp>)
#         5    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:683(_reconstruct_block)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:984(__from_arrow__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:858(_deserialize_column_index)
#
#
# count took: 0.0000 seconds
#          9 function calls (7 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:9(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352(__len__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          7 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:12(count_index_length)
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# mean took: 0.0018 seconds
#          288 function calls (283 primitive calls) in 0.002 seconds
#
#    Ordered by: cumulative time
#    List reduced from 117 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 /var/tmp/ipykernel_14262/3872611389.py:15(mean)
#       2/1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418(__getitem__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3876(_get_item_cache)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:977(iget)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:158(blknos)
#         1    0.001    0.001    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:224(_rebuild_blknos_and_blklocs)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#
#
# standard deviation took: 0.0009 seconds
#          279 function calls (278 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 90 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:18(standard_deviation)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10610(std)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10317(std)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271(_stat_function_ddof)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#       2/1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838(nanstd)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877(nanvar)
#         3    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45(_sum)
#         4    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:787(_get_counts_nanvar)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377(_get_counts)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(putmask)
#
#
# mean of columns addition took: 0.0006 seconds
#          516 function calls (513 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 169 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:21(mean_of_sum)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#       4/3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#
#
# addition of columns took: 0.0004 seconds
#          299 function calls (297 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#    List reduced from 116 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:24(sum_columns)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#        57    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#
#
# mean of columns multiplication took: 0.0006 seconds
#          455 function calls (453 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 157 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:29(mean_of_product)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         3    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45(_sum)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#
#
# multiplication of columns took: 0.0003 seconds
#          299 function calls (297 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#    List reduced from 116 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:32(product_columns)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.mul}
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#        57    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#
#
# value counts took: 0.0008 seconds
#          568 function calls (564 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 156 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:37(value_counts)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/base.py:874(value_counts)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796(value_counts)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876(value_counts_arraylike)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/util/_decorators.py:302(wrapper)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258(sort_values)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343(nargsort)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#       135    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:6279(ensure_index)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375(__new__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:103(_ensure_data)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931(new_block)
#
#
# complex arithmetic ops took: 0.0068 seconds
#          6642 function calls (6583 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time
#    List reduced from 203 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.007    0.007 /var/tmp/ipykernel_14262/3872611389.py:41(complicated_arithmetic_operation)
#         8    0.000    0.000    0.004    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.002    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        32    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#        19    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         6    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:318(reconstruct)
#        26    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#
#
# mean of complex arithmetic ops took: 0.0059 seconds
#          6554 function calls (6499 primitive calls) in 0.006 seconds
#
#    Ordered by: cumulative time
#    List reduced from 226 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.006    0.006 /var/tmp/ipykernel_14262/3872611389.py:52(mean_of_complicated_arithmetic_operation)
#         8    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.002    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        28    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         6    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:318(reconstruct)
#        26    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#        19    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        26    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931(new_block)
#        19    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#
#
# groupby statistics took: 0.0046 seconds
#          4084 function calls (4030 primitive calls) in 0.005 seconds
#
#    Ordered by: cumulative time
#    List reduced from 456 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.005    0.005 /var/tmp/ipykernel_14262/3872611389.py:62(groupby_statistics)
#         1    0.000    0.000    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:964(aggregate)
#         1    0.000    0.000    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:143(agg)
#         1    0.000    0.000    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405(agg_dict_like)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:435(<dictcomp>)
#       6/2    0.000    0.000    0.003    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:225(aggregate)
#         2    0.000    0.000    0.003    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278(_aggregate_multiple_funcs)
#         2    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1634(mean)
#         2    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:322(_cython_agg_general)
#         2    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:338(array_func)
#         2    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:991(_cython_operation)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1723(std)
#         2    0.001    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2790(_get_cythonized_result)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/util/_decorators.py:302(wrapper)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/concat.py:90(concat)
#
#
# join count took: 0.0034 seconds
#          3066 function calls (3042 primitive calls) in 0.003 seconds
#
#    Ordered by: cumulative time
#    List reduced from 316 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.003    0.003 /var/tmp/ipykernel_14262/3872611389.py:74(join_count)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:944(_get_join_info)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:198(join)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:3918(join)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475(_concatenate_join_units)
#     74/66    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#         1    0.001    0.001    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018(is_unique)
#        22    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:491(<listcomp>)
#
#
# join took: 0.0022 seconds
#          3016 function calls (2995 primitive calls) in 0.002 seconds
#
#    Ordered by: cumulative time
#    List reduced from 307 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 /var/tmp/ipykernel_14262/3872611389.py:77(join_data)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475(_concatenate_join_units)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#     74/66    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#        22    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:491(<listcomp>)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403(get_reindexed_values)
#         8    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        16    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#     20/18    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54(take_nd)
# 0.0022071399998822017

# %%
# Concatenate results
df_filtered_profile_all = pd.concat(joblib_filtered_profile_data, ignore_index=True)

# %%
# Gerar gráfico cProfile para os dados filtrados (top 15 por 'percall')
print_profile_per_task(joblib_filtered_profile_data, metric='percall', top_n=25)
# Out:
# ============================================================
# Tarefa: read file
# Top 25 funções por 'percall':
#
#                                                                                                                function  percall
#                                                                                     ~:0 (<pyarrow.lib.table_to_blocks>) 0.051291
#                                                         ~:0 (<method 'to_table' of 'pyarrow._dataset.Dataset' objects>) 0.042594
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377 (__init__) 0.002038
#                                                                                         ~:0 (<built-in method io.open>) 0.000656
#                                           ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000363
#                                                                                     ~:0 (<built-in method numpy.array>) 0.000309
#                                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201 (read) 0.000257
#                                                                        ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000184
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:984 (__from_arrow__) 0.000129
#                                                                             ~:0 (<built-in method builtins.isinstance>) 0.000124
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1858 (maybe_coerce_values) 0.000088
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/_arrow_utils.py:49 (__init__) 0.000085
#                                                     /opt/conda/envs/cdle/lib/python3.7/json/encoder.py:204 (iterencode) 0.000083
#                                                           ~:0 (<built-in method pandas._libs.tslibs.offsets.to_offset>) 0.000072
#                                                                          ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000068
#                                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440 (read) 0.000067
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:794 (_get_extension_dtypes) 0.000063
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:1073 (_engine) 0.000059
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/_arrow_utils.py:9 (pyarrow_array_to_numpy_and_mask) 0.000057
#                                                     /opt/conda/envs/cdle/lib/python3.7/json/decoder.py:343 (raw_decode) 0.000054
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1130 (<listcomp>) 0.000050
#                                          ~:0 (<method 'make_fragment' of 'pyarrow._dataset.ParquetFileFormat' objects>) 0.000049
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/_mixins.py:180 (__setitem__) 0.000048
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/api.py:34 (make_block) 0.000046
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756 (table_to_blockmanager) 0.000044
#
# ============================================================
# Tarefa: count
# Top 25 funções por 'percall':
#
#                                                                                   function  percall
#                                                       ~:0 (<built-in method builtins.len>) 0.000004
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352 (__len__) 0.000003
#                                           /var/tmp/ipykernel_14262/3872611389.py:9 (count) 0.000002
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000001
#                                                  ~:0 (<built-in method time.perf_counter>) 0.000000
#                                     ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ============================================================
# Tarefa: count index length
# Top 25 funções por 'percall':
#
#                                                                                   function  percall
#                             /var/tmp/ipykernel_14262/3872611389.py:12 (count_index_length) 0.000004
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000002
#                                                  ~:0 (<built-in method time.perf_counter>) 0.000000
#                                                       ~:0 (<built-in method builtins.len>) 0.000000
#                                     ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ============================================================
# Tarefa: mean
# Top 25 funções por 'percall':
#
#                                                                                                             function  percall
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:224 (_rebuild_blknos_and_blklocs) 0.000992
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000259
#                                                                     ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000071
#                                                                                 ~:0 (<built-in method numpy.arange>) 0.000052
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:347 (_na_ok_dtype) 0.000049
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000014
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:977 (iget) 0.000014
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000013
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000013
#                                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000012
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3876 (_get_item_cache) 0.000012
#                                                                          ~:0 (<built-in method builtins.isinstance>) 0.000011
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000010
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000009
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000009
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000009
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000008
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000008
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000007
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000007
#                                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000006
#                                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000006
#                                                                     /var/tmp/ipykernel_14262/3872611389.py:15 (mean) 0.000006
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000006
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000005
#
# ============================================================
# Tarefa: standard deviation
# Top 25 funções por 'percall':
#
#                                                                                             function  percall
#                                                     ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000284
#                        ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000145
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877 (nanvar) 0.000085
#                                                     ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000040
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45 (_sum) 0.000032
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000031
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000013
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000013
#                                                          ~:0 (<built-in method builtins.isinstance>) 0.000012
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838 (nanstd) 0.000012
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000012
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000009
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000009
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000009
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:787 (_get_counts_nanvar) 0.000007
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:673 (is_integer_dtype) 0.000007
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1585 (_ensure_numeric) 0.000006
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
#                                       /var/tmp/ipykernel_14262/3872611389.py:18 (standard_deviation) 0.000005
#                                                           <__array_function__ internals>:2 (putmask) 0.000005
#                                                      ~:0 (<method 'sum' of 'numpy.ndarray' objects>) 0.000005
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000005
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000005
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:80 (check) 0.000005
#
# ============================================================
# Tarefa: mean of columns addition
# Top 25 funções por 'percall':
#
#                                                                                            function  percall
#                                                    ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000047
#                                                               ~:0 (<built-in method _operator.add>) 0.000033
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000019
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000018
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000016
#                                                         ~:0 (<built-in method builtins.isinstance>) 0.000015
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000013
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000011
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000011
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000011
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000011
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000010
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000010
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:977 (iget) 0.000010
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000009
#                                             /var/tmp/ipykernel_14262/3872611389.py:21 (mean_of_sum) 0.000009
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000009
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000008
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000008
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000008
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000008
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3876 (_get_item_cache) 0.000007
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000007
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000006
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000006
#
# ============================================================
# Tarefa: addition of columns
# Top 25 funções por 'percall':
#
#                                                                                              function  percall
#                                                                 ~:0 (<built-in method _operator.add>) 0.000113
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000016
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000010
#                                                           ~:0 (<built-in method builtins.isinstance>) 0.000010
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000008
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000007
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000007
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000007
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000007
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000005
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000004
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000004
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000004
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000004
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:96 (_get_single_key) 0.000004
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000004
#                                               /var/tmp/ipykernel_14262/3872611389.py:24 (sum_columns) 0.000004
#                                                              ~:0 (<built-in method builtins.getattr>) 0.000004
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2218 (is_object) 0.000003
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/missing.py:140 (dispatch_fill_zeros) 0.000003
#                                                                  ~:0 (<built-in method builtins.all>) 0.000003
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:631 (_info_axis) 0.000003
#
# ============================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por 'percall':
#
#                                                                                            function  percall
#                                                    ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000229
#                                                               ~:0 (<built-in method _operator.mul>) 0.000035
#                                                         ~:0 (<built-in method builtins.isinstance>) 0.000020
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000018
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000015
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000011
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000011
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000011
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000009
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000009
#                                         /var/tmp/ipykernel_14262/3872611389.py:29 (mean_of_product) 0.000008
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000007
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000007
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000007
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000006
#                                                            ~:0 (<built-in method builtins.getattr>) 0.000006
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000005
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:438 (__exit__) 0.000005
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000005
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000005
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000005
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000004
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:780 (is_empty_data) 0.000004
#
# ============================================================
# Tarefa: multiplication of columns
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#                                                                  ~:0 (<built-in method _operator.mul>) 0.000033
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000015
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000012
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:433 (__enter__) 0.000010
#                                                               ~:0 (<built-in method builtins.getattr>) 0.000007
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000007
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000006
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000006
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000006
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000005
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000005
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:96 (_get_single_key) 0.000005
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000004
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000004
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000004
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000004
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000004
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/inference.py:321 (is_hashable) 0.000004
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000004
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569 (from_array) 0.000003
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000003
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000003
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000003
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:673 (_try_cast) 0.000003
#
# ============================================================
# Tarefa: value counts
# Top 25 funções por 'percall':
#
#                                                                                                function  percall
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876 (value_counts_arraylike) 0.000274
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000032
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343 (nargsort) 0.000029
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000029
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000021
#                                                     ~:0 (<method 'argsort' of 'numpy.ndarray' objects>) 0.000018
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258 (sort_values) 0.000016
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796 (value_counts) 0.000014
#                                                                    ~:0 (<built-in method numpy.arange>) 0.000011
#                           ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000011
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000010
#                                                                ~:0 (<built-in method builtins.getattr>) 0.000009
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000008
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4587 (__getitem__) 0.000008
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:605 (_simple_new) 0.000008
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000007
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000007
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000007
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000006
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000006
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000006
#                                                   <frozen importlib._bootstrap>:1009 (_handle_fromlist) 0.000005
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000005
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:183 (_reconstruct_data) 0.000005
#
# ============================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.002142
#                                                              ~:0 (<built-in method _operator.truediv>) 0.000360
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000253
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000240
#                                                                  ~:0 (<built-in method _operator.mul>) 0.000140
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000135
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000128
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000122
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000095
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000095
#                           /var/tmp/ipykernel_14262/3872611389.py:41 (complicated_arithmetic_operation) 0.000088
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000085
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000085
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000081
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000078
#                                                               ~:0 (<built-in method builtins.getattr>) 0.000076
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000066
#                                                                  ~:0 (<built-in method _operator.sub>) 0.000061
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000057
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:577 (name) 0.000055
#                                                                   ~:0 (<built-in method builtins.len>) 0.000055
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000054
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000050
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1539 (__init__) 0.000049
#                                                  <frozen importlib._bootstrap>:1009 (_handle_fromlist) 0.000049
#
# ============================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.001891
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000243
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000191
#                                                              ~:0 (<built-in method _operator.truediv>) 0.000160
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000132
#                                                                  ~:0 (<built-in method _operator.mul>) 0.000114
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000106
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000103
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000103
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000084
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000077
#                                                       ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000076
#                                                               ~:0 (<built-in method builtins.getattr>) 0.000075
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000073
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000071
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000069
#                   /var/tmp/ipykernel_14262/3872611389.py:52 (mean_of_complicated_arithmetic_operation) 0.000068
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000059
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000058
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000056
#                                                                   ~:0 (<built-in method builtins.len>) 0.000054
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000048
#                                                       ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000045
#                                                                  ~:0 (<built-in method _operator.sub>) 0.000044
#                                                                  ~:0 (<built-in method _operator.pow>) 0.000044
#
# ============================================================
# Tarefa: groupby statistics
# Top 25 funções por 'percall':
#
#                                                                                                        function  percall
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2790 (_get_cythonized_result) 0.000795
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:525 (_call_cython_op) 0.000389
#                                   ~:0 (<method 'factorize' of 'pandas._libs.hashtable.Int64HashTable' objects>) 0.000243
#                                                                     ~:0 (<built-in method builtins.isinstance>) 0.000148
#                                                                  ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000121
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000112
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000054
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:680 (get_grouper) 0.000054
#                                                                        ~:0 (<built-in method builtins.getattr>) 0.000049
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000042
#                                                                            ~:0 (<built-in method builtins.len>) 0.000042
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278 (_aggregate_multiple_funcs) 0.000040
#                                                           <frozen importlib._bootstrap>:1009 (_handle_fromlist) 0.000039
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000036
#                                        ~:0 (<method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects>) 0.000035
#                                                                        ~:0 (<built-in method builtins.hasattr>) 0.000034
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000032
#                                                                  ~:0 (<pandas._libs.algos.take_1d_int64_int64>) 0.000029
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1811 (_form_blocks) 0.000029
#                                                                             ~:0 (<built-in method numpy.array>) 0.000029
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:571 (factorize) 0.000026
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/common.py:224 (asarray_tuplesafe) 0.000025
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000025
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/concat.py:626 (_make_concat_multiindex) 0.000024
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:846 (__init__) 0.000024
#
# ============================================================
# Tarefa: join count
# Top 25 funções por 'percall':
#
#                                                                                                                       function  percall
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:2018 (is_unique) 0.000657
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:1948 (is_monotonic_increasing) 0.000257
#                                                                           ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.000225
#                                                                               ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000075
#                                                                                    ~:0 (<built-in method builtins.isinstance>) 0.000075
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000073
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000059
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/inference.py:426 (is_inferred_bool_dtype) 0.000045
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000042
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000041
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000041
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.000038
#                                                                                           ~:0 (<built-in method builtins.all>) 0.000036
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000035
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:517 (_take_preprocess_indexer_and_fill_value) 0.000032
#                                                                          <frozen importlib._bootstrap>:1009 (_handle_fromlist) 0.000030
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000029
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000028
#                                                                                           ~:0 (<built-in method builtins.len>) 0.000028
#                                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381 (is_na) 0.000027
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:327 (_inner_indexer) 0.000026
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:552 (na_value_for_dtype) 0.000026
#                                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/base.py:425 (find) 0.000026
#                               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:598 (<genexpr>) 0.000026
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000025
#
# ============================================================
# Tarefa: join
# Top 25 funções por 'percall':
#
#                                                                                                                       function  percall
#                                                                           ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.000228
#                                                                                    ~:0 (<built-in method builtins.isinstance>) 0.000095
#                                                                               ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000081
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000074
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000067
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000056
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000038
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000036
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000034
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000033
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000030
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711 (get_result) 0.000029
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:552 (na_value_for_dtype) 0.000028
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.000028
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000027
#                                                                          <frozen importlib._bootstrap>:1009 (_handle_fromlist) 0.000027
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:551 (_get_empty_dtype) 0.000026
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:517 (_take_preprocess_indexer_and_fill_value) 0.000026
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000025
#                                                                                           ~:0 (<built-in method builtins.len>) 0.000024
#                                                                                           ~:0 (<built-in method builtins.all>) 0.000023
#                                                                                 ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000023
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585 (_is_uniform_join_units) 0.000022
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000022
#                                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/base.py:425 (find) 0.000022

# %% [markdown]
# **Operations with cache**

# %% [markdown]
# To simulate a realistic scenario where filtered data is reused across tasks (e.g., in iterative workflows or pipelines), the  joblib.Memory was used to cache intermediate results.
#
# For this process we:
#
# - Set up a cache directory (joblib_cache) where joblib stores memoized outputs.
#
# - Defined a function get_filtered_data(df) to wrap the already-filtered DataFrame.
#
# - Decorated it with @memory.cache, so that if the same input is passed again, the cached version is reused, avoiding recomputation.
#
# This simulates "cached data" behavior, often found in pipelines or repeated analytics tasks.
#
# Then a list of parallel tasks was built using this cached DataFrame (joblib_cache) and benchmarked them using the same benchmark_joblib function.

# %%
from joblib import Memory

# Setup a directory where joblib will store cached results
memory = Memory(location='joblib_cache', verbose=0)

# Wrap the filtering logic (or any intermediate result) in a cached function
@memory.cache
def get_filtered_data(df):
    return df       # In this case, df is already filtered, so we just return it

# Apply the cached function to the filtered DataFrame
joblib_cache = get_filtered_data(joblib_filtered)

# %%
# === Define task list using the cached data ===
tasks_cache = [
    (read_file_parquet, None, {}, "read file"),
    (count, joblib_cache, {}, "count"),
    (count_index_length, joblib_cache, {}, "count index length"),
    (mean, joblib_cache, {}, "mean"),
    (standard_deviation, joblib_cache, {}, "standard deviation"),
    (mean_of_sum, joblib_cache, {}, "mean of columns addition"),
    (sum_columns, joblib_cache, {}, "addition of columns"),
    (mean_of_product, joblib_cache, {}, "mean of columns multiplication"),
    (product_columns, joblib_cache, {}, "multiplication of columns"),
    (value_counts, joblib_cache, {}, "value counts"),
    (complicated_arithmetic_operation, joblib_cache, {}, "complex arithmetic ops"),
    (mean_of_complicated_arithmetic_operation, joblib_cache, {}, "mean of complex arithmetic ops"),
    (groupby_statistics, joblib_cache, {}, "groupby statistics"),
    (join_count, joblib_cache, {'other': other}, "join count"),
    (join_data, joblib_cache, {'other': other}, "join"),
]

# %%
# Run the Joblib benchmark using cached data (simulating in-memory reuse)
df_results_cache = benchmark_joblib(tasks_cache, n_jobs=-1, save_path='Results_Joblib_L/joblib_cache_local_large')
print(df_results_cache)
# Out:
# O arquivo Parquet foi salvo em Results_Joblib_L/joblib_cache_local_large.
#                                 duration
# task
# read file                       0.130254
# count                           0.000005
# count index length              0.000003
# mean                            0.000436
# standard deviation              0.000579
# mean of columns addition        0.000675
# addition of columns             0.000628
# mean of columns multiplication  0.000697
# multiplication of columns       0.000509
# value counts                    0.001063
# complex arithmetic ops          0.004669
# mean of complex arithmetic ops  0.005061
# groupby statistics              0.003320
# join count                      0.002418
# join                            0.002231

# %% [markdown]
# **Cache with cProfile**

# %% [markdown]
# In this part of the report, cProfile is used to benchmark the performance of several data operations on a cached version of the filtered DataFrame (joblib_cache). By profiling each function individually, it's possible to identify bottlenecks and analyze which tasks are the most computationally expensive in terms of time per call and cumulative execution time.

# %%
# === Benchmarks with cProfile using cached filtered data ===
joblib_benchmarks_cache_cprofile = {'duration': [], 'task': []}
joblib_cache_profile_data = []

# %%
# Execute benchmarks with cProfile
benchmark_cprofile(read_file_parquet, df=None, benchmarks=joblib_benchmarks_cache_cprofile, name='read file', profile_data=joblib_cache_profile_data)
benchmark_cprofile(count, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='count', profile_data=joblib_cache_profile_data)
benchmark_cprofile(count_index_length, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='count index length', profile_data=joblib_cache_profile_data)
benchmark_cprofile(mean, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='mean', profile_data=joblib_cache_profile_data)
benchmark_cprofile(standard_deviation, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='standard deviation', profile_data=joblib_cache_profile_data)
benchmark_cprofile(mean_of_sum, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='mean of columns addition', profile_data=joblib_cache_profile_data)
benchmark_cprofile(sum_columns, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='addition of columns', profile_data=joblib_cache_profile_data)
benchmark_cprofile(mean_of_product, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='mean of columns multiplication', profile_data=joblib_cache_profile_data)
benchmark_cprofile(product_columns, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='multiplication of columns', profile_data=joblib_cache_profile_data)
benchmark_cprofile(value_counts, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='value counts', profile_data=joblib_cache_profile_data)
benchmark_cprofile(complicated_arithmetic_operation, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='complex arithmetic ops', profile_data=joblib_cache_profile_data)
benchmark_cprofile(mean_of_complicated_arithmetic_operation, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='mean of complex arithmetic ops', profile_data=joblib_cache_profile_data)
benchmark_cprofile(groupby_statistics, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='groupby statistics', profile_data=joblib_cache_profile_data)
benchmark_cprofile(join_count, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='join count', other=other, profile_data=joblib_cache_profile_data)
benchmark_cprofile(join_data, df=joblib_cache, benchmarks=joblib_benchmarks_cache_cprofile, name='join', other=other, profile_data=joblib_cache_profile_data)
# Out:
# read file took: 0.0941 seconds
#          2473 function calls (2462 primitive calls) in 0.094 seconds
#
#    Ordered by: cumulative time
#    List reduced from 400 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.094    0.094 /var/tmp/ipykernel_14262/3872611389.py:6(read_file_parquet)
#         1    0.000    0.000    0.094    0.094 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:433(read_parquet)
#         1    0.000    0.000    0.094    0.094 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201(read)
#         1    0.000    0.000    0.051    0.051 {method 'to_pandas' of 'pyarrow.lib._PandasConvertible' objects}
#         1    0.000    0.000    0.051    0.051 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:756(table_to_blockmanager)
#         1    0.000    0.000    0.049    0.049 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1109(_table_to_blocks)
#         1    0.048    0.048    0.048    0.048 {pyarrow.lib.table_to_blocks}
#         1    0.000    0.000    0.042    0.042 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1551(read_table)
#         1    0.000    0.000    0.040    0.040 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1440(read)
#         1    0.040    0.040    0.040    0.040 {method 'to_table' of 'pyarrow._dataset.Dataset' objects}
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1116(<listcomp>)
#         5    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:683(_reconstruct_block)
#         1    0.001    0.001    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377(__init__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:984(__from_arrow__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:858(_deserialize_column_index)
#
#
# count took: 0.0000 seconds
#          9 function calls (7 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:9(count)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352(__len__)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# count index length took: 0.0000 seconds
#          7 function calls (6 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:12(count_index_length)
#         2    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#       2/1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794(__len__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# mean took: 0.0005 seconds
#          184 function calls in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 78 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:15(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258(_get_values)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214(_maybe_get_mask)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:61(isna)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:144(_isna)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221(_isna_array)
#         3    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#
#
# standard deviation took: 0.0004 seconds
#          279 function calls (278 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#    List reduced from 90 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:18(standard_deviation)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10610(std)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10317(std)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271(_stat_function_ddof)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#       2/1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838(nanstd)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877(nanvar)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258(_get_values)
#         4    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         3    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45(_sum)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(putmask)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214(_maybe_get_mask)
#
#
# mean of columns addition took: 0.0006 seconds
#          455 function calls (453 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 157 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:21(mean_of_sum)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#
#
# addition of columns took: 0.0004 seconds
#          299 function calls (297 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#    List reduced from 116 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:24(sum_columns)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:90(__add__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931(new_block)
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#
#
# mean of columns multiplication took: 0.0006 seconds
#          455 function calls (453 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 157 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:29(mean_of_product)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10740(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10368(mean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324(_stat_function)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359(_reduce)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84(_f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120(f)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396(new_func)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616(nanmean)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         3    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:45(_sum)
#
#
# multiplication of columns took: 0.0003 seconds
#          299 function calls (297 primitive calls) in 0.000 seconds
#
#    Ordered by: cumulative time
#    List reduced from 116 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 /var/tmp/ipykernel_14262/3872611389.py:32(product_columns)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.mul}
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473(__getattr__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#        57    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#
#
# value counts took: 0.0007 seconds
#          567 function calls (563 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#    List reduced from 155 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 /var/tmp/ipykernel_14262/3872611389.py:37(value_counts)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/base.py:874(value_counts)
#         1    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796(value_counts)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876(value_counts_arraylike)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/util/_decorators.py:302(wrapper)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258(sort_values)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343(nargsort)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:6279(ensure_index)
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375(__new__)
#       135    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931(new_block)
#         1    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:103(_ensure_data)
#         6    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369(extract_array)
#
#
# complex arithmetic ops took: 0.0061 seconds
#          6398 function calls (6343 primitive calls) in 0.006 seconds
#
#    Ordered by: cumulative time
#    List reduced from 190 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.006    0.006 /var/tmp/ipykernel_14262/3872611389.py:41(complicated_arithmetic_operation)
#         8    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#         8    0.002    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        19    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#        19    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#        28    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#        19    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#         6    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:318(reconstruct)
#        26    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#
#
# mean of complex arithmetic ops took: 0.0062 seconds
#          6554 function calls (6499 primitive calls) in 0.006 seconds
#
#    Ordered by: cumulative time
#    List reduced from 226 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.006    0.006 /var/tmp/ipykernel_14262/3872611389.py:52(mean_of_complicated_arithmetic_operation)
#        19    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54(new_method)
#         8    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:2029(__array_ufunc__)
#        19    0.000    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516(_arith_method)
#         8    0.002    0.000    0.003    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234(array_ufunc)
#        28    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315(__init__)
#        19    0.000    0.000    0.002    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916(_construct_result)
#         6    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:114(__truediv__)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:106(__mul__)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185(arithmetic_op)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138(_na_arithmetic_op)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:223(evaluate)
#        19    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/computation/expressions.py:63(_evaluate_standard)
#        26    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569(from_array)
#         7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:318(reconstruct)
#
#
# groupby statistics took: 0.0043 seconds
#          4022 function calls (3968 primitive calls) in 0.004 seconds
#
#    Ordered by: cumulative time
#    List reduced from 446 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.004    0.004 /var/tmp/ipykernel_14262/3872611389.py:62(groupby_statistics)
#         1    0.000    0.000    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:964(aggregate)
#         1    0.000    0.000    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:143(agg)
#         1    0.000    0.000    0.004    0.004 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405(agg_dict_like)
#         1    0.000    0.000    0.003    0.003 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:435(<dictcomp>)
#       6/2    0.000    0.000    0.003    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:225(aggregate)
#         2    0.000    0.000    0.003    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278(_aggregate_multiple_funcs)
#         2    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:1634(mean)
#         2    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:322(_cython_agg_general)
#         2    0.000    0.000    0.001    0.001 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:338(array_func)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:991(_cython_operation)
#         4    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:573(__init__)
#      13/7    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375(__new__)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/util/_decorators.py:302(wrapper)
#         2    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/construction.py:396(dict_to_mgr)
#
#
# join count took: 0.0025 seconds
#          3021 function calls (2998 primitive calls) in 0.002 seconds
#
#    Ordered by: cumulative time
#    List reduced from 308 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 /var/tmp/ipykernel_14262/3872611389.py:74(join_count)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475(_concatenate_join_units)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#     74/66    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#        22    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:491(<listcomp>)
#         8    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403(get_reindexed_values)
#        16    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#     20/18    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54(take_nd)
#
#
# join took: 0.0024 seconds
#          3016 function calls (2995 primitive calls) in 0.002 seconds
#
#    Ordered by: cumulative time
#    List reduced from 307 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 /var/tmp/ipykernel_14262/3872611389.py:77(join_data)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:9171(merge)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:89(merge)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/merge.py:711(get_result)
#         1    0.000    0.000    0.002    0.002 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171(concatenate_managers)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475(_concatenate_join_units)
#     74/66    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585(_is_uniform_join_units)
#        22    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:607(<genexpr>)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381(is_na)
#         8    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647(isna_all)
#        16    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679(<genexpr>)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:491(<listcomp>)
#        11    0.000    0.000    0.001    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403(get_reindexed_values)
#     20/18    0.000    0.000    0.000    0.000 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54(take_nd)
# 0.0024235790001512214

# %%
# Concatenate all results
df_cache_profile_all = pd.concat(joblib_cache_profile_data, ignore_index=True)

# %%
print_profile_per_task(joblib_cache_profile_data, metric='percall', top_n=25)
# Out:
# ============================================================
# Tarefa: read file
# Top 25 funções por 'percall':
#
#                                                                                                                function  percall
#                                                                                     ~:0 (<pyarrow.lib.table_to_blocks>) 0.047750
#                                                         ~:0 (<method 'to_table' of 'pyarrow._dataset.Dataset' objects>) 0.040039
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/parquet.py:1377 (__init__) 0.001274
#                                                        /opt/conda/envs/cdle/lib/python3.7/posixpath.py:232 (expanduser) 0.000417
#                                                                                     ~:0 (<built-in method numpy.array>) 0.000385
#                                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/io/parquet.py:201 (read) 0.000246
#                                                                                         ~:0 (<built-in method io.open>) 0.000210
#                                                                        ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000187
#                                                                             ~:0 (<built-in method builtins.isinstance>) 0.000126
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py:984 (__from_arrow__) 0.000117
#                                           ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000096
#                                                                                      ~:0 (<built-in method posix.stat>) 0.000086
#                                                                          ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000068
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/_arrow_utils.py:49 (__init__) 0.000068
#                                                           ~:0 (<built-in method pandas._libs.tslibs.offsets.to_offset>) 0.000068
#                            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/multi.py:1073 (_engine) 0.000057
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:794 (_get_extension_dtypes) 0.000056
#                                          ~:0 (<method 'make_fragment' of 'pyarrow._dataset.ParquetFileFormat' objects>) 0.000053
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/_arrow_utils.py:9 (pyarrow_array_to_numpy_and_mask) 0.000051
#                             /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:1130 (<listcomp>) 0.000048
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pyarrow/pandas_compat.py:683 (_reconstruct_block) 0.000045
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000044
#                                                     /opt/conda/envs/cdle/lib/python3.7/json/decoder.py:343 (raw_decode) 0.000044
#                                                     /opt/conda/envs/cdle/lib/python3.7/json/encoder.py:204 (iterencode) 0.000043
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/_arrow_utils.py:63 (__arrow_ext_deserialize__) 0.000041
#
# ============================================================
# Tarefa: count
# Top 25 funções por 'percall':
#
#                                                                                   function  percall
#                                                       ~:0 (<built-in method builtins.len>) 0.000005
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:1352 (__len__) 0.000003
#                                           /var/tmp/ipykernel_14262/3872611389.py:9 (count) 0.000002
#                                                  ~:0 (<built-in method time.perf_counter>) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000000
#                                     ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000000
#
# ============================================================
# Tarefa: count index length
# Top 25 funções por 'percall':
#
#                                                                                   function  percall
#                             /var/tmp/ipykernel_14262/3872611389.py:12 (count_index_length) 0.000005
#                                                  ~:0 (<built-in method time.perf_counter>) 0.000001
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:794 (__len__) 0.000001
#                                     ~:0 (<method 'disable' of '_lsprof.Profiler' objects>) 0.000001
#                                                       ~:0 (<built-in method builtins.len>) 0.000000
#
# ============================================================
# Tarefa: mean
# Top 25 funções por 'percall':
#
#                                                                                             function  percall
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000205
#                                                     ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000079
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000014
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000013
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000012
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000011
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000009
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000008
#                                                     /var/tmp/ipykernel_14262/3872611389.py:15 (mean) 0.000008
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:1377 (_get_counts) 0.000007
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000007
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:673 (is_integer_dtype) 0.000006
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000006
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000005
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000005
#                                                              ~:0 (<built-in method numpy.geterrobj>) 0.000004
#                                                          ~:0 (<built-in method builtins.isinstance>) 0.000004
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_methods.py:53 (_any) 0.000004
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000004
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:396 (new_func) 0.000003
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214 (_maybe_get_mask) 0.000003
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:87 (<genexpr>) 0.000003
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:80 (check) 0.000003
#
# ============================================================
# Tarefa: standard deviation
# Top 25 funções por 'percall':
#
#                                                                                            function  percall
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:877 (nanvar) 0.000082
#                                                    ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000060
#                       ~:0 (<built-in method numpy.core._multiarray_umath.implement_array_function>) 0.000034
#                                                    ~:0 (<method 'copy' of 'numpy.ndarray' objects>) 0.000020
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000018
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:120 (f) 0.000011
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000011
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:838 (nanstd) 0.000011
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000009
#                                                         ~:0 (<built-in method builtins.isinstance>) 0.000008
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000008
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000008
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000006
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10271 (_stat_function_ddof) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000005
#                                      /var/tmp/ipykernel_14262/3872611389.py:18 (standard_deviation) 0.000005
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000004
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10317 (std) 0.000004
#                                                  ~:0 (<method 'astype' of 'numpy.generic' objects>) 0.000004
#                                                            ~:0 (<built-in method builtins.getattr>) 0.000004
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000004
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:214 (_maybe_get_mask) 0.000004
#                                                          <__array_function__ internals>:2 (putmask) 0.000004
#
# ============================================================
# Tarefa: mean of columns addition
# Top 25 funções por 'percall':
#
#                                                                                              function  percall
#                                                                 ~:0 (<built-in method _operator.add>) 0.000125
#                                                      ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000041
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000026
#                                                           ~:0 (<built-in method builtins.isinstance>) 0.000023
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000016
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000013
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000012
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000008
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000008
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000008
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000008
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000008
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:616 (nanmean) 0.000007
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000007
#                                               /var/tmp/ipykernel_14262/3872611389.py:21 (mean_of_sum) 0.000007
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000006
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000006
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000006
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000006
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000005
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000005
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000005
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000005
#
# ============================================================
# Tarefa: addition of columns
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#                                                                  ~:0 (<built-in method _operator.add>) 0.000148
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000016
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000010
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000010
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000009
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000009
#                                                               ~:0 (<built-in method builtins.getattr>) 0.000007
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000006
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000006
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000006
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000006
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/__init__.py:151 (align_method_SERIES) 0.000005
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000005
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000005
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1737 (<genexpr>) 0.000005
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000005
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000005
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000004
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000004
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000004
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000004
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:565 (_get_root) 0.000004
#                                                                   ~:0 (<built-in method builtins.len>) 0.000004
#
# ============================================================
# Tarefa: mean of columns multiplication
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#                                                       ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000214
#                                                                  ~:0 (<built-in method _operator.mul>) 0.000042
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000018
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000012
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:258 (_get_values) 0.000010
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000009
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000009
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000009
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000009
#                                            /var/tmp/ipykernel_14262/3872611389.py:29 (mean_of_product) 0.000008
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000007
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000007
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/nanops.py:84 (_f) 0.000007
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000006
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000006
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000006
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:10324 (_stat_function) 0.000005
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000005
#                                                                ~:0 (<built-in method numpy.seterrobj>) 0.000005
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000005
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/__init__.py:151 (align_method_SERIES) 0.000005
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000005
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000005
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:4359 (_reduce) 0.000005
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:433 (__enter__) 0.000004
#
# ============================================================
# Tarefa: multiplication of columns
# Top 25 funções por 'percall':
#
#                                                                                                   function  percall
#                                                                      ~:0 (<built-in method _operator.mul>) 0.000060
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000012
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000010
#                                                                ~:0 (<built-in method builtins.isinstance>) 0.000010
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000008
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000008
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3418 (__getitem__) 0.000006
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000006
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000005
#                                                                   ~:0 (<built-in method builtins.getattr>) 0.000005
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000005
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000004
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000004
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4537 (__contains__) 0.000004
#                                                /var/tmp/ipykernel_14262/3872611389.py:32 (product_columns) 0.000004
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/frame.py:3876 (_get_item_cache) 0.000004
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000004
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:138 (_na_arithmetic_op) 0.000003
#                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000003
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:185 (arithmetic_op) 0.000003
#                /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py:70 (__init__) 0.000003
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/common.py:54 (new_method) 0.000003
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000003
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/ops/__init__.py:151 (align_method_SERIES) 0.000003
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1718 (validate_all_hashable) 0.000003
#
# ============================================================
# Tarefa: value counts
# Top 25 funções por 'percall':
#
#                                                                                                function  percall
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:876 (value_counts_arraylike) 0.000265
#                                                             ~:0 (<built-in method builtins.isinstance>) 0.000023
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/sorting.py:343 (nargsort) 0.000022
#                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000017
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:3258 (sort_values) 0.000013
#                                                     ~:0 (<method 'argsort' of 'numpy.ndarray' objects>) 0.000011
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000010
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:6279 (ensure_index) 0.000010
#           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:796 (value_counts) 0.000009
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000008
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:605 (_simple_new) 0.000008
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000007
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000007
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000007
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000007
#         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:4587 (__getitem__) 0.000007
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000006
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1264 (is_bool_dtype) 0.000006
#                                                                ~:0 (<built-in method builtins.getattr>) 0.000006
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5473 (__getattr__) 0.000005
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/numeric.py:140 (_ensure_array) 0.000004
#     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000004
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:221 (_isna_array) 0.000004
#  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/_config/config.py:579 (_get_deprecated_option) 0.000004
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000004
#
# ============================================================
# Tarefa: complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.001933
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000252
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000192
#                                                              ~:0 (<built-in method _operator.truediv>) 0.000172
#                                                                  ~:0 (<built-in method _operator.mul>) 0.000157
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000135
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000118
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000116
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000083
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000082
#                           /var/tmp/ipykernel_14262/3872611389.py:41 (complicated_arithmetic_operation) 0.000078
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000077
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000076
#                                                               ~:0 (<built-in method builtins.getattr>) 0.000075
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000075
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000069
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000068
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000067
#                                                                   ~:0 (<built-in method builtins.len>) 0.000062
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000058
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569 (from_array) 0.000054
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:577 (name) 0.000050
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000049
#                                                                  ~:0 (<built-in method _operator.sub>) 0.000046
#                                                               ~:0 (<built-in method builtins.hasattr>) 0.000046
#
# ============================================================
# Tarefa: mean of complex arithmetic ops
# Top 25 funções por 'percall':
#
#                                                                                               function  percall
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/arraylike.py:234 (array_ufunc) 0.001879
#                                                              ~:0 (<built-in method _operator.truediv>) 0.000345
#                                                            ~:0 (<built-in method builtins.isinstance>) 0.000268
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000209
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:5516 (_arith_method) 0.000140
#                                                                  ~:0 (<built-in method _operator.mul>) 0.000114
#            /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5435 (__finalize__) 0.000111
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000097
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:463 (sanitize_array) 0.000086
#                   /var/tmp/ipykernel_14262/3872611389.py:52 (mean_of_complicated_arithmetic_operation) 0.000085
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:627 (name) 0.000084
#                                                                  ~:0 (<built-in method _operator.pow>) 0.000081
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32 (seterr) 0.000080
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:5489 (__setattr__) 0.000073
#                                                               ~:0 (<built-in method builtins.getattr>) 0.000072
#      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000069
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000064
#              /opt/conda/envs/cdle/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132 (geterr) 0.000064
#       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/construction.py:369 (extract_array) 0.000060
#                                                                   ~:0 (<built-in method builtins.len>) 0.000059
#                                                                  ~:0 (<built-in method _operator.sub>) 0.000056
#        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:2916 (_construct_result) 0.000048
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:577 (name) 0.000047
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000047
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1569 (from_array) 0.000047
#
# ============================================================
# Tarefa: groupby statistics
# Top 25 funções por 'percall':
#
#                                                                                                        function  percall
#   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/groupby.py:2790 (_get_cythonized_result) 0.000466
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/ops.py:525 (_call_cython_op) 0.000390
#                                                                  ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000201
#                                   ~:0 (<method 'factorize' of 'pandas._libs.hashtable.Int64HashTable' objects>) 0.000182
#                                                                     ~:0 (<built-in method builtins.isinstance>) 0.000173
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:375 (__new__) 0.000159
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000054
#                                                                            ~:0 (<built-in method builtins.len>) 0.000047
#                                                                        ~:0 (<built-in method builtins.hasattr>) 0.000046
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/series.py:315 (__init__) 0.000043
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/generic.py:278 (_aggregate_multiple_funcs) 0.000041
#          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/managers.py:1811 (_form_blocks) 0.000040
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:1578 (_is_dtype_type) 0.000039
#                                                           <frozen importlib._bootstrap>:1009 (_handle_fromlist) 0.000038
#                                                                        ~:0 (<built-in method builtins.getattr>) 0.000038
#                                                                             ~:0 (<built-in method numpy.empty>) 0.000030
#                                                                  ~:0 (<pandas._libs.algos.take_1d_int64_int64>) 0.000029
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/common.py:224 (asarray_tuplesafe) 0.000027
#                                                                             ~:0 (<built-in method numpy.array>) 0.000027
#               /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/groupby/grouper.py:680 (get_grouper) 0.000026
#                       /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/apply.py:405 (agg_dict_like) 0.000026
#                      /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/algorithms.py:571 (factorize) 0.000025
#                          /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/generic.py:233 (__init__) 0.000025
#                                                                            ~:0 (<built-in method builtins.all>) 0.000025
#    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/reshape/concat.py:626 (_make_concat_multiindex) 0.000024
#
# ============================================================
# Tarefa: join count
# Top 25 funções por 'percall':
#
#                                                                                                                       function  percall
#                                                                           ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.000225
#                                                                               ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000094
#                                                                                    ~:0 (<built-in method builtins.isinstance>) 0.000088
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000064
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000061
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000061
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.000044
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000041
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000041
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000040
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:517 (_take_preprocess_indexer_and_fill_value) 0.000035
#                                                                                           ~:0 (<built-in method builtins.all>) 0.000031
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000030
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:190 (is_sparse) 0.000029
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:552 (na_value_for_dtype) 0.000029
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000029
#                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:585 (_is_uniform_join_units) 0.000028
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000028
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000028
#                                                                          <frozen importlib._bootstrap>:1009 (_handle_fromlist) 0.000027
#                                                                                           ~:0 (<built-in method builtins.len>) 0.000025
#                                                                                 ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000025
#                                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381 (is_na) 0.000024
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:327 (_inner_indexer) 0.000024
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000024
#
# ============================================================
# Tarefa: join
# Top 25 funções por 'percall':
#
#                                                                                                                       function  percall
#                                                                           ~:0 (<built-in method pandas._libs.missing.isnaobj>) 0.000221
#                                                                               ~:0 (<method 'reduce' of 'numpy.ufunc' objects>) 0.000175
#                                                                                    ~:0 (<built-in method builtins.isinstance>) 0.000097
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:111 (_take_nd_ndarray) 0.000071
#             /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:239 (_get_mgr_concatenation_plan) 0.000052
#                           /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:339 (needs_filling) 0.000048
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:54 (take_nd) 0.000044
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:171 (concatenate_managers) 0.000042
#                                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:679 (<genexpr>) 0.000041
# /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/array_algos/take.py:517 (_take_preprocess_indexer_and_fill_value) 0.000038
#                 /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:475 (_concatenate_join_units) 0.000036
#                    /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:403 (get_reindexed_values) 0.000035
#                                                                                           ~:0 (<built-in method builtins.all>) 0.000031
#                         /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1890 (get_block_type) 0.000027
#                                     /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/generic.py:43 (_check) 0.000026
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:647 (isna_all) 0.000026
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:552 (na_value_for_dtype) 0.000024
#                                                                                 ~:0 (<pandas._libs.lib.maybe_convert_objects>) 0.000024
#                                   /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:381 (is_na) 0.000024
#                                                                                           ~:0 (<built-in method builtins.len>) 0.000023
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/indexes/base.py:327 (_inner_indexer) 0.000021
#                              /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/blocks.py:1931 (new_block) 0.000021
#                                  /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/common.py:190 (is_sparse) 0.000021
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/dtypes/missing.py:259 (_isna_string_dtype) 0.000021
#                        /opt/conda/envs/cdle/lib/python3.7/site-packages/pandas/core/internals/concat.py:551 (_get_empty_dtype) 0.000021
